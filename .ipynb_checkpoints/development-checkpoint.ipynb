# %% [markdown]
# # Auxiliary

# %%
import numpy as np
import tensorflow as tf
import itertools

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Models

# %%
from models.pbc import Box
from models.lj import LJFluid
from models.chain import GaussianChain
from models.ising import IsingModel
from models.nematic import NematicLattice
# Out:
# [autoreload of models.nematic failed: Traceback (most recent call last):
#   File "/Users/sfriedowitz/anaconda3/envs/mlearn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/sfriedowitz/anaconda3/envs/mlearn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/sfriedowitz/anaconda3/envs/mlearn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/Users/sfriedowitz/anaconda3/envs/mlearn/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 332, in update_class
#     if (old_obj == new_obj) is True:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ]

# %% [markdown]
# ## LJ Fluid

# %%
lj = LJFluid(sig = 3, L = 50, dim = 2)
x = lj.init_coords(10, init_try = 5000)

# %%
lj.calc_energy(x)
# Out:
# -0.7674727179833012

# %%
lj.draw_config(x)

# %% [markdown]
# ## Gaussian Chain

# %%
chain = GaussianChain(r0 = 1.5, k = 10.0, L = 10)

chain.params
# Out:
# {'sig': 1.0, 'eps': 1.0, 'r0': 1.5, 'k': 10.0, 'L': 10}

# %%
N = 400
x = chain.init_coords(N)

chain.calc_energy(x)

chain.calc_energy_idx(x, 1)
# Out:
# 5.446925581873977

# %%
chain.draw_config(chain.unwrap(x))

# %%
# %time chain.oprm(x)
# Out:
# CPU times: user 3.96 ms, sys: 575 µs, total: 4.53 ms
# Wall time: 4.07 ms
# 264.81395469500467

# %%
(N * 1.5**2) / 6
# Out:
# 150.0

# %% [markdown]
# ## Ising Model

# %%
ising = IsingModel(h = 1.0)

ising.params
# Out:
# {'h': 1.0, 'J': 1.0}

# %%
x = ising.init_coords(4)

ising.calc_energy(x)
# Out:
# 0.0

# %%
# %time ising.calc_energy_idx(x, 10)
# Out:
# CPU times: user 95 µs, sys: 9 µs, total: 104 µs
# Wall time: 98.2 µs
# -1.0

# %%
ising.draw_config(x)

# %%
ising.oprm(x)
# Out:
# -0.125

# %% [markdown]
# ## Nematic Lattice

# %%
nem = NematicLattice()

# %%
a = np.array([0, 0, 1])
# Out:
# array([0, 0, 1])
