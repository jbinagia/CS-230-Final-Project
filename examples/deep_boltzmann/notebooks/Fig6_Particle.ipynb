# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import keras
import tensorflow as tf
import pyemma
from pyemma.util.statistics import confidence_interval
# Out:
# Using TensorFlow backend.

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
rcParams.update({'font.size': 16})

# %%
# Switch AUTORELOAD ON. Disable this when in production mode!
# %load_ext autoreload
# %autoreload 2

# %%
import keras
import tensorflow as tf
from deep_boltzmann.models import ParticleDimer
from deep_boltzmann.networks.training import FlexibleTrainer, MLTrainer
from deep_boltzmann.networks.invertible import invnet, EnergyInvNet
from deep_boltzmann.sampling import GaussianPriorMCMC
from deep_boltzmann.sampling.latent_sampling import BiasedModel
from deep_boltzmann.sampling.permutation import HungarianMapper
from deep_boltzmann.util import load_obj, save_obj
# Out:
# /Users/noe/anaconda/lib/python3.5/site-packages/pyemma/__init__.py:130: UserWarning: You are not using the latest release of PyEMMA. Latest is 2.5.5, you have 2.5.3.
#   .format(latest=latest, current=current), category=UserWarning)

# %%
def energy_stats(network):
    blind_sample_z, blind_sample_x, blind_energy_z, blind_energies_x, _ = network.sample(temperature=1.0, nsample=100000)
    nlow = np.size(np.where(blind_energies_x < 100)[0])
    return blind_energies_x.min(), nlow

def sample_stats(d):
    from deep_boltzmann.util import count_transitions, acf
    ntrans = count_transitions(d, 1.25, 1.75)
    acf100 = acf(d, 100)
    acf1000 = acf(d, 1000)
    acf10000 = acf(d, 10000)
    return ntrans, acf100[0], acf1000[0], acf10000[0]

def distance_metric(x):
    """ Outputs 2.5 for closed and 5 for open dimer
    """
    d = model.dimer_distance_tf(x)
    dscaled = 3.0 * (d - 1.5)
    return 2.5 * (1.0 + tf.sigmoid(dscaled))

# %%
def train_and_sample_free_energy(trainer, model, xtrain, temperatures_analysis, 
                                 nsample=100, nepochs_per_iter=10, niter=100, train_batchsize=None):
    bg = trainer.bg
    # Train and sample for multiple temperatures
    F_by_temp = [[] for T in temperatures_analysis]
    Ex_by_temp = [[] for T in temperatures_analysis]
    Jzx_by_temp = [[] for T in temperatures_analysis]
    for i in range(niter):  # training iteration
        print(i, '/', niter)
        if train_batchsize is None:
            trainer.train(xtrain, epochs=nepochs_per_iter)
        else:
            trainer.train(xtrain, epochs=nepochs_per_iter, batch_size=train_batchsize)
        for t, T in enumerate(temperatures_analysis):  # temperature iteration
            samples_z = np.sqrt(T) * np.random.randn(nsample, model.dim)
            samples_x, samples_Jzx = bg.transform_zxJ(samples_z)
            samples_enerx = model.energy(samples_x)
            Ex_by_temp[t].append(samples_enerx)
            Jzx_by_temp[t].append(samples_Jzx)     
    for t, T in enumerate(temperatures_analysis):  # temperature iteration
        F_by_temp[t] = np.concatenate(Ex_by_temp[t]) / T - np.concatenate(Jzx_by_temp[t])
        #Ex_by_temp[t] = np.concatenate(Ex_by_temp[t]) / T
        #Jzx_by_temp[t] = np.concatenate(Jzx_by_temp[t])
    return F_by_temp

# %%
def train_and_sample(trainer, model, xtrain, temperatures_analysis,
                     nsample=100, nepochs_per_iter=10, niter=100):
    bg = trainer.bg
    # Train and sample for multiple temperatures
    F_by_temp = [[] for T in temperatures_analysis]
    Ex_by_temp = [[] for T in temperatures_analysis]
    Jzx_by_temp = [[] for T in temperatures_analysis]
    Jxz_by_temp = [[] for T in temperatures_analysis]
    for i in range(niter):  # training iteration
        print(i, '/', niter)
        trainer.train(xtrain, epochs=nepochs_per_iter)
        for t, T in enumerate(temperatures_analysis):  # temperature iteration
            samples_z = np.sqrt(T) * np.random.randn(nsample, model.dim)
            samples_x, samples_Jzx = bg.transform_zxJ(samples_z)
            _, samples_Jxz = bg.transform_xzJ(samples_x)
            samples_enerx = model.energy(samples_x)
            Ex_by_temp[t].append(samples_enerx)
            Jzx_by_temp[t].append(samples_Jzx)
            Jxz_by_temp[t].append(samples_Jxz)
    for t, T in enumerate(temperatures_analysis):  # temperature iteration
        E = np.concatenate(Ex_by_temp[t])
        Jzx = np.concatenate(Jzx_by_temp[t])
        Jxz = np.concatenate(Jzx_by_temp[t])
        Ex_by_temp[t] = E
        Jzx_by_temp[t] = Jzx
        Jxz_by_temp[t] = Jxz
        F_by_temp[t] = E / T - Jzx
    resdict = {}
    resdict['E'] = Ex_by_temp
    resdict['Jzx'] = Jzx_by_temp
    resdict['Jxz'] = Jxz_by_temp
    resdict['F'] = F_by_temp
    return resdict

# %%
def dF_running_mean(dFs, window=100, step=1, dF_cut=50):
    dF_runningmean = []
    for i in range(0, dFs.size-window, step):
        chunk = dFs[i:i+window]
        chunk_reg = chunk[np.logical_and(chunk > -dF_cut, chunk < dF_cut)]
        dF_runningmean.append(chunk_reg.mean())
    return dF_runningmean

# %%
def clean_differences_from_scratch_chunk(E1, Jxz1, Jzx1, E2, Jzx2, Jxz2, T=1.0, chunksize=1000,
                                         cut_initial=-1000, cut_over_median=2500, cut_Jdiff=0.01, return_terms=False):
    dFs = []
    dEs = []
    dJs = []
    median1_cleaned = np.median(E1[E1 < cut_initial])
    median2_cleaned = np.median(E2[E2 < cut_initial])
    for t in range(0, E1.size//chunksize):
        E1chunk = E1[t*chunksize:(t+1)*chunksize]
        E2chunk = E2[t*chunksize:(t+1)*chunksize]
        Jzx1chunk = Jzx1[t*chunksize:(t+1)*chunksize]
        Jzx2chunk = Jzx2[t*chunksize:(t+1)*chunksize]
        Jxz1chunk = Jzx1[t*chunksize:(t+1)*chunksize]
        Jxz2chunk = Jzx2[t*chunksize:(t+1)*chunksize]
        # keep only what's good in both and where we have invertibility:
        sel_ener = np.logical_and(E1chunk < median1_cleaned + cut_over_median, 
                                  E2chunk < median2_cleaned + cut_over_median)
        sel_inv = np.logical_and(Jxz1chunk + Jzx1chunk < cut_Jdiff, Jxz2chunk + Jzx2chunk < cut_Jdiff)
        sel = np.logical_and(sel_ener, sel_inv)
        dF = np.mean((E2chunk[sel]/T - Jzx2chunk[sel]) - (E1chunk[sel]/T - Jzx1chunk[sel]))
        dE = np.mean(E2chunk[sel]/T - E1chunk[sel]/T)
        dJ = np.mean(Jzx1chunk[sel] - Jzx2chunk[sel])
        dFs.append(dF)
        dEs.append(dE)
        dJs.append(dJ)
    if return_terms:
        return np.array(dFs), np.array(dEs), np.array(dJs)
    else:
        return np.array(dFs)

# %%
paper_dir = '/Users/noe/data/papers/NoeEtAl_BoltzmannGeneratorsRev/'

# %% [markdown]
# Particle model
# ---
# Run notebook "Particles_Simulation_Data" to generate data

# %%
# load trajectory data
trajdict = np.load('../data/particles_tilted/trajdata_long.npz')
import ast
params = ast.literal_eval(str(trajdict['params']))
traj_closed_train = trajdict['traj_closed_train_hungarian']
traj_open_train = trajdict['traj_open_train_hungarian']
traj_closed_test = trajdict['traj_closed_test_hungarian']
traj_open_test = trajdict['traj_open_test_hungarian']
x = np.vstack([traj_closed_train, traj_open_train])
xval = np.vstack([traj_closed_test, traj_open_test])

# %%
# create model
params['grid_k'] = 0.0
model = ParticleDimer(params=params)

# %%
# hyperparameters
hyperparams = {'layer_types' : 'RRRRRRRR',
               'nl_layers' : 3,
               'nl_hidden' : 200,
               'nl_activation' : 'tanh',
               'zstd' : 1.0,
               'reg_Jxz' : 0.0,
               'temperature' : [0.1, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 3.0, 4.0],
               'weight_ML' : 0.1,
               'weight_W2' : 0.0,
               'weight_RC' : 10.0,
               }

# %%
npzfile = np.load('./particles/US_data.npz')
colors = ['black', 'purple', 'blue', 'orange', 'red']
x = npzfile['umbrella_positions']
temperatures_US = npzfile['temperatures']
dF_closed_open_US = []
for i, dF in enumerate(npzfile['umbrella_free_energies']):
    icolor = i // 3
    plt.plot(x, dF, color=colors[icolor])
    W = np.exp(-dF)
    dF_at_kT0 = -np.log(np.sum(W[x < 1.5]) / np.sum(W[x >= 1.5]))
    dF_closed_open_US.append(dF_at_kT0)
    print(temperatures_US[i], dF_at_kT0)
# Out:
# 0.15 -60.78149494219376
# 0.15 -54.80906030006441
# 0.15 -66.82129157380976
# 0.25 -34.02408228190505
# 0.25 -36.378770183999876
# 0.25 -31.033689809728696
# 0.5 -14.286441470542922
# 0.5 -15.261248313620838
# 0.5 -13.63487889725406
# 1.0 -6.628717637498096
# 1.0 -7.124522164227016
# 1.0 -7.547679576558392
# 2.0 -3.3690130502955613
# 2.0 -3.298268077804168
# 2.0 -3.0709626368335443

# %% [markdown]
# Boltzmann Generator
# -------

# %%
ndata = 10000
batchsize_ML =  128
batchsize_KL = 1000
noise_intensity = 0.05

#ndata = 5000
#batchsize_ML =  128
#batchsize_KL = 1000
#noise_intensity = 0.05
temperatures_training = np.array([1.0, 2.0, 3.0])
temperatures_analysis = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.6, 0.8, 1.0, 1.25, 1.5, 1.75, 2.0, 2.5, 3.0, 3.5, 4.0]

# %%
X1 = traj_closed_train[:ndata]
X1val = traj_closed_test[:ndata]
X1noise = X1 + noise_intensity * np.random.randn(*X1.shape).astype(np.float32)
X2 = traj_open_train[:ndata]
X2val = traj_open_test[:ndata]
X2noise = X2 + noise_intensity * np.random.randn(*X2.shape).astype(np.float32)

# %%
plt.figure(figsize=(4, 2))
X1_dist = model.dimer_distance(X1)
X2_dist = model.dimer_distance(X2)
plt.hist(X1_dist[X1_dist < 3], 100, density=True)
plt.hist(X2_dist[X2_dist < 3], 100, density=True)
plt.xlim(0.6, 2.4)
plt.ylim(0, 20)
plt.xticks([1, 1.5, 2])
plt.xlabel('distance / nm')
plt.yticks([])
#plt.savefig(paper_dir + 'figs/particles/minidist.pdf', bbox_inches='tight', transparent=True)
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
model.draw_config(X1[10], dimercolor='blue', alpha=0.8);

# %%
model.draw_config(X2[0], dimercolor='red', alpha=0.8);

# %%
bg1 = invnet(model.dim, 'RRRRRRRR', energy_model=model, nl_layers=4, nl_hidden=100, #100
             nl_activation='relu', nl_activation_scale='tanh', whiten=X1noise)
bg2 = invnet(model.dim, 'RRRRRRRR', energy_model=model, nl_layers=4, nl_hidden=100, #100
             nl_activation='relu', nl_activation_scale='tanh', whiten=X2noise)
# Out:
# W<RRRRRRRR>
# W 76 0 0
# < 76 0 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# > 38 38 0
# WARNING:tensorflow:From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 21-04-19 23:40:11 tensorflow   WARNING  From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# W<RRRRRRRR>
# W 76 0 0
# < 76 0 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# R 38 38 0
# > 38 38 0

# %%
hist_bg1_ML = bg1.train_ML(X1noise, xval=X1val, epochs=100, lr=0.001, batch_size=batchsize_ML, 
                           std=1.0, verbose=0, return_test_energies=False)
hist_bg2_ML = bg2.train_ML(X2noise, xval=X2val, epochs=100, lr=0.001, batch_size=batchsize_ML, 
                           std=1.0, verbose=0, return_test_energies=False)
# Out:
# WARNING:tensorflow:From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 21-04-19 23:40:14 tensorflow   WARNING  From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].plot(hist_bg1_ML[0])
axes[0].plot(hist_bg1_ML[1])
axes[1].plot(hist_bg1_ML[0])
axes[1].plot(hist_bg1_ML[1])
#axes[1].plot(mltrainer2.loss_train)

# %%
_, sample_x_bg1, _, energies_x_bg1, _ = bg1.sample(nsample=10000)
_, sample_x_bg2, _, energies_x_bg2, _ = bg2.sample(nsample=10000)
sample_d1 = model.dimer_distance(sample_x_bg1)
sample_d2 = model.dimer_distance(sample_x_bg2)
plt.hist(sample_d1[sample_d1 < 3], 100, log=True)
plt.hist(sample_d2[sample_d2 < 3], 100, log=True)
plt.xlim(0, 3)
# Out:
# (0, 3)

# %% [markdown]
# **KL training**

# %%
# initial training
Eschedule = [[ 40,  0.0001, 1e6,  1e3,  0.0, 0.0],
             [ 40,  0.0001, 1e6,  300,  0.0, 0.0],
             [ 40,  0.0001, 1e5,  100,  0.0, 0.0],
             [ 40,  0.0001, 5e4,   50,  0.0, 0.0],
             [ 40,  0.0001, 5e4,   20,  0.0, 0.0],
             [100,  0.0001, 5e4,    5,  0.0, 0.0],
             [200,  0.0001, 5e4,    1,  0.0, 0.0]]

# %%
#Eschedule = [[200,  0.0001, 5e4,  0.5,  0.0, 0.0]]

# %%
resdicts1 = []
resdicts2 = []

# %%
for i, s in enumerate(Eschedule):
    print(s)
    flextrainer1 = FlexibleTrainer(bg1, lr=s[1], batch_size=batchsize_KL,
                                   high_energy=s[2], max_energy=1e10, temperature=temperatures_training,
                                   w_ML=s[3], w_KL=1.0, std=1.0)
    resdict = train_and_sample(flextrainer1, model, X1noise, temperatures_analysis, 
                               nsample=500, nepochs_per_iter=3, niter=s[0]//3)
    resdicts1.append(resdict)
# Out:
# [40, 0.0001, 1000000.0, 1000.0, 0.0, 0.0]
# 0 / 13
# WARNING:tensorflow:From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# 21-04-19 23:40:51 tensorflow   WARNING  From /Users/noe/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 0/3 loss 121686.5156 index_layer_3_loss -73.2880 lambda_51_loss 194974.5625
# Epoch 1/3 loss 128249.6172 index_layer_3_loss -67.1543 lambda_51_loss 195403.9062
# Epoch 2/3 loss 120646.1172 index_layer_3_loss -73.4968 lambda_51_loss 194142.9375
# 1 / 13
# Epoch 0/3 loss 124145.3984 index_layer_3_loss -73.6456 lambda_51_loss 197790.9531
# Epoch 1/3 loss 112731.9062 index_layer_3_loss -76.2630 lambda_51_loss 188994.8594
# Epoch 2/3 loss 114835.5000 index_layer_3_loss -72.0225 lambda_51_loss 186857.9844
# 2 / 13
# Epoch 0/3 loss 138473.9062 index_layer_3_loss -41.1502 lambda_51_loss 179624.1094
# Epoch 1/3 loss 117770.6250 index_layer_3_loss -53.8535 lambda_51_loss 171624.1250
# Epoch 2/3 loss 116395.2422 index_layer_3_loss -68.6270 lambda_51_loss 185022.2344
# 3 / 13
# Epoch 0/3 loss 109304.0156 index_layer_3_loss -68.7860 lambda_51_loss 178090.0000
# Epoch 1/3 loss 110273.9844 index_layer_3_loss -65.1118 lambda_51_loss 175385.7969
# Epoch 2/3 loss 88081.9609 index_layer_3_loss -81.4031 lambda_51_loss 169485.0156
# 4 / 13
# Epoch 0/3 loss 86313.3984 index_layer_3_loss -75.8692 lambda_51_loss 162182.5781
# Epoch 1/3 loss 102201.7656 index_layer_3_loss -64.7512 lambda_51_loss 166952.9844
# Epoch 2/3 loss 81038.8516 index_layer_3_loss -72.7557 lambda_51_loss 153794.5781
# 5 / 13
# Epoch 0/3 loss 71871.2109 index_layer_3_loss -74.9024 lambda_51_loss 146773.5938
# Epoch 1/3 loss 79049.5391 index_layer_3_loss -74.2075 lambda_51_loss 153257.0156
# Epoch 2/3 loss 77837.1094 index_layer_3_loss -78.3356 lambda_51_loss 156172.7188
# 6 / 13
# Epoch 0/3 loss 74631.0000 index_layer_3_loss -73.6453 lambda_51_loss 148276.2656
# Epoch 1/3 loss 63745.6328 index_layer_3_loss -72.7637 lambda_51_loss 136509.3125
# Epoch 2/3 loss 67027.9219 index_layer_3_loss -77.7816 lambda_51_loss 144809.5156
# 7 / 13
# Epoch 0/3 loss 64530.8906 index_layer_3_loss -72.9913 lambda_51_loss 137522.1562
# Epoch 1/3 loss 72273.1250 index_layer_3_loss -65.3709 lambda_51_loss 137644.0781
# Epoch 2/3 loss 38331.6797 index_layer_3_loss -89.3192 lambda_51_loss 127650.8359
# 8 / 13
# Epoch 0/3 loss 56055.3359 index_layer_3_loss -68.4165 lambda_51_loss 124471.8359
# Epoch 1/3 loss 57979.0859 index_layer_3_loss -70.4798 lambda_51_loss 128458.9062
# Epoch 2/3 loss 43185.4844 index_layer_3_loss -73.1673 lambda_51_loss 116352.8047
# 9 / 13
# Epoch 0/3 loss 63488.7578 index_layer_3_loss -53.7008 lambda_51_loss 117189.5703
# Epoch 1/3 loss 42872.0703 index_layer_3_loss -76.7579 lambda_51_loss 119629.9844
# Epoch 2/3 loss 42572.4219 index_layer_3_loss -73.3308 lambda_51_loss 115903.2656
# 10 / 13
# Epoch 0/3 loss 42125.8750 index_layer_3_loss -69.9244 lambda_51_loss 112050.3203
# Epoch 1/3 loss 19563.5938 index_layer_3_loss -85.7024 lambda_51_loss 105266.0078
# Epoch 2/3 loss 38094.4766 index_layer_3_loss -70.3776 lambda_51_loss 108472.0859
# 11 / 13
# Epoch 0/3 loss 37590.3750 index_layer_3_loss -75.3142 lambda_51_loss 112904.5547
# Epoch 1/3 loss 35319.4844 index_layer_3_loss -68.3683 lambda_51_loss 103687.7891
# Epoch 2/3 loss 28903.3008 index_layer_3_loss -64.1808 lambda_51_loss 93084.1484
# 12 / 13
# Epoch 0/3 loss 14909.4141 index_layer_3_loss -78.2023 lambda_51_loss 93111.6797
# Epoch 1/3 loss 15520.7734 index_layer_3_loss -80.3024 lambda_51_loss 95823.1562
# Epoch 2/3 loss 17249.6875 index_layer_3_loss -75.4811 lambda_51_loss 92730.7891
# [40, 0.0001, 1000000.0, 300, 0.0, 0.0]
# 0 / 13
# Epoch 0/3 loss 59544.2266 index_layer_3_loss -74.7580 lambda_51_loss 81971.6328
# Epoch 1/3 loss 63515.7031 index_layer_3_loss -71.4696 lambda_51_loss 84956.5938
# Epoch 2/3 loss 57773.4531 index_layer_3_loss -72.2344 lambda_51_loss 79443.7656
# 1 / 13
# Epoch 0/3 loss 54527.5000 index_layer_3_loss -79.1832 lambda_51_loss 78282.4688
# Epoch 1/3 loss 57674.6836 index_layer_3_loss -70.8665 lambda_51_loss 78934.6406
# Epoch 2/3 loss 49311.4648 index_layer_3_loss -77.5237 lambda_51_loss 72568.5625
# 2 / 13
# Epoch 0/3 loss 50730.9180 index_layer_3_loss -65.3142 lambda_51_loss 70325.1875
# Epoch 1/3 loss 41912.0859 index_layer_3_loss -68.5046 lambda_51_loss 62463.4766
# Epoch 2/3 loss 40129.0977 index_layer_3_loss -73.7328 lambda_51_loss 62248.9414
# 3 / 13
# Epoch 0/3 loss 34009.3672 index_layer_3_loss -74.1856 lambda_51_loss 56265.0430
# Epoch 1/3 loss 34345.2148 index_layer_3_loss -59.1237 lambda_51_loss 52082.3125
# Epoch 2/3 loss 29453.3164 index_layer_3_loss -71.2075 lambda_51_loss 50815.5508
# 4 / 13
# Epoch 0/3 loss 29351.3184 index_layer_3_loss -70.0775 lambda_51_loss 50374.5820
# Epoch 1/3 loss 36341.8477 index_layer_3_loss -38.9628 lambda_51_loss 48030.6992
# Epoch 2/3 loss 28863.9121 index_layer_3_loss -64.5155 lambda_51_loss 48218.5586
# 5 / 13
# Epoch 0/3 loss 19616.5605 index_layer_3_loss -73.1596 lambda_51_loss 41564.4531
# Epoch 1/3 loss 19978.0723 index_layer_3_loss -68.1506 lambda_51_loss 40423.2656
# Epoch 2/3 loss 25374.4688 index_layer_3_loss -51.7778 lambda_51_loss 40907.8125
# 6 / 13
# Epoch 0/3 loss 12187.3203 index_layer_3_loss -63.0043 lambda_51_loss 31088.6211
# Epoch 1/3 loss 11228.9268 index_layer_3_loss -54.1979 lambda_51_loss 27488.3008
# Epoch 2/3 loss 12665.3945 index_layer_3_loss -71.0485 lambda_51_loss 33979.9453
# 7 / 13
# Epoch 0/3 loss 5757.0605 index_layer_3_loss -61.4674 lambda_51_loss 24197.2871
# Epoch 1/3 loss 13920.7812 index_layer_3_loss -45.0807 lambda_51_loss 27445.0020
# Epoch 2/3 loss 5498.2578 index_layer_3_loss -54.4723 lambda_51_loss 21839.9336
# 8 / 13
# Epoch 0/3 loss 6412.5840 index_layer_3_loss -61.7628 lambda_51_loss 24941.4219
# Epoch 1/3 loss 3444.8574 index_layer_3_loss -70.7314 lambda_51_loss 24664.2891
# Epoch 2/3 loss 3764.5098 index_layer_3_loss -63.0340 lambda_51_loss 22674.7188
# 9 / 13
# Epoch 0/3 loss 1752.1562 index_layer_3_loss -58.2993 lambda_51_loss 19241.9531
# Epoch 1/3 loss -4443.7051 index_layer_3_loss -75.0353 lambda_51_loss 18066.8984
# Epoch 2/3 loss -6006.6621 index_layer_3_loss -69.7763 lambda_51_loss 14926.2266
# 10 / 13
# Epoch 0/3 loss 7077.6484 index_layer_3_loss -35.0198 lambda_51_loss 17583.5898
# Epoch 1/3 loss -5700.7607 index_layer_3_loss -63.7843 lambda_51_loss 13434.5420
# Epoch 2/3 loss -2625.6172 index_layer_3_loss -72.6393 lambda_51_loss 19166.1855
# 11 / 13
# Epoch 0/3 loss -5534.1377 index_layer_3_loss -64.2371 lambda_51_loss 13736.9893
# Epoch 1/3 loss -5660.2666 index_layer_3_loss -58.8045 lambda_51_loss 11981.0928
# Epoch 2/3 loss -10904.4434 index_layer_3_loss -66.6416 lambda_51_loss 9088.0293
# 12 / 13
# Epoch 0/3 loss -10156.0605 index_layer_3_loss -70.5533 lambda_51_loss 11009.9180
# Epoch 1/3 loss 3745.5039 index_layer_3_loss -17.5578 lambda_51_loss 9012.8467
# Epoch 2/3 loss -3922.5488 index_layer_3_loss -47.1704 lambda_51_loss 10228.5811
# [40, 0.0001, 100000.0, 100, 0.0, 0.0]
# 0 / 13
# Epoch 0/3 loss -3839.7681 index_layer_3_loss -63.9116 lambda_51_loss 2551.3896
# Epoch 1/3 loss -1718.5974 index_layer_3_loss -46.2272 lambda_51_loss 2904.1277
# Epoch 2/3 loss -3355.4558 index_layer_3_loss -61.4429 lambda_51_loss 2788.8367
# 1 / 13
# Epoch 0/3 loss -4098.2432 index_layer_3_loss -62.3055 lambda_51_loss 2132.3018
# Epoch 1/3 loss -5205.4658 index_layer_3_loss -73.0770 lambda_51_loss 2102.2307
# Epoch 2/3 loss -5154.0889 index_layer_3_loss -70.7729 lambda_51_loss 1923.2058
# 2 / 13
# Epoch 0/3 loss -4148.8398 index_layer_3_loss -64.4689 lambda_51_loss 2298.0488
# Epoch 1/3 loss -4219.3545 index_layer_3_loss -62.6884 lambda_51_loss 2049.4802
# Epoch 2/3 loss -4297.5820 index_layer_3_loss -66.7173 lambda_51_loss 2374.1438
# 3 / 13
# Epoch 0/3 loss -4616.5264 index_layer_3_loss -66.0224 lambda_51_loss 1985.7183
# Epoch 1/3 loss -4324.6182 index_layer_3_loss -65.3888 lambda_51_loss 2214.2625
# Epoch 2/3 loss -4876.5186 index_layer_3_loss -69.2295 lambda_51_loss 2046.4283
# 4 / 13
# Epoch 0/3 loss -4987.5703 index_layer_3_loss -68.5507 lambda_51_loss 1867.4948
# Epoch 1/3 loss -5550.6489 index_layer_3_loss -69.7970 lambda_51_loss 1429.0494
# Epoch 2/3 loss -5300.7031 index_layer_3_loss -69.0572 lambda_51_loss 1605.0159
# 5 / 13
# Epoch 0/3 loss -5144.2407 index_layer_3_loss -70.3340 lambda_51_loss 1889.1636
# Epoch 1/3 loss -5389.9795 index_layer_3_loss -70.0589 lambda_51_loss 1615.9083
# Epoch 2/3 loss -5963.1323 index_layer_3_loss -74.8743 lambda_51_loss 1524.3003
# 6 / 13
# Epoch 0/3 loss -5870.9912 index_layer_3_loss -72.1773 lambda_51_loss 1346.7345
# Epoch 1/3 loss -5098.7764 index_layer_3_loss -67.8784 lambda_51_loss 1689.0646
# Epoch 2/3 loss -4442.0181 index_layer_3_loss -60.2758 lambda_51_loss 1585.5581
# 7 / 13
# Epoch 0/3 loss -2655.7507 index_layer_3_loss -40.4587 lambda_51_loss 1390.1218
# Epoch 1/3 loss -6093.8364 index_layer_3_loss -74.7386 lambda_51_loss 1380.0215
# Epoch 2/3 loss -5840.1670 index_layer_3_loss -75.3680 lambda_51_loss 1696.6321
# 8 / 13
# Epoch 0/3 loss -5906.5054 index_layer_3_loss -70.8921 lambda_51_loss 1182.7013
# Epoch 1/3 loss -6175.4956 index_layer_3_loss -74.4693 lambda_51_loss 1271.4390
# Epoch 2/3 loss -5406.8506 index_layer_3_loss -67.0879 lambda_51_loss 1301.9399
# 9 / 13
# Epoch 0/3 loss -5607.8364 index_layer_3_loss -68.2877 lambda_51_loss 1220.9344
# Epoch 1/3 loss -5323.2397 index_layer_3_loss -63.5892 lambda_51_loss 1035.6772
# Epoch 2/3 loss -5738.2812 index_layer_3_loss -68.4187 lambda_51_loss 1103.5917
# 10 / 13
# Epoch 0/3 loss -5721.8545 index_layer_3_loss -68.1475 lambda_51_loss 1092.8940
# Epoch 1/3 loss -6461.9092 index_layer_3_loss -75.6653 lambda_51_loss 1104.6200
# Epoch 2/3 loss -5452.2109 index_layer_3_loss -64.6200 lambda_51_loss 1009.7925
# 11 / 13
# Epoch 0/3 loss -5087.0752 index_layer_3_loss -59.0277 lambda_51_loss 815.6990
# Epoch 1/3 loss -5656.2954 index_layer_3_loss -66.0783 lambda_51_loss 951.5333
# Epoch 2/3 loss -6577.4800 index_layer_3_loss -74.2179 lambda_51_loss 844.3069
# 12 / 13
# Epoch 0/3 loss -5921.5400 index_layer_3_loss -69.0466 lambda_51_loss 983.1200
# Epoch 1/3 loss -5882.3936 index_layer_3_loss -67.1487 lambda_51_loss 832.4761
# Epoch 2/3 loss -5001.8345 index_layer_3_loss -59.4220 lambda_51_loss 940.3643
# [40, 0.0001, 50000.0, 50, 0.0, 0.0]
# 0 / 13
# Epoch 0/3 loss -3093.5093 index_layer_3_loss -75.3299 lambda_51_loss 672.9865
# Epoch 1/3 loss -2794.0613 index_layer_3_loss -69.4322 lambda_51_loss 677.5471
# Epoch 2/3 loss -2911.9004 index_layer_3_loss -70.9035 lambda_51_loss 633.2731
# 1 / 13
# Epoch 0/3 loss -2906.3911 index_layer_3_loss -69.3005 lambda_51_loss 558.6353
# Epoch 1/3 loss -2725.0823 index_layer_3_loss -67.6206 lambda_51_loss 655.9499
# Epoch 2/3 loss -1300.5034 index_layer_3_loss -40.3516 lambda_51_loss 717.0787
# 2 / 13
# Epoch 0/3 loss -2771.3286 index_layer_3_loss -68.4986 lambda_51_loss 653.6028
# Epoch 1/3 loss -2711.0198 index_layer_3_loss -65.2923 lambda_51_loss 553.5961
# Epoch 2/3 loss -2747.1731 index_layer_3_loss -66.4241 lambda_51_loss 574.0333
# 3 / 13
# Epoch 0/3 loss -2940.5664 index_layer_3_loss -69.4955 lambda_51_loss 534.2076
# Epoch 1/3 loss -2752.8650 index_layer_3_loss -68.2577 lambda_51_loss 660.0184
# Epoch 2/3 loss -663.1940 index_layer_3_loss -24.9732 lambda_51_loss 585.4670
# 4 / 13
# Epoch 0/3 loss -1245.1429 index_layer_3_loss -36.3544 lambda_51_loss 572.5753
# Epoch 1/3 loss -2688.6208 index_layer_3_loss -65.8876 lambda_51_loss 605.7605
# Epoch 2/3 loss -2724.9119 index_layer_3_loss -65.3953 lambda_51_loss 544.8533
# 5 / 13
# Epoch 0/3 loss -3048.2981 index_layer_3_loss -71.1776 lambda_51_loss 510.5799
# Epoch 1/3 loss -2887.1001 index_layer_3_loss -70.0965 lambda_51_loss 617.7271
# Epoch 2/3 loss -3115.4724 index_layer_3_loss -71.8232 lambda_51_loss 475.6851
# 6 / 13
# Epoch 0/3 loss -2407.1177 index_layer_3_loss -59.6797 lambda_51_loss 576.8654
# Epoch 1/3 loss -3110.9961 index_layer_3_loss -72.0482 lambda_51_loss 491.4133
# Epoch 2/3 loss -2482.8247 index_layer_3_loss -60.8063 lambda_51_loss 557.4911
# 7 / 13
# Epoch 0/3 loss -3015.0659 index_layer_3_loss -70.3483 lambda_51_loss 502.3470
# Epoch 1/3 loss -2878.1719 index_layer_3_loss -67.5274 lambda_51_loss 498.1980
# Epoch 2/3 loss -3145.0198 index_layer_3_loss -72.7234 lambda_51_loss 491.1511
# 8 / 13
# Epoch 0/3 loss -3008.6704 index_layer_3_loss -68.9496 lambda_51_loss 438.8088
# Epoch 1/3 loss -3308.2310 index_layer_3_loss -74.7220 lambda_51_loss 427.8702
# Epoch 2/3 loss -2777.8828 index_layer_3_loss -64.9810 lambda_51_loss 471.1666
# 9 / 13
# Epoch 0/3 loss -3190.6411 index_layer_3_loss -72.1961 lambda_51_loss 419.1620
# Epoch 1/3 loss -3233.1516 index_layer_3_loss -72.3540 lambda_51_loss 384.5471
# Epoch 2/3 loss -3315.2012 index_layer_3_loss -76.6081 lambda_51_loss 515.2020
# 10 / 13
# Epoch 0/3 loss -3389.7725 index_layer_3_loss -77.7040 lambda_51_loss 495.4277
# Epoch 1/3 loss -3352.3826 index_layer_3_loss -76.1729 lambda_51_loss 456.2643
# Epoch 2/3 loss -3226.1902 index_layer_3_loss -73.7282 lambda_51_loss 460.2195
# 11 / 13
# Epoch 0/3 loss -2705.3164 index_layer_3_loss -65.5194 lambda_51_loss 570.6541
# Epoch 1/3 loss -821.0520 index_layer_3_loss -25.7775 lambda_51_loss 467.8250
# Epoch 2/3 loss -3102.9556 index_layer_3_loss -70.8564 lambda_51_loss 439.8667
# 12 / 13
# Epoch 0/3 loss -2707.7073 index_layer_3_loss -64.4830 lambda_51_loss 516.4432
# Epoch 1/3 loss -3088.6624 index_layer_3_loss -70.7864 lambda_51_loss 450.6587
# Epoch 2/3 loss -2655.8069 index_layer_3_loss -62.1484 lambda_51_loss 451.6140
# [40, 0.0001, 50000.0, 20, 0.0, 0.0]
# 0 / 13
# Epoch 0/3 loss -866.4744 index_layer_3_loss -65.7515 lambda_51_loss 448.5548
# Epoch 1/3 loss -918.8352 index_layer_3_loss -66.3604 lambda_51_loss 408.3720
# Epoch 2/3 loss -993.9071 index_layer_3_loss -69.7564 lambda_51_loss 401.2215
# 1 / 13
# Epoch 0/3 loss -1002.9967 index_layer_3_loss -72.5945 lambda_51_loss 448.8924
# Epoch 1/3 loss -932.1164 index_layer_3_loss -71.2046 lambda_51_loss 491.9752
# Epoch 2/3 loss -300.2764 index_layer_3_loss -39.7589 lambda_51_loss 494.9011
# 2 / 13
# Epoch 0/3 loss -970.0735 index_layer_3_loss -69.3794 lambda_51_loss 417.5137
# Epoch 1/3 loss -1024.6038 index_layer_3_loss -73.6506 lambda_51_loss 448.4091
# Epoch 2/3 loss -1070.8776 index_layer_3_loss -74.7629 lambda_51_loss 424.3800
# 3 / 13
# Epoch 0/3 loss -945.4894 index_layer_3_loss -69.3685 lambda_51_loss 441.8811
# Epoch 1/3 loss -877.7911 index_layer_3_loss -69.0176 lambda_51_loss 502.5612
# Epoch 2/3 loss -950.7139 index_layer_3_loss -66.5771 lambda_51_loss 380.8290
# 4 / 13
# Epoch 0/3 loss -985.1063 index_layer_3_loss -69.5333 lambda_51_loss 405.5594
# Epoch 1/3 loss -897.3485 index_layer_3_loss -67.8280 lambda_51_loss 459.2117
# Epoch 2/3 loss -878.3116 index_layer_3_loss -63.4908 lambda_51_loss 391.5042
# 5 / 13
# Epoch 0/3 loss -993.9895 index_layer_3_loss -68.8037 lambda_51_loss 382.0854
# Epoch 1/3 loss -947.4603 index_layer_3_loss -68.0632 lambda_51_loss 413.8034
# Epoch 2/3 loss -1125.5352 index_layer_3_loss -74.9999 lambda_51_loss 374.4619
# 6 / 13
# Epoch 0/3 loss -1068.7432 index_layer_3_loss -71.4603 lambda_51_loss 360.4628
# Epoch 1/3 loss -915.0289 index_layer_3_loss -63.7854 lambda_51_loss 360.6789
# Epoch 2/3 loss -905.4980 index_layer_3_loss -67.1331 lambda_51_loss 437.1642
# 7 / 13
# Epoch 0/3 loss -997.0975 index_layer_3_loss -68.3713 lambda_51_loss 370.3286
# Epoch 1/3 loss -942.5948 index_layer_3_loss -67.4199 lambda_51_loss 405.8038
# Epoch 2/3 loss -1000.1881 index_layer_3_loss -72.3576 lambda_51_loss 446.9642
# 8 / 13
# Epoch 0/3 loss -1019.6305 index_layer_3_loss -72.2595 lambda_51_loss 425.5588
# Epoch 1/3 loss -942.2178 index_layer_3_loss -67.5731 lambda_51_loss 409.2445
# Epoch 2/3 loss -1008.2628 index_layer_3_loss -72.0861 lambda_51_loss 433.4589
# 9 / 13
# Epoch 0/3 loss -960.3307 index_layer_3_loss -66.9699 lambda_51_loss 379.0672
# Epoch 1/3 loss -849.5845 index_layer_3_loss -64.6702 lambda_51_loss 443.8201
# Epoch 2/3 loss -1081.9753 index_layer_3_loss -72.4233 lambda_51_loss 366.4916
# 10 / 13
# Epoch 0/3 loss -1017.4703 index_layer_3_loss -71.7914 lambda_51_loss 418.3575
# Epoch 1/3 loss -1009.4328 index_layer_3_loss -67.6124 lambda_51_loss 342.8150
# Epoch 2/3 loss -861.7675 index_layer_3_loss -62.3891 lambda_51_loss 386.0145
# 11 / 13
# Epoch 0/3 loss -1055.5750 index_layer_3_loss -71.2123 lambda_51_loss 368.6717
# Epoch 1/3 loss -961.8289 index_layer_3_loss -66.1375 lambda_51_loss 360.9214
# Epoch 2/3 loss -1026.5546 index_layer_3_loss -69.5285 lambda_51_loss 364.0164
# 12 / 13
# Epoch 0/3 loss -956.2526 index_layer_3_loss -65.8051 lambda_51_loss 359.8503
# Epoch 1/3 loss -1054.5181 index_layer_3_loss -70.0726 lambda_51_loss 346.9333
# Epoch 2/3 loss -1107.5161 index_layer_3_loss -73.3462 lambda_51_loss 359.4072
# [100, 0.0001, 50000.0, 5, 0.0, 0.0]
# 0 / 33
# Epoch 0/3 loss -42.5267 index_layer_3_loss -73.4903 lambda_51_loss 324.9248
# Epoch 1/3 loss -26.2639 index_layer_3_loss -69.2196 lambda_51_loss 319.8344
# Epoch 2/3 loss -43.1565 index_layer_3_loss -71.5549 lambda_51_loss 314.6180
# 1 / 33
# Epoch 0/3 loss -52.9362 index_layer_3_loss -72.1440 lambda_51_loss 307.7838
# Epoch 1/3 loss -11.2583 index_layer_3_loss -69.5412 lambda_51_loss 336.4478
# Epoch 2/3 loss -27.7892 index_layer_3_loss -67.6743 lambda_51_loss 310.5822
# 2 / 33
# Epoch 0/3 loss -42.6957 index_layer_3_loss -72.9474 lambda_51_loss 322.0411
# Epoch 1/3 loss 142.0096 index_layer_3_loss -32.3781 lambda_51_loss 303.9001
# Epoch 2/3 loss 194.0496 index_layer_3_loss -20.5701 lambda_51_loss 296.9001
# 3 / 33
# Epoch 0/3 loss -82.0666 index_layer_3_loss -75.6867 lambda_51_loss 296.3671
# Epoch 1/3 loss 90.3500 index_layer_3_loss -43.6493 lambda_51_loss 308.5965
# Epoch 2/3 loss -55.5550 index_layer_3_loss -71.4112 lambda_51_loss 301.5008
# 4 / 33
# Epoch 0/3 loss -79.7429 index_layer_3_loss -77.2135 lambda_51_loss 306.3248
# Epoch 1/3 loss -56.0516 index_layer_3_loss -72.6154 lambda_51_loss 307.0255
# Epoch 2/3 loss -39.7641 index_layer_3_loss -69.6660 lambda_51_loss 308.5658
# 5 / 33
# Epoch 0/3 loss 11.1151 index_layer_3_loss -59.5432 lambda_51_loss 308.8311
# Epoch 1/3 loss 0.4106 index_layer_3_loss -59.5967 lambda_51_loss 298.3943
# Epoch 2/3 loss 122.9375 index_layer_3_loss -36.2213 lambda_51_loss 304.0440
# 6 / 33
# Epoch 0/3 loss 273.6548 index_layer_3_loss -10.0755 lambda_51_loss 324.0323
# Epoch 1/3 loss 12.9495 index_layer_3_loss -57.2562 lambda_51_loss 299.2308
# Epoch 2/3 loss -2.3797 index_layer_3_loss -60.6684 lambda_51_loss 300.9620
# 7 / 33
# Epoch 0/3 loss -40.9940 index_layer_3_loss -71.6680 lambda_51_loss 317.3458
# Epoch 1/3 loss -49.6302 index_layer_3_loss -70.4868 lambda_51_loss 302.8040
# Epoch 2/3 loss -24.5475 index_layer_3_loss -68.6826 lambda_51_loss 318.8655
# 8 / 33
# Epoch 0/3 loss -21.4997 index_layer_3_loss -70.2791 lambda_51_loss 329.8959
# Epoch 1/3 loss 209.4046 index_layer_3_loss -28.9769 lambda_51_loss 354.2888
# Epoch 2/3 loss 157.8115 index_layer_3_loss -32.2907 lambda_51_loss 319.2650
# 9 / 33
# Epoch 0/3 loss -34.9422 index_layer_3_loss -72.2048 lambda_51_loss 326.0818
# Epoch 1/3 loss -56.5226 index_layer_3_loss -71.9920 lambda_51_loss 303.4372
# Epoch 2/3 loss 2.5053 index_layer_3_loss -74.2071 lambda_51_loss 373.5410
# 10 / 33
# Epoch 0/3 loss -47.7223 index_layer_3_loss -70.0394 lambda_51_loss 302.4749
# Epoch 1/3 loss -0.2003 index_layer_3_loss -64.6377 lambda_51_loss 322.9880
# Epoch 2/3 loss -17.1896 index_layer_3_loss -69.5587 lambda_51_loss 330.6039
# 11 / 33
# Epoch 0/3 loss -7.9824 index_layer_3_loss -62.7998 lambda_51_loss 306.0167
# Epoch 1/3 loss 20.6761 index_layer_3_loss -59.0847 lambda_51_loss 316.0993
# Epoch 2/3 loss -25.6046 index_layer_3_loss -68.4377 lambda_51_loss 316.5840
# 12 / 33
# Epoch 0/3 loss -11.9791 index_layer_3_loss -66.8053 lambda_51_loss 322.0472
# Epoch 1/3 loss -32.2057 index_layer_3_loss -69.7236 lambda_51_loss 316.4124
# Epoch 2/3 loss -17.1372 index_layer_3_loss -68.0483 lambda_51_loss 323.1042
# 13 / 33
# Epoch 0/3 loss -20.6804 index_layer_3_loss -65.6626 lambda_51_loss 307.6326
# Epoch 1/3 loss -40.7914 index_layer_3_loss -71.1591 lambda_51_loss 315.0042
# Epoch 2/3 loss 4.4535 index_layer_3_loss -62.8908 lambda_51_loss 318.9073
# 14 / 33
# Epoch 0/3 loss 34.2191 index_layer_3_loss -59.4582 lambda_51_loss 331.5100
# Epoch 1/3 loss -47.0162 index_layer_3_loss -69.9154 lambda_51_loss 302.5609
# Epoch 2/3 loss -12.2909 index_layer_3_loss -64.5590 lambda_51_loss 310.5042
# 15 / 33
# Epoch 0/3 loss -49.3739 index_layer_3_loss -69.9386 lambda_51_loss 300.3190
# Epoch 1/3 loss -40.9096 index_layer_3_loss -70.7951 lambda_51_loss 313.0660
# Epoch 2/3 loss 14.7614 index_layer_3_loss -66.6360 lambda_51_loss 347.9413
# 16 / 33
# Epoch 0/3 loss -15.8392 index_layer_3_loss -68.1276 lambda_51_loss 324.7986
# Epoch 1/3 loss 38.0482 index_layer_3_loss -64.1087 lambda_51_loss 358.5918
# Epoch 2/3 loss -36.1491 index_layer_3_loss -68.8753 lambda_51_loss 308.2271
# 17 / 33
# Epoch 0/3 loss 48.8758 index_layer_3_loss -60.5606 lambda_51_loss 351.6788
# Epoch 1/3 loss -18.3558 index_layer_3_loss -64.4605 lambda_51_loss 303.9468
# Epoch 2/3 loss -22.3976 index_layer_3_loss -64.5028 lambda_51_loss 300.1162
# 18 / 33
# Epoch 0/3 loss -25.6031 index_layer_3_loss -65.8460 lambda_51_loss 303.6269
# Epoch 1/3 loss -55.6450 index_layer_3_loss -71.7134 lambda_51_loss 302.9222
# Epoch 2/3 loss -30.9358 index_layer_3_loss -66.2724 lambda_51_loss 300.4263
# 19 / 33
# Epoch 0/3 loss -27.6104 index_layer_3_loss -65.9103 lambda_51_loss 301.9409
# Epoch 1/3 loss -60.6750 index_layer_3_loss -73.0256 lambda_51_loss 304.4532
# Epoch 2/3 loss -55.9221 index_layer_3_loss -70.4704 lambda_51_loss 296.4296
# 20 / 33
# Epoch 0/3 loss -54.8895 index_layer_3_loss -70.5931 lambda_51_loss 298.0760
# Epoch 1/3 loss -1.3152 index_layer_3_loss -68.5611 lambda_51_loss 341.4905
# Epoch 2/3 loss -47.9240 index_layer_3_loss -71.6557 lambda_51_loss 310.3545
# 21 / 33
# Epoch 0/3 loss -69.5567 index_layer_3_loss -73.4142 lambda_51_loss 297.5142
# Epoch 1/3 loss -11.7477 index_layer_3_loss -69.6348 lambda_51_loss 336.4261
# Epoch 2/3 loss -24.6279 index_layer_3_loss -69.1486 lambda_51_loss 321.1153
# 22 / 33
# Epoch 0/3 loss -55.9262 index_layer_3_loss -71.1136 lambda_51_loss 299.6420
# Epoch 1/3 loss -43.6430 index_layer_3_loss -69.1061 lambda_51_loss 301.8874
# Epoch 2/3 loss -8.0494 index_layer_3_loss -61.1216 lambda_51_loss 297.5587
# 23 / 33
# Epoch 0/3 loss -28.1500 index_layer_3_loss -65.8132 lambda_51_loss 300.9161
# Epoch 1/3 loss -59.9424 index_layer_3_loss -72.0046 lambda_51_loss 300.0807
# Epoch 2/3 loss -64.8259 index_layer_3_loss -72.5995 lambda_51_loss 298.1715
# 24 / 33
# Epoch 0/3 loss -47.1368 index_layer_3_loss -69.7273 lambda_51_loss 301.4999
# Epoch 1/3 loss -47.7224 index_layer_3_loss -69.3806 lambda_51_loss 299.1807
# Epoch 2/3 loss -45.5466 index_layer_3_loss -69.7481 lambda_51_loss 303.1937
# 25 / 33
# Epoch 0/3 loss 17.9622 index_layer_3_loss -57.5326 lambda_51_loss 305.6251
# Epoch 1/3 loss -67.4002 index_layer_3_loss -72.4687 lambda_51_loss 294.9433
# Epoch 2/3 loss -37.5984 index_layer_3_loss -69.7648 lambda_51_loss 311.2256
# 26 / 33
# Epoch 0/3 loss -50.8978 index_layer_3_loss -68.7186 lambda_51_loss 292.6951
# Epoch 1/3 loss -36.6325 index_layer_3_loss -66.5703 lambda_51_loss 296.2189
# Epoch 2/3 loss -36.1486 index_layer_3_loss -71.7909 lambda_51_loss 322.8058
# 27 / 33
# Epoch 0/3 loss -32.2242 index_layer_3_loss -67.2092 lambda_51_loss 303.8220
# Epoch 1/3 loss -5.7155 index_layer_3_loss -68.3148 lambda_51_loss 335.8584
# Epoch 2/3 loss -59.4549 index_layer_3_loss -71.7161 lambda_51_loss 299.1258
# 28 / 33
# Epoch 0/3 loss -57.5764 index_layer_3_loss -71.6015 lambda_51_loss 300.4310
# Epoch 1/3 loss -1.8423 index_layer_3_loss -59.6351 lambda_51_loss 296.3329
# Epoch 2/3 loss -43.4689 index_layer_3_loss -70.6029 lambda_51_loss 309.5454
# 29 / 33
# Epoch 0/3 loss -65.3878 index_layer_3_loss -72.4302 lambda_51_loss 296.7633
# Epoch 1/3 loss -29.8123 index_layer_3_loss -70.8240 lambda_51_loss 324.3077
# Epoch 2/3 loss -44.9263 index_layer_3_loss -68.3363 lambda_51_loss 296.7549
# 30 / 33
# Epoch 0/3 loss -54.3659 index_layer_3_loss -71.3759 lambda_51_loss 302.5136
# Epoch 1/3 loss -68.0600 index_layer_3_loss -72.8023 lambda_51_loss 295.9513
# Epoch 2/3 loss -40.3832 index_layer_3_loss -66.1519 lambda_51_loss 290.3763
# 31 / 33
# Epoch 0/3 loss -39.1765 index_layer_3_loss -73.0437 lambda_51_loss 326.0417
# Epoch 1/3 loss -52.7484 index_layer_3_loss -72.3788 lambda_51_loss 309.1457
# Epoch 2/3 loss -49.3619 index_layer_3_loss -70.9551 lambda_51_loss 305.4136
# 32 / 33
# Epoch 0/3 loss -44.1060 index_layer_3_loss -67.6702 lambda_51_loss 294.2449
# Epoch 1/3 loss -47.9754 index_layer_3_loss -68.7151 lambda_51_loss 295.6000
# Epoch 2/3 loss -51.6035 index_layer_3_loss -70.0965 lambda_51_loss 298.8793
# [200, 0.0001, 50000.0, 1, 0.0, 0.0]
# 0 / 66
# Epoch 0/3 loss 219.4652 index_layer_3_loss -74.8153 lambda_51_loss 294.2805
# Epoch 1/3 loss 256.3416 index_layer_3_loss -68.7608 lambda_51_loss 325.1024
# Epoch 2/3 loss 257.0568 index_layer_3_loss -71.2375 lambda_51_loss 328.2943
# 1 / 66
# Epoch 0/3 loss 219.0661 index_layer_3_loss -71.6737 lambda_51_loss 290.7397
# Epoch 1/3 loss 228.1543 index_layer_3_loss -65.5748 lambda_51_loss 293.7291
# Epoch 2/3 loss 224.0832 index_layer_3_loss -65.0549 lambda_51_loss 289.1381
# 2 / 66
# Epoch 0/3 loss 224.8451 index_layer_3_loss -63.0177 lambda_51_loss 287.8628
# Epoch 1/3 loss 237.4631 index_layer_3_loss -58.4634 lambda_51_loss 295.9265
# Epoch 2/3 loss 290.3943 index_layer_3_loss -7.8944 lambda_51_loss 298.2887
# 3 / 66
# Epoch 0/3 loss 238.3808 index_layer_3_loss -74.4853 lambda_51_loss 312.8661
# Epoch 1/3 loss 225.9456 index_layer_3_loss -61.9421 lambda_51_loss 287.8877
# Epoch 2/3 loss 213.5563 index_layer_3_loss -75.7047 lambda_51_loss 289.2610
# 4 / 66
# Epoch 0/3 loss 227.5468 index_layer_3_loss -65.6555 lambda_51_loss 293.2023
# Epoch 1/3 loss 226.3922 index_layer_3_loss -69.1541 lambda_51_loss 295.5463
# Epoch 2/3 loss 217.5544 index_layer_3_loss -70.4315 lambda_51_loss 287.9859
# 5 / 66
# Epoch 0/3 loss 223.5235 index_layer_3_loss -63.2319 lambda_51_loss 286.7554
# Epoch 1/3 loss 211.5476 index_layer_3_loss -76.7311 lambda_51_loss 288.2787
# Epoch 2/3 loss 223.0735 index_layer_3_loss -62.7322 lambda_51_loss 285.8057
# 6 / 66
# Epoch 0/3 loss 216.4385 index_layer_3_loss -69.6777 lambda_51_loss 286.1162
# Epoch 1/3 loss 216.9159 index_layer_3_loss -72.0718 lambda_51_loss 288.9877
# Epoch 2/3 loss 217.6488 index_layer_3_loss -68.1504 lambda_51_loss 285.7992
# 7 / 66
# Epoch 0/3 loss 214.3609 index_layer_3_loss -70.7809 lambda_51_loss 285.1418
# Epoch 1/3 loss 217.8905 index_layer_3_loss -66.3904 lambda_51_loss 284.2810
# Epoch 2/3 loss 223.7144 index_layer_3_loss -61.4747 lambda_51_loss 285.1891
# 8 / 66
# Epoch 0/3 loss 218.0198 index_layer_3_loss -66.7066 lambda_51_loss 284.7264
# Epoch 1/3 loss 214.8822 index_layer_3_loss -70.0166 lambda_51_loss 284.8989
# Epoch 2/3 loss 220.1149 index_layer_3_loss -66.1900 lambda_51_loss 286.3049
# 9 / 66
# Epoch 0/3 loss 215.2726 index_layer_3_loss -68.6988 lambda_51_loss 283.9715
# Epoch 1/3 loss 219.6797 index_layer_3_loss -65.0491 lambda_51_loss 284.7288
# Epoch 2/3 loss 217.6712 index_layer_3_loss -68.5059 lambda_51_loss 286.1771
# 10 / 66
# Epoch 0/3 loss 223.3236 index_layer_3_loss -61.4928 lambda_51_loss 284.8164
# Epoch 1/3 loss 250.3783 index_layer_3_loss -33.9352 lambda_51_loss 284.3135
# Epoch 2/3 loss 245.1107 index_layer_3_loss -64.6755 lambda_51_loss 309.7862
# 11 / 66
# Epoch 0/3 loss 219.5007 index_layer_3_loss -65.3646 lambda_51_loss 284.8652
# Epoch 1/3 loss 230.9877 index_layer_3_loss -67.9115 lambda_51_loss 298.8992
# Epoch 2/3 loss 216.8822 index_layer_3_loss -71.1589 lambda_51_loss 288.0411
# 12 / 66
# Epoch 0/3 loss 213.7308 index_layer_3_loss -69.7665 lambda_51_loss 283.4974
# Epoch 1/3 loss 210.1807 index_layer_3_loss -73.0943 lambda_51_loss 283.2751
# Epoch 2/3 loss 215.1555 index_layer_3_loss -71.2431 lambda_51_loss 286.3987
# 13 / 66
# Epoch 0/3 loss 215.0962 index_layer_3_loss -70.1859 lambda_51_loss 285.2820
# Epoch 1/3 loss 215.3683 index_layer_3_loss -66.6774 lambda_51_loss 282.0457
# Epoch 2/3 loss 240.2316 index_layer_3_loss -60.9016 lambda_51_loss 301.1332
# 14 / 66
# Epoch 0/3 loss 213.9691 index_layer_3_loss -67.3687 lambda_51_loss 281.3379
# Epoch 1/3 loss 220.5692 index_layer_3_loss -69.5194 lambda_51_loss 290.0886
# Epoch 2/3 loss 214.3209 index_layer_3_loss -70.2616 lambda_51_loss 284.5825
# 15 / 66
# Epoch 0/3 loss 233.1066 index_layer_3_loss -70.2098 lambda_51_loss 303.3164
# Epoch 1/3 loss 214.4876 index_layer_3_loss -68.3995 lambda_51_loss 282.8871
# Epoch 2/3 loss 220.0969 index_layer_3_loss -64.9109 lambda_51_loss 285.0078
# 16 / 66
# Epoch 0/3 loss 216.7790 index_layer_3_loss -65.1479 lambda_51_loss 281.9268
# Epoch 1/3 loss 209.1542 index_layer_3_loss -72.1198 lambda_51_loss 281.2740
# Epoch 2/3 loss 211.4546 index_layer_3_loss -70.4327 lambda_51_loss 281.8873
# 17 / 66
# Epoch 0/3 loss 238.6990 index_layer_3_loss -61.6398 lambda_51_loss 300.3388
# Epoch 1/3 loss 212.9994 index_layer_3_loss -70.2245 lambda_51_loss 283.2239
# Epoch 2/3 loss 212.8484 index_layer_3_loss -69.7901 lambda_51_loss 282.6385
# 18 / 66
# Epoch 0/3 loss 213.9021 index_layer_3_loss -66.8871 lambda_51_loss 280.7892
# Epoch 1/3 loss 217.1632 index_layer_3_loss -71.2207 lambda_51_loss 288.3840
# Epoch 2/3 loss 215.8707 index_layer_3_loss -64.4541 lambda_51_loss 280.3248
# 19 / 66
# Epoch 0/3 loss 208.2645 index_layer_3_loss -73.1481 lambda_51_loss 281.4127
# Epoch 1/3 loss 213.8165 index_layer_3_loss -69.2562 lambda_51_loss 283.0727
# Epoch 2/3 loss 217.3350 index_layer_3_loss -66.2547 lambda_51_loss 283.5897
# 20 / 66
# Epoch 0/3 loss 214.6124 index_layer_3_loss -67.5547 lambda_51_loss 282.1671
# Epoch 1/3 loss 215.2436 index_layer_3_loss -67.5425 lambda_51_loss 282.7861
# Epoch 2/3 loss 215.2582 index_layer_3_loss -65.6984 lambda_51_loss 280.9566
# 21 / 66
# Epoch 0/3 loss 214.4094 index_layer_3_loss -69.2482 lambda_51_loss 283.6576
# Epoch 1/3 loss 216.0975 index_layer_3_loss -67.4959 lambda_51_loss 283.5934
# Epoch 2/3 loss 213.3634 index_layer_3_loss -69.1820 lambda_51_loss 282.5454
# 22 / 66
# Epoch 0/3 loss 211.2808 index_layer_3_loss -68.9968 lambda_51_loss 280.2776
# Epoch 1/3 loss 210.8658 index_layer_3_loss -68.8960 lambda_51_loss 279.7617
# Epoch 2/3 loss 210.4284 index_layer_3_loss -70.5921 lambda_51_loss 281.0205
# 23 / 66
# Epoch 0/3 loss 210.5675 index_layer_3_loss -71.1469 lambda_51_loss 281.7144
# Epoch 1/3 loss 210.1101 index_layer_3_loss -70.4372 lambda_51_loss 280.5473
# Epoch 2/3 loss 211.3392 index_layer_3_loss -68.3087 lambda_51_loss 279.6479
# 24 / 66
# Epoch 0/3 loss 214.2049 index_layer_3_loss -67.3359 lambda_51_loss 281.5408
# Epoch 1/3 loss 257.6152 index_layer_3_loss -69.4647 lambda_51_loss 327.0798
# Epoch 2/3 loss 230.0246 index_layer_3_loss -66.9888 lambda_51_loss 297.0134
# 25 / 66
# Epoch 0/3 loss 218.6311 index_layer_3_loss -64.1172 lambda_51_loss 282.7483
# Epoch 1/3 loss 214.1044 index_layer_3_loss -70.2082 lambda_51_loss 284.3125
# Epoch 2/3 loss 205.6264 index_layer_3_loss -74.9529 lambda_51_loss 280.5793
# 26 / 66
# Epoch 0/3 loss 212.5065 index_layer_3_loss -68.3796 lambda_51_loss 280.8861
# Epoch 1/3 loss 208.2784 index_layer_3_loss -71.9863 lambda_51_loss 280.2648
# Epoch 2/3 loss 211.0669 index_layer_3_loss -69.6155 lambda_51_loss 280.6824
# 27 / 66
# Epoch 0/3 loss 221.2349 index_layer_3_loss -67.9051 lambda_51_loss 289.1400
# Epoch 1/3 loss 253.9996 index_layer_3_loss -27.9618 lambda_51_loss 281.9614
# Epoch 2/3 loss 210.3643 index_layer_3_loss -71.8119 lambda_51_loss 282.1762
# 28 / 66
# Epoch 0/3 loss 233.1594 index_layer_3_loss -48.1591 lambda_51_loss 281.3185
# Epoch 1/3 loss 207.8591 index_layer_3_loss -72.0595 lambda_51_loss 279.9186
# Epoch 2/3 loss 211.3736 index_layer_3_loss -68.1895 lambda_51_loss 279.5630
# 29 / 66
# Epoch 0/3 loss 235.2272 index_layer_3_loss -45.3727 lambda_51_loss 280.5999
# Epoch 1/3 loss 206.4507 index_layer_3_loss -74.3944 lambda_51_loss 280.8451
# Epoch 2/3 loss 209.9623 index_layer_3_loss -71.0613 lambda_51_loss 281.0236
# 30 / 66
# Epoch 0/3 loss 227.8124 index_layer_3_loss -68.3208 lambda_51_loss 296.1333
# Epoch 1/3 loss 213.8051 index_layer_3_loss -66.2367 lambda_51_loss 280.0417
# Epoch 2/3 loss 228.8555 index_layer_3_loss -71.9733 lambda_51_loss 300.8288
# 31 / 66
# Epoch 0/3 loss 211.8347 index_layer_3_loss -69.0785 lambda_51_loss 280.9132
# Epoch 1/3 loss 228.6144 index_layer_3_loss -71.5285 lambda_51_loss 300.1429
# Epoch 2/3 loss 213.7611 index_layer_3_loss -67.5448 lambda_51_loss 281.3059
# 32 / 66
# Epoch 0/3 loss 208.6945 index_layer_3_loss -72.4428 lambda_51_loss 281.1373
# Epoch 1/3 loss 230.9151 index_layer_3_loss -67.6757 lambda_51_loss 298.5909
# Epoch 2/3 loss 213.8504 index_layer_3_loss -70.3520 lambda_51_loss 284.2024
# 33 / 66
# Epoch 0/3 loss 215.7930 index_layer_3_loss -65.1505 lambda_51_loss 280.9435
# Epoch 1/3 loss 208.5975 index_layer_3_loss -71.5138 lambda_51_loss 280.1113
# Epoch 2/3 loss 224.5537 index_layer_3_loss -66.4437 lambda_51_loss 290.9974
# 34 / 66
# Epoch 0/3 loss 208.5181 index_layer_3_loss -73.8248 lambda_51_loss 282.3428
# Epoch 1/3 loss 209.9828 index_layer_3_loss -70.6462 lambda_51_loss 280.6291
# Epoch 2/3 loss 208.2794 index_layer_3_loss -72.4636 lambda_51_loss 280.7431
# 35 / 66
# Epoch 0/3 loss 228.9754 index_layer_3_loss -68.4155 lambda_51_loss 297.3908
# Epoch 1/3 loss 213.8026 index_layer_3_loss -68.0638 lambda_51_loss 281.8664
# Epoch 2/3 loss 214.8579 index_layer_3_loss -71.8160 lambda_51_loss 286.6739
# 36 / 66
# Epoch 0/3 loss 277.1863 index_layer_3_loss -5.5732 lambda_51_loss 282.7596
# Epoch 1/3 loss 206.1434 index_layer_3_loss -75.3280 lambda_51_loss 281.4714
# Epoch 2/3 loss 217.1743 index_layer_3_loss -68.7129 lambda_51_loss 285.8872
# 37 / 66
# Epoch 0/3 loss 217.7737 index_layer_3_loss -64.9881 lambda_51_loss 282.7618
# Epoch 1/3 loss 209.2866 index_layer_3_loss -71.3995 lambda_51_loss 280.6861
# Epoch 2/3 loss 213.4191 index_layer_3_loss -67.4303 lambda_51_loss 280.8495
# 38 / 66
# Epoch 0/3 loss 212.1033 index_layer_3_loss -68.6450 lambda_51_loss 280.7484
# Epoch 1/3 loss 204.7790 index_layer_3_loss -76.4020 lambda_51_loss 281.1810
# Epoch 2/3 loss 218.3594 index_layer_3_loss -62.9308 lambda_51_loss 281.2902
# 39 / 66
# Epoch 0/3 loss 209.4932 index_layer_3_loss -71.0778 lambda_51_loss 280.5710
# Epoch 1/3 loss 211.1796 index_layer_3_loss -69.0816 lambda_51_loss 280.2612
# Epoch 2/3 loss 210.2569 index_layer_3_loss -71.1356 lambda_51_loss 281.3925
# 40 / 66
# Epoch 0/3 loss 216.9103 index_layer_3_loss -63.9690 lambda_51_loss 280.8793
# Epoch 1/3 loss 220.5332 index_layer_3_loss -70.1445 lambda_51_loss 290.6777
# Epoch 2/3 loss 210.8519 index_layer_3_loss -70.4792 lambda_51_loss 281.3311
# 41 / 66
# Epoch 0/3 loss 212.8678 index_layer_3_loss -70.2266 lambda_51_loss 283.0945
# Epoch 1/3 loss 216.9180 index_layer_3_loss -63.4047 lambda_51_loss 280.3227
# Epoch 2/3 loss 209.4671 index_layer_3_loss -73.1455 lambda_51_loss 282.6126
# 42 / 66
# Epoch 0/3 loss 228.1326 index_layer_3_loss -67.2868 lambda_51_loss 295.4194
# Epoch 1/3 loss 208.7583 index_layer_3_loss -72.7590 lambda_51_loss 281.5173
# Epoch 2/3 loss 211.4537 index_layer_3_loss -73.1934 lambda_51_loss 284.6472
# 43 / 66
# Epoch 0/3 loss 210.6485 index_layer_3_loss -69.1648 lambda_51_loss 279.8133
# Epoch 1/3 loss 229.7076 index_layer_3_loss -65.9086 lambda_51_loss 295.6162
# Epoch 2/3 loss 211.6174 index_layer_3_loss -69.3431 lambda_51_loss 280.9605
# 44 / 66
# Epoch 0/3 loss 208.9445 index_layer_3_loss -71.1367 lambda_51_loss 280.0812
# Epoch 1/3 loss 207.4528 index_layer_3_loss -75.9617 lambda_51_loss 283.4145
# Epoch 2/3 loss 216.1040 index_layer_3_loss -67.3402 lambda_51_loss 283.4442
# 45 / 66
# Epoch 0/3 loss 206.5084 index_layer_3_loss -73.6697 lambda_51_loss 280.1781
# Epoch 1/3 loss 214.1085 index_layer_3_loss -66.1928 lambda_51_loss 280.3013
# Epoch 2/3 loss 213.8842 index_layer_3_loss -66.2314 lambda_51_loss 280.1155
# 46 / 66
# Epoch 0/3 loss 215.4177 index_layer_3_loss -73.0399 lambda_51_loss 288.4576
# Epoch 1/3 loss 208.4369 index_layer_3_loss -72.5304 lambda_51_loss 280.9673
# Epoch 2/3 loss 210.5764 index_layer_3_loss -69.6923 lambda_51_loss 280.2686
# 47 / 66
# Epoch 0/3 loss 209.6653 index_layer_3_loss -69.8257 lambda_51_loss 279.4910
# Epoch 1/3 loss 206.1866 index_layer_3_loss -73.5227 lambda_51_loss 279.7093
# Epoch 2/3 loss 212.9241 index_layer_3_loss -68.1265 lambda_51_loss 281.0507
# 48 / 66
# Epoch 0/3 loss 213.4108 index_layer_3_loss -70.3456 lambda_51_loss 283.7564
# Epoch 1/3 loss 212.0389 index_layer_3_loss -68.6060 lambda_51_loss 280.6449
# Epoch 2/3 loss 210.9452 index_layer_3_loss -68.5941 lambda_51_loss 279.5393
# 49 / 66
# Epoch 0/3 loss 212.4473 index_layer_3_loss -69.6277 lambda_51_loss 282.0750
# Epoch 1/3 loss 207.6760 index_layer_3_loss -72.5481 lambda_51_loss 280.2241
# Epoch 2/3 loss 214.3045 index_layer_3_loss -69.4079 lambda_51_loss 283.7124
# 50 / 66
# Epoch 0/3 loss 206.3439 index_layer_3_loss -73.2387 lambda_51_loss 279.5826
# Epoch 1/3 loss 218.2146 index_layer_3_loss -62.9451 lambda_51_loss 281.1596
# Epoch 2/3 loss 205.1214 index_layer_3_loss -74.8466 lambda_51_loss 279.9680
# 51 / 66
# Epoch 0/3 loss 208.8768 index_layer_3_loss -72.0661 lambda_51_loss 280.9429
# Epoch 1/3 loss 212.3050 index_layer_3_loss -67.5815 lambda_51_loss 279.8865
# Epoch 2/3 loss 206.3567 index_layer_3_loss -72.8624 lambda_51_loss 279.2191
# 52 / 66
# Epoch 0/3 loss 209.8178 index_layer_3_loss -69.2445 lambda_51_loss 279.0623
# Epoch 1/3 loss 209.6684 index_layer_3_loss -69.7816 lambda_51_loss 279.4500
# Epoch 2/3 loss 209.9131 index_layer_3_loss -69.6766 lambda_51_loss 279.5898
# 53 / 66
# Epoch 0/3 loss 208.3628 index_layer_3_loss -72.6492 lambda_51_loss 281.0121
# Epoch 1/3 loss 214.2923 index_layer_3_loss -66.4272 lambda_51_loss 280.7195
# Epoch 2/3 loss 210.8795 index_layer_3_loss -69.3668 lambda_51_loss 280.2463
# 54 / 66
# Epoch 0/3 loss 207.4579 index_layer_3_loss -70.3089 lambda_51_loss 277.7667
# Epoch 1/3 loss 207.7129 index_layer_3_loss -72.6443 lambda_51_loss 280.3571
# Epoch 2/3 loss 208.0990 index_layer_3_loss -70.1520 lambda_51_loss 278.2510
# 55 / 66
# Epoch 0/3 loss 207.1411 index_layer_3_loss -71.5829 lambda_51_loss 278.7240
# Epoch 1/3 loss 227.0191 index_layer_3_loss -53.6224 lambda_51_loss 280.6415
# Epoch 2/3 loss 217.2563 index_layer_3_loss -67.0662 lambda_51_loss 284.3224
# 56 / 66
# Epoch 0/3 loss 205.8661 index_layer_3_loss -73.1319 lambda_51_loss 278.9980
# Epoch 1/3 loss 208.9132 index_layer_3_loss -70.2962 lambda_51_loss 279.2094
# Epoch 2/3 loss 205.6349 index_layer_3_loss -72.4190 lambda_51_loss 278.0539
# 57 / 66
# Epoch 0/3 loss 210.8386 index_layer_3_loss -68.1003 lambda_51_loss 278.9388
# Epoch 1/3 loss 208.3862 index_layer_3_loss -71.3145 lambda_51_loss 279.7007
# Epoch 2/3 loss 209.3327 index_layer_3_loss -70.6387 lambda_51_loss 279.9714
# 58 / 66
# Epoch 0/3 loss 218.4767 index_layer_3_loss -77.6024 lambda_51_loss 296.0790
# Epoch 1/3 loss 221.6501 index_layer_3_loss -72.6808 lambda_51_loss 294.3308
# Epoch 2/3 loss 205.8842 index_layer_3_loss -72.9579 lambda_51_loss 278.8421
# 59 / 66
# Epoch 0/3 loss 204.9810 index_layer_3_loss -73.8877 lambda_51_loss 278.8687
# Epoch 1/3 loss 206.8769 index_layer_3_loss -72.6386 lambda_51_loss 279.5154
# Epoch 2/3 loss 209.4804 index_layer_3_loss -68.7629 lambda_51_loss 278.2433
# 60 / 66
# Epoch 0/3 loss 218.7468 index_layer_3_loss -60.9290 lambda_51_loss 279.6758
# Epoch 1/3 loss 250.6604 index_layer_3_loss -28.6056 lambda_51_loss 279.2660
# Epoch 2/3 loss 207.4603 index_layer_3_loss -70.0462 lambda_51_loss 277.5065
# 61 / 66
# Epoch 0/3 loss 219.5142 index_layer_3_loss -67.1826 lambda_51_loss 286.6968
# Epoch 1/3 loss 226.1426 index_layer_3_loss -68.3504 lambda_51_loss 294.4930
# Epoch 2/3 loss 209.4597 index_layer_3_loss -70.3530 lambda_51_loss 279.8127
# 62 / 66
# Epoch 0/3 loss 205.8125 index_layer_3_loss -73.5665 lambda_51_loss 279.3790
# Epoch 1/3 loss 210.5500 index_layer_3_loss -68.5288 lambda_51_loss 279.0789
# Epoch 2/3 loss 211.5307 index_layer_3_loss -68.2235 lambda_51_loss 279.7542
# 63 / 66
# Epoch 0/3 loss 209.6328 index_layer_3_loss -68.6885 lambda_51_loss 278.3213
# Epoch 1/3 loss 234.4408 index_layer_3_loss -73.2076 lambda_51_loss 307.6484
# Epoch 2/3 loss 225.9395 index_layer_3_loss -68.7802 lambda_51_loss 294.7197
# 64 / 66
# Epoch 0/3 loss 205.5307 index_layer_3_loss -73.5333 lambda_51_loss 279.0640
# Epoch 1/3 loss 207.9380 index_layer_3_loss -72.0361 lambda_51_loss 279.9741
# Epoch 2/3 loss 214.3985 index_layer_3_loss -66.9744 lambda_51_loss 281.3729
# 65 / 66
# Epoch 0/3 loss 209.7782 index_layer_3_loss -70.5904 lambda_51_loss 280.3686
# Epoch 1/3 loss 209.5981 index_layer_3_loss -72.1672 lambda_51_loss 281.7653
# Epoch 2/3 loss 206.0667 index_layer_3_loss -74.3768 lambda_51_loss 280.4435

# %%
for i, s in enumerate(Eschedule):
    print(s)
    flextrainer2 = FlexibleTrainer(bg2, lr=s[1], batch_size=batchsize_KL,
                                   high_energy=s[2], max_energy=1e10, temperature=temperatures_training,
                                   w_ML=s[3], w_KL=1.0, std=1.0)
    resdict = train_and_sample(flextrainer2, model, X2noise, temperatures_analysis, 
                               nsample=500, nepochs_per_iter=3, niter=s[0]//3)
    resdicts2.append(resdict)
# Out:
# [40, 0.0001, 1000000.0, 1000.0, 0.0, 0.0]
# 0 / 13
# Epoch 0/3 loss 127154.2812 index_layer_9_loss -82.1849 lambda_103_loss 209339.1406
# Epoch 1/3 loss 142760.4844 index_layer_9_loss -60.2095 lambda_103_loss 202969.9844
# Epoch 2/3 loss 132511.0000 index_layer_9_loss -71.9911 lambda_103_loss 204502.1406
# 1 / 13
# Epoch 0/3 loss 110874.6797 index_layer_9_loss -90.0682 lambda_103_loss 200942.8594
# Epoch 1/3 loss 154369.7969 index_layer_9_loss -60.7425 lambda_103_loss 215112.2500
# Epoch 2/3 loss 124721.7422 index_layer_9_loss -71.8097 lambda_103_loss 196531.4219
# 2 / 13
# Epoch 0/3 loss 141908.9375 index_layer_9_loss -63.8845 lambda_103_loss 205793.4375
# Epoch 1/3 loss 113430.0234 index_layer_9_loss -73.6437 lambda_103_loss 187073.7500
# Epoch 2/3 loss 98640.3750 index_layer_9_loss -88.4593 lambda_103_loss 187099.7031
# 3 / 13
# Epoch 0/3 loss 100685.0938 index_layer_9_loss -85.0354 lambda_103_loss 185720.4531
# Epoch 1/3 loss 105690.2031 index_layer_9_loss -74.2172 lambda_103_loss 179907.4375
# Epoch 2/3 loss 112168.6016 index_layer_9_loss -69.2443 lambda_103_loss 181412.8750
# 4 / 13
# Epoch 0/3 loss 99848.8906 index_layer_9_loss -73.1821 lambda_103_loss 173030.9688
# Epoch 1/3 loss 71862.3828 index_layer_9_loss -93.7008 lambda_103_loss 165563.2188
# Epoch 2/3 loss 101623.8750 index_layer_9_loss -80.9422 lambda_103_loss 182566.0938
# 5 / 13
# Epoch 0/3 loss 99011.9297 index_layer_9_loss -67.3897 lambda_103_loss 166401.6250
# Epoch 1/3 loss 112359.8984 index_layer_9_loss -66.8091 lambda_103_loss 179169.0312
# Epoch 2/3 loss 79824.3281 index_layer_9_loss -81.0123 lambda_103_loss 160836.6406
# 6 / 13
# Epoch 0/3 loss 74981.0156 index_layer_9_loss -79.0588 lambda_103_loss 154039.8281
# Epoch 1/3 loss 77094.8281 index_layer_9_loss -67.4289 lambda_103_loss 144523.7031
# Epoch 2/3 loss 79650.2188 index_layer_9_loss -77.3699 lambda_103_loss 157020.1562
# 7 / 13
# Epoch 0/3 loss 69998.2969 index_layer_9_loss -79.4390 lambda_103_loss 149437.3281
# Epoch 1/3 loss 63503.1641 index_layer_9_loss -79.8795 lambda_103_loss 143382.6406
# Epoch 2/3 loss 74299.4062 index_layer_9_loss -70.1962 lambda_103_loss 144495.5625
# 8 / 13
# Epoch 0/3 loss 62407.0703 index_layer_9_loss -81.2990 lambda_103_loss 143706.0469
# Epoch 1/3 loss 69852.1250 index_layer_9_loss -65.1557 lambda_103_loss 135007.8594
# Epoch 1/3 loss 208.8139 index_layer_9_loss -73.3260 lambda_103_loss 282.1399
# Epoch 2/3 loss 213.1525 index_layer_9_loss -70.4850 lambda_103_loss 283.6375
# 65 / 66
# Epoch 0/3 loss 213.9678 index_layer_9_loss -68.2985 lambda_103_loss 282.2663
# Epoch 1/3 loss 210.4004 index_layer_9_loss -71.2096 lambda_103_loss 281.6100
# Epoch 2/3 loss 210.1486 index_layer_9_loss -72.1222 lambda_103_loss 282.2708

# %%
# concatenate results
swt_E1 = np.hstack([r['E'] for r in resdicts1])
swt_E2 = np.hstack([r['E'] for r in resdicts2])
swt_Jzx1 = np.hstack([r['Jzx'] for r in resdicts1])
swt_Jzx2 = np.hstack([r['Jzx'] for r in resdicts2])
swt_Jxz1 = np.hstack([r['Jxz'] for r in resdicts1])
swt_Jxz2 = np.hstack([r['Jxz'] for r in resdicts2])

# %%
for t, T in enumerate(temperatures_analysis[:-4]):
    energies = swt_E1[i, -20000:] / T
    plt.hist(energies[energies<200], 100, density=True, alpha=0.4);
    plt.ylim(0, 0.25)
# Out:
# /Users/noe/anaconda/lib/python3.5/site-packages/numpy/lib/histograms.py:815: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
dFs12 = []
for t, T in enumerate(temperatures_analysis):
    dFs12.append(clean_differences_from_scratch_chunk(swt_E1[t], swt_Jzx1[t], swt_Jxz1[t], 
                                                      swt_E2[t], swt_Jzx2[t], swt_Jxz2[t], 
                                                      T=temperatures_analysis[t],                                            
                                                      #T=1.0,
                                                      chunksize=200, cut_initial=1000, cut_over_median=50))
# Out:
# /Users/noe/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/noe/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/noe/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.figure(figsize=(5, 4))

xrange = np.linspace(0, 600, dFs12[0].size)

# Plot Umbrella sampling reference
#dF_true_015 = -np.mean(dF_closed_open_US[0:3])
dF_true_025 = -np.mean(dF_closed_open_US[3:6])
dF_true_05 = -np.mean(dF_closed_open_US[6:9])
dF_true_10 = -np.mean(dF_closed_open_US[9:12])
dF_true_20 = -np.mean(dF_closed_open_US[12:15])
#dF_true_015_std = np.std(dF_closed_open_US[0:3])
dF_true_025_std = np.std(dF_closed_open_US[3:6])
dF_true_05_std = np.std(dF_closed_open_US[6:9])
dF_true_10_std = np.std(dF_closed_open_US[9:12])
dF_true_20_std = np.std(dF_closed_open_US[12:15])
#plt.plot([xrange[0], xrange[-1]], [dF_true_015, dF_true_015], color='black', linewidth=3, label='Umbrella Sampling')
plt.plot([xrange[0], xrange[-1]], [dF_true_025, dF_true_025], color='black', linewidth=3, label='US')
plt.plot([xrange[0], xrange[-1]], [dF_true_05, dF_true_05], color='black', linewidth=3)
plt.plot([xrange[0], xrange[-1]], [dF_true_10, dF_true_10], color='black', linewidth=3)
#plt.plot([xrange[0], xrange[-1]], [dF_true_20, dF_true_20], color='black', linewidth=3)
#plt.fill_between([xrange[0], xrange[-1]], [dF_true_015-dF_true_015_std, dF_true_015-dF_true_015_std], [dF_true_015+dF_true_015_std, dF_true_015+dF_true_015_std], color='black', alpha=0.4)
plt.fill_between([xrange[0], xrange[-1]], [dF_true_025-dF_true_025_std, dF_true_025-dF_true_025_std], [dF_true_025+dF_true_025_std, dF_true_025+dF_true_025_std], color='black', alpha=0.4)
plt.fill_between([xrange[0], xrange[-1]], [dF_true_05-dF_true_05_std, dF_true_05-dF_true_05_std], [dF_true_05+dF_true_05_std, dF_true_05+dF_true_05_std], color='black', alpha=0.4)
plt.fill_between([xrange[0], xrange[-1]], [dF_true_10-dF_true_10_std, dF_true_10-dF_true_10_std], [dF_true_10+dF_true_10_std, dF_true_10+dF_true_10_std], color='black', alpha=0.4)
#plt.fill_between([xrange[0], xrange[-1]], [dF_true_20-dF_true_20_std, dF_true_20-dF_true_20_std], [dF_true_20+dF_true_20_std, dF_true_20+dF_true_20_std], color='black', alpha=0.4)

# BG Estimates
#plt.plot(xrange, dFs12[1]) # 0.15
plt.plot(xrange, dFs12[3], linewidth=3, color='#006600', label='0.25 $T_0$')
plt.plot(xrange, dFs12[7], linewidth=3, color='#009900', label='0.5 $T_0$')
plt.plot(xrange, dFs12[10], linewidth=3, color='#00CC00', label='1 $T_0$')
#plt.plot(xrange, dFs12[14], linewidth=3, color='#00FF00', label='2 $T_0$')

plt.xlim(300, 600)
plt.ylim(0, 70)
plt.xlabel('Training iterations')
plt.ylabel('Free energy difference / $kT_0$')
plt.legend(loc='upper center', ncol=2, frameon=False)
#plt.savefig(paper_dir + 'figs/particles/free_energy_2BGs_conv.pdf', bbox_inches='tight', transparent=True)

# %%
distinct_temperatures_US = [0.15, 0.25, 0.5, 1.0, 2.0]
means_US = np.array(dF_closed_open_US).reshape((-1, 3)).mean(axis=1)
stds_US = np.array(dF_closed_open_US).reshape((-1, 3)).std(axis=1)

# %%
plt.figure(figsize=(5, 4))
dFs12arr = np.array(dFs12)
means = dFs12arr[:, -20:].mean(axis=(1))
uncertainties = dFs12arr[:, -20:].std(axis=(1))
plt.plot(temperatures_analysis, means, color='green', linewidth=2)
plt.fill_between(temperatures_analysis, means-2.0*uncertainties, means+2.0*uncertainties, color='green', alpha=0.5)
plt.errorbar(distinct_temperatures_US, -means_US, 2.0*stds_US,
             color='black', elinewidth=2, linewidth=0, marker='.', markersize=10, label='Umbrella\nsampling')
plt.semilogx()
plt.xlim(0.1, 2.5)
plt.ylim(-5, 70)
plt.xlabel('Temperature / K')
plt.ylabel('Free energy difference / $kT_0$')
plt.legend(loc=3, frameon=True, handletextpad=0)
plt.savefig(paper_dir + 'figs/particles/free_energy_2BGs.pdf', bbox_inches='tight', transparent=True)

# %%
_, sample_x_bg1, _, energies_x_bg1, _ = bg1.sample(nsample=10000)
plt.hist(model.energy(traj_closed_train[:10000]), 100, density=True, alpha=0.5);
plt.hist(energies_x_bg1[energies_x_bg1<100], 100, density=True, alpha=0.5);
plt.xlim(20, 100)
# Out:
# (20, 100)

# %%
_, sample_x_bg2, _, energies_x_bg2, _ = bg2.sample(nsample=10000)
plt.hist(model.energy(traj_closed_train[:10000]), 100, density=True, alpha=0.5);
plt.hist(energies_x_bg2[energies_x_bg2<100], 100, density=True, alpha=0.5);
plt.xlim(20, 100)
# Out:
# (20, 100)
