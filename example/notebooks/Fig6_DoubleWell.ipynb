# %% [markdown]
# Computing free energy differences with two Boltzmann generators
# ------
# Here we construct two Boltzmann generators (x <--> z) and (y <-->z) that map two different parts of configuration space to the same latent space. We then sample from latent space and compute free energy differences between the two sets of configurations.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import keras
import tensorflow as tf
import pyemma
from pyemma.util.statistics import confidence_interval
# Out:
# Using TensorFlow backend.

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
rcParams.update({'font.size': 16})

# %%
# Switch AUTORELOAD ON. Disable this when in production mode!
# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/noe/anaconda/lib/python3.5/site-packages/pyemma/__init__.py:130: UserWarning: You are not using the latest release of PyEMMA. Latest is 2.5.6, you have 2.5.3.
#   .format(latest=latest, current=current), category=UserWarning)

# %%
from deep_boltzmann.models import DoubleWell
from deep_boltzmann.networks.invertible import create_NICERNet, create_RealNVPNet, invnet
from deep_boltzmann.sampling import GaussianPriorMCMC
from deep_boltzmann.networks.plot import test_xz_projection
from deep_boltzmann.util import count_transitions
from deep_boltzmann.sampling.analysis import free_energy_bootstrap, mean_finite, std_finite

# %%
def getx(x):
    return x[:, 0]

# %% [markdown]
# Double well
# ---

# %%
paper_dir = '/Users/noe/data/papers/NoeEtAl_BoltzmannGeneratorsRev/'

# %%
params = DoubleWell.params_default.copy()
params['dim'] = 2
double_well = DoubleWell(params=params)
plt.figure(figsize=(5,5))
double_well.plot_dimer_energy();
#plt.savefig(paper_dir + 'figs/doublewell_potential.pdf', bbox_inches='tight')

# %%
print(params)
# Out:
# {'a4': 1.0, 'a1': 1.0, 'k': 1.0, 'a2': 6.0, 'dim': 2}

# %%
# simulation data
from deep_boltzmann.sampling import MetropolisGauss

# %%
nsteps = 10000
x0_left = np.array([[-1.8, 0.0]])
x0_right = np.array([[1.8, 0.0]])

sampler = MetropolisGauss(double_well, x0_left, noise=0.1, stride=10)
sampler.run(nsteps)
traj_left = sampler.traj.copy()

sampler.reset(x0_left)
sampler.run(nsteps)
traj_left_val = sampler.traj.copy()

sampler.reset(x0_right)
sampler.run(nsteps)
traj_right = sampler.traj.copy()

sampler.reset(x0_right)
sampler.run(nsteps)
traj_right_val = sampler.traj.copy()

# %%
plt.figure(figsize=(10, 4))
ax1 = plt.subplot2grid((1, 3), (0, 0), colspan=2)
ax2 = plt.subplot2grid((1, 3), (0, 2))
ax1.plot(traj_left[:, 0], color='blue', alpha=0.7)
ax1.plot(traj_right[:, 0], color='red', alpha=0.7)
ax1.set_xlim(0, 1000)
ax1.set_ylim(-2.5, 2.5)
ax1.set_xlabel('Time / steps')
ax1.set_ylabel('x / a.u.')
ax2.hist(traj_left[:, 0], 30, orientation='horizontal', histtype='stepfilled', color='blue', alpha=0.2);
ax2.hist(traj_left[:, 0], 30, orientation='horizontal', histtype='step', color='blue', linewidth=2);
ax2.hist(traj_right[:, 0], 30, orientation='horizontal', histtype='stepfilled', color='red', alpha=0.2);
ax2.hist(traj_right[:, 0], 30, orientation='horizontal', histtype='step', color='red', linewidth=2);
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_ylim(-2.5, 2.5)
ax2.set_xlabel('Probability')
#plt.savefig(paper_dir + 'figs/doublewell_prior_trajs.pdf', bbox_inches='tight')
# Out:
# Text(0.5,0,'Probability')

# %%
x = np.vstack([traj_left, traj_right])
xval = np.vstack([traj_left_val, traj_right_val])

# %%
# prepare transition state
x_ts = np.vstack([np.zeros(1000), (1.0/double_well.params['k']) * np.random.randn(1000)]).T

# %%
def plot_potential(labels=True, cbar=True):
    # 2D potential
    xgrid = np.linspace(-3, 3, 100)
    ygrid = np.linspace(-6, 6, 100)
    Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
    X = np.vstack([Xgrid.flatten(), Ygrid.flatten()]).T
    E = double_well.energy(X)
    E = E.reshape((100, 100))
    E = np.minimum(E, 10.0)
    plt.figure(figsize=(5, 4))
    plt.contourf(Xgrid, Ygrid, E, 50, cmap='jet', vmax=4)
    if cbar:
        cbar = plt.colorbar()
        cbar.set_label('Energy / kT', labelpad=-15, y=0.6)
        cbar.set_ticks([-10, -5, 0, 5, 10])
    if labels:
        plt.xlabel('$x_1$ / a.u.')
        plt.ylabel('$x_2$ / a.u.')
    else:
        plt.xticks([])
        plt.yticks([])

# %%
plot_potential(labels=False, cbar=False)
plt.plot(traj_left[:, 0], traj_left[:, 1], color='teal', linewidth=0, marker='.')
plt.plot(traj_right[:, 0], traj_right[:, 1], color='red', linewidth=0, marker='.')
#plt.savefig(paper_dir + 'figs/double_well/xdist_2BGs.pdf', bbox_inches='tight')

# %% [markdown]
# Training
# -------

# %%
batchsize_ML = 128
batchsize_KL = 1000

# %%
def train_flexible(network, epochsE, x, xval=None, wML=1.0, wKL=1.0, wW2=0.0, wRC=0.0, temperature=1.0, explore=1.0, return_test_energies=False):
    nterms = 0
    if wML > 0:
        nterms +=1
    if wKL > 0:
        nterms +=1
    if wW2 > 0:
        nterms +=1
    if nterms == 1 and wKL > 0:
        _, loss_train, loss_val = network.train_KL(lr=0.001, epochs=epochsE, batch_size=batchsize_KL, explore=explore, verbose=0)
        return loss_train, loss_val
    else:
        returns = network.train_flexible(x, xval=xval, lr=0.001, epochs=epochsE, 
                                         batch_size=batchsize_KL, std=1.0,
                                         weight_ML=wML, weight_KL=wKL, weight_MC=0.0, weight_W2=wW2, weight_RCEnt=wRC, 
                                         rc_func=getx, rc_min=-2.5, rc_max=2.5,
                                         temperature=temperature, explore=explore, 
                                         verbose=0, return_test_energies=return_test_energies)
        return returns[1:]

# %% [markdown]
# Temperature dependence, direct estimate
# ----

# %%
from deep_boltzmann.networks.training import MLTrainer, FlexibleTrainer

# %%
temperature = np.array([0.5, 1.0, 2.0, 4.0])
temperatures_analysis = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5, 0.6, 0.8, 1.0, 1.25, 1.5, 1.75, 2.0, 2.5, 3.0, 3.5, 4.0]

# %%
# compute exact free energy difference
xx, xE = double_well.plot_dimer_energy();
dFs_ref = []
Rs = []
for T in temperatures_analysis:
    W = np.exp(-xE / T)
    r = np.sum(W[xx>=0]) / np.sum(W[xx<0])
    Rs.append(r)
    dFs_ref.append(-np.log(r))

# %%
def train_and_sample_free_energy(trainer, model, xtrain, temperatures_analysis, 
                                 nsample=100, nepochs_per_iter=10, niter=100, train_batchsize=None):
    bg = trainer.bg
    # Train and sample for multiple temperatures
    F_by_temp = [[] for T in temperatures_analysis]
    Ex_by_temp = [[] for T in temperatures_analysis]
    Jzx_by_temp = [[] for T in temperatures_analysis]
    for i in range(niter):  # training iteration
        print(i, '/', niter)
        if train_batchsize is None:
            trainer.train(xtrain, epochs=nepochs_per_iter)
        else:
            trainer.train(xtrain, epochs=nepochs_per_iter, batch_size=train_batchsize)
        for t, T in enumerate(temperatures_analysis):  # temperature iteration
            samples_z = np.sqrt(T) * np.random.randn(nsample, model.dim)
            samples_x, samples_Jzx = bg.transform_zxJ(samples_z)
            samples_enerx = model.energy(samples_x)
            Ex_by_temp[t].append(samples_enerx)
            Jzx_by_temp[t].append(samples_Jzx)     
    for t, T in enumerate(temperatures_analysis):  # temperature iteration
        F_by_temp[t] = np.concatenate(Ex_by_temp[t]) / T - np.concatenate(Jzx_by_temp[t])
        #Ex_by_temp[t] = np.concatenate(Ex_by_temp[t])
        #Jzx_by_temp[t] = np.concatenate(Jzx_by_temp[t])
    return F_by_temp

# %%
def dF_running_mean(dFs, window=100, step=1, dF_cut=50):
    dF_runningmean = []
    for i in range(0, dFs.size-window, step):
        chunk = dFs[i:i+window]
        chunk_reg = chunk[np.logical_and(chunk > -dF_cut, chunk < dF_cut)]
        dF_runningmean.append(chunk_reg.mean())
    return dF_runningmean

# %%
bg1 = invnet(double_well.dim, 'RRRR', double_well, nl_layers=2, nl_hidden=100, 
             nl_activation='relu', nl_activation_scale='tanh')
bg2 = invnet(double_well.dim, 'RRRR', double_well, nl_layers=2, nl_hidden=100, 
             nl_activation='relu', nl_activation_scale='tanh')
# Out:
# <RRRR>
# < 2 0 0
# R 1 1 0
# R 1 1 0
# R 1 1 0
# R 1 1 0
# > 1 1 0
# <RRRR>
# < 2 0 0
# R 1 1 0
# R 1 1 0
# R 1 1 0
# R 1 1 0
# > 1 1 0

# %%
mltrainer1 = MLTrainer(bg1, lr=0.001)
mltrainer2 = MLTrainer(bg2, lr=0.001)
# Out:
# Compiling the graph
# Compiling the graph

# %%
F1_ML_by_temp = train_and_sample_free_energy(mltrainer1, double_well, traj_left, temperatures_analysis, 
                                             train_batchsize=128, nsample=1000, nepochs_per_iter=10, niter=20)
F2_ML_by_temp = train_and_sample_free_energy(mltrainer2, double_well, traj_right, temperatures_analysis, 
                                             train_batchsize=128, nsample=1000, nepochs_per_iter=10, niter=20)
# Out:
# 0 / 20
# Epoch 0/10 loss 2.9221
# Epoch 1/10 loss 2.6320
# Epoch 2/10 loss 2.3288
# Epoch 3/10 loss 2.2576
# Epoch 4/10 loss 2.0792
# Epoch 5/10 loss 1.8697
# Epoch 6/10 loss 1.8033
# Epoch 7/10 loss 1.7389
# Epoch 8/10 loss 1.6127
# Epoch 9/10 loss 1.4428
# 1 / 20
# Epoch 0/10 loss 1.4036
# Epoch 1/10 loss 1.3728
# Epoch 2/10 loss 1.3105
# Epoch 3/10 loss 1.2653
# Epoch 4/10 loss 1.1605
# Epoch 5/10 loss 1.0991
# Epoch 6/10 loss 1.0298
# Epoch 7/10 loss 0.9805
# Epoch 8/10 loss 1.0817
# Epoch 9/10 loss 0.9247
# 2 / 20
# Epoch 0/10 loss 0.9059
# Epoch 1/10 loss 1.0262
# Epoch 2/10 loss 0.8641
# Epoch 3/10 loss 0.8013
# Epoch 4/10 loss 0.8311
# Epoch 5/10 loss 0.8568
# Epoch 6/10 loss 0.7929
# Epoch 7/10 loss 0.7805
# Epoch 8/10 loss 0.8386
# Epoch 9/10 loss 0.7085
# 3 / 20
# Epoch 0/10 loss 0.7006
# Epoch 1/10 loss 0.6211
# Epoch 2/10 loss 0.6373
# Epoch 3/10 loss 0.5915
# Epoch 4/10 loss 0.7016
# Epoch 5/10 loss 0.5218
# Epoch 6/10 loss 0.5093
# Epoch 7/10 loss 0.5596
# Epoch 8/10 loss 0.6311
# Epoch 9/10 loss 0.4849
# 4 / 20
# Epoch 0/10 loss 0.5690
# Epoch 1/10 loss 0.5215
# Epoch 2/10 loss 0.6443
# Epoch 3/10 loss 0.4277
# Epoch 4/10 loss 0.4066
# Epoch 5/10 loss 0.5088
# Epoch 6/10 loss 0.4618
# Epoch 7/10 loss 0.4407
# Epoch 8/10 loss 0.3116
# Epoch 9/10 loss 0.3238
# 5 / 20
# Epoch 0/10 loss 0.4531
# Epoch 1/10 loss 0.3176
# Epoch 2/10 loss 0.2743
# Epoch 3/10 loss 0.2777
# Epoch 4/10 loss 0.3437
# Epoch 5/10 loss 0.3280
# Epoch 6/10 loss 0.2272
# Epoch 7/10 loss 0.4535
# Epoch 8/10 loss 0.2512
# Epoch 9/10 loss 0.2604
# 6 / 20
# Epoch 0/10 loss 0.2224
# Epoch 1/10 loss 0.2923
# Epoch 2/10 loss 0.1545
# Epoch 3/10 loss 0.2496
# Epoch 4/10 loss 0.1769
# Epoch 5/10 loss 0.2420
# Epoch 6/10 loss 0.0989
# Epoch 7/10 loss 0.0215
# Epoch 8/10 loss 0.1549
# Epoch 9/10 loss 0.1002
# 7 / 20
# Epoch 0/10 loss 0.1920
# Epoch 1/10 loss -0.0367
# Epoch 2/10 loss -0.0355
# Epoch 3/10 loss 0.0569
# Epoch 4/10 loss -0.0011
# Epoch 5/10 loss 0.0576
# Epoch 6/10 loss -0.1141
# Epoch 7/10 loss -0.1032
# Epoch 8/10 loss 0.1741
# Epoch 9/10 loss -0.0293
# 8 / 20
# Epoch 0/10 loss -0.0134
# Epoch 1/10 loss -0.0106
# Epoch 2/10 loss -0.1640
# Epoch 3/10 loss -0.0810
# Epoch 4/10 loss -0.2661
# Epoch 5/10 loss -0.2377
# Epoch 6/10 loss -0.1511
# Epoch 7/10 loss 0.0807
# Epoch 8/10 loss -0.2310
# Epoch 9/10 loss -0.2185
# 9 / 20
# Epoch 0/10 loss 0.0760
# Epoch 1/10 loss -0.2667
# Epoch 2/10 loss -0.2411
# Epoch 3/10 loss -0.2267
# Epoch 4/10 loss -0.2707
# Epoch 5/10 loss -0.2955
# Epoch 6/10 loss -0.1618
# Epoch 7/10 loss -0.1529
# Epoch 8/10 loss -0.3699
# Epoch 9/10 loss -0.2710
# 10 / 20
# Epoch 0/10 loss -0.1953
# Epoch 1/10 loss -0.2183
# Epoch 2/10 loss -0.4057
# Epoch 3/10 loss -0.3726
# Epoch 4/10 loss -0.3738
# Epoch 5/10 loss -0.2522
# Epoch 6/10 loss -0.3659
# Epoch 7/10 loss -0.2471
# Epoch 8/10 loss -0.3289
# Epoch 9/10 loss -0.4480
# 11 / 20
# Epoch 0/10 loss -0.2643
# Epoch 1/10 loss -0.3560
# Epoch 2/10 loss -0.3758
# Epoch 3/10 loss -0.3975
# Epoch 4/10 loss -0.4700
# Epoch 5/10 loss -0.5640
# Epoch 6/10 loss -0.3585
# Epoch 7/10 loss -0.2739
# Epoch 8/10 loss -0.3658
# Epoch 9/10 loss -0.2661
# 12 / 20
# Epoch 0/10 loss -0.3966
# Epoch 1/10 loss -0.3804
# Epoch 2/10 loss -0.3799
# Epoch 3/10 loss -0.4778
# Epoch 4/10 loss -0.4738
# Epoch 5/10 loss -0.2920
# Epoch 6/10 loss -0.5070
# Epoch 7/10 loss -0.3916
# Epoch 8/10 loss -0.4429
# Epoch 9/10 loss -0.4294
# 13 / 20
# Epoch 0/10 loss -0.3929
# Epoch 1/10 loss -0.5500
# Epoch 2/10 loss -0.4965
# Epoch 3/10 loss -0.4776
# Epoch 4/10 loss -0.2521
# Epoch 5/10 loss -0.3664
# Epoch 6/10 loss -0.4283
# Epoch 7/10 loss -0.3318
# Epoch 8/10 loss -0.5831
# Epoch 9/10 loss -0.5599
# 14 / 20
# Epoch 0/10 loss -0.5539
# Epoch 1/10 loss -0.4303
# Epoch 2/10 loss -0.3204
# Epoch 3/10 loss -0.4631
# Epoch 4/10 loss -0.4820
# Epoch 5/10 loss -0.4507
# Epoch 6/10 loss -0.4591
# Epoch 7/10 loss -0.5600
# Epoch 8/10 loss -0.5430
# Epoch 9/10 loss -0.4590
# 15 / 20
# Epoch 0/10 loss -0.4969
# Epoch 1/10 loss -0.3914
# Epoch 2/10 loss -0.4994
# Epoch 3/10 loss -0.4012
# Epoch 4/10 loss -0.5716
# Epoch 5/10 loss -0.4471
# Epoch 6/10 loss -0.3759
# Epoch 7/10 loss -0.5844
# Epoch 8/10 loss -0.6033
# Epoch 9/10 loss -0.3478
# 16 / 20
# Epoch 0/10 loss -0.4932
# Epoch 1/10 loss -0.5930
# Epoch 2/10 loss -0.4493
# Epoch 3/10 loss -0.5337
# Epoch 4/10 loss -0.3654
# Epoch 5/10 loss -0.3861
# Epoch 6/10 loss -0.4799
# Epoch 7/10 loss -0.4876
# Epoch 8/10 loss -0.5278
# Epoch 9/10 loss -0.4723
# 17 / 20
# Epoch 0/10 loss -0.5195
# Epoch 1/10 loss -0.4429
# Epoch 2/10 loss -0.5193
# Epoch 3/10 loss -0.5645
# Epoch 4/10 loss -0.4369
# Epoch 5/10 loss -0.5442
# Epoch 6/10 loss -0.3625
# Epoch 7/10 loss -0.3538
# Epoch 8/10 loss -0.4708
# Epoch 9/10 loss -0.4300
# 18 / 20
# Epoch 0/10 loss -0.4871
# Epoch 1/10 loss -0.4948
# Epoch 2/10 loss -0.5811
# Epoch 3/10 loss -0.4743
# Epoch 4/10 loss -0.6039
# Epoch 5/10 loss -0.4060
# Epoch 6/10 loss -0.5104
# Epoch 7/10 loss -0.5672
# Epoch 8/10 loss -0.3108
# Epoch 9/10 loss -0.4766
# 19 / 20
# Epoch 0/10 loss -0.3863
# Epoch 1/10 loss -0.5967
# Epoch 2/10 loss -0.4580
# Epoch 3/10 loss -0.3143
# Epoch 4/10 loss -0.5763
# Epoch 5/10 loss -0.4102
# Epoch 6/10 loss -0.4758
# Epoch 7/10 loss -0.5538
# Epoch 8/10 loss -0.3722
# Epoch 9/10 loss -0.5352
# 0 / 20
# Epoch 0/10 loss 1.8686
# Epoch 1/10 loss 1.9418
# Epoch 2/10 loss 1.8327
# Epoch 3/10 loss 1.5718
# Epoch 4/10 loss 1.5477
# Epoch 5/10 loss 1.3963
# Epoch 6/10 loss 1.3973
# Epoch 7/10 loss 1.2886
# Epoch 8/10 loss 1.3041
# Epoch 9/10 loss 1.2060
# 1 / 20
# Epoch 0/10 loss 1.1427
# Epoch 1/10 loss 0.9817
# Epoch 2/10 loss 1.0415
# Epoch 3/10 loss 0.9400
# Epoch 4/10 loss 0.9752
# Epoch 5/10 loss 0.8198
# Epoch 6/10 loss 0.7392
# Epoch 7/10 loss 0.7660
# Epoch 8/10 loss 0.6862
# Epoch 9/10 loss 0.6728
# 2 / 20
# Epoch 0/10 loss 0.7694
# Epoch 1/10 loss 0.7136
# Epoch 2/10 loss 0.6456
# Epoch 3/10 loss 0.6612
# Epoch 4/10 loss 0.6286
# Epoch 5/10 loss 0.5665
# Epoch 6/10 loss 0.5733
# Epoch 7/10 loss 0.6258
# Epoch 8/10 loss 0.5614
# Epoch 9/10 loss 0.4970
# 3 / 20
# Epoch 0/10 loss 0.4315
# Epoch 1/10 loss 0.4056
# Epoch 2/10 loss 0.2808
# Epoch 3/10 loss 0.3779
# Epoch 4/10 loss 0.3049
# Epoch 5/10 loss 0.2666
# Epoch 6/10 loss 0.2304
# Epoch 7/10 loss 0.1286
# Epoch 8/10 loss 0.2479
# Epoch 9/10 loss 0.2549
# 4 / 20
# Epoch 0/10 loss 0.1730
# Epoch 1/10 loss 0.2293
# Epoch 2/10 loss 0.2609
# Epoch 3/10 loss 0.0968
# Epoch 4/10 loss 0.3000
# Epoch 5/10 loss 0.0633
# Epoch 6/10 loss 0.0986
# Epoch 7/10 loss 0.2077
# Epoch 8/10 loss 0.2411
# Epoch 9/10 loss 0.1884
# 5 / 20
# Epoch 0/10 loss 0.0054
# Epoch 1/10 loss 0.0232
# Epoch 2/10 loss 0.0701
# Epoch 3/10 loss 0.2089
# Epoch 4/10 loss -0.0897
# Epoch 5/10 loss -0.0292
# Epoch 6/10 loss -0.0129
# Epoch 7/10 loss 0.0156
# Epoch 8/10 loss 0.1097
# Epoch 9/10 loss -0.1101
# 6 / 20
# Epoch 0/10 loss -0.0428
# Epoch 1/10 loss -0.0868
# Epoch 2/10 loss -0.1623
# Epoch 3/10 loss -0.1265
# Epoch 4/10 loss -0.1090
# Epoch 5/10 loss -0.1340
# Epoch 6/10 loss -0.0324
# Epoch 7/10 loss -0.1061
# Epoch 8/10 loss -0.1382
# Epoch 9/10 loss -0.0831
# 7 / 20
# Epoch 0/10 loss -0.1345
# Epoch 1/10 loss -0.0702
# Epoch 2/10 loss 0.0125
# Epoch 3/10 loss -0.1455
# Epoch 4/10 loss -0.1535
# Epoch 5/10 loss -0.2195
# Epoch 6/10 loss -0.1116
# Epoch 7/10 loss -0.1526
# Epoch 8/10 loss -0.3252
# Epoch 9/10 loss -0.3121
# 8 / 20
# Epoch 0/10 loss -0.2906
# Epoch 1/10 loss -0.2691
# Epoch 2/10 loss -0.2872
# Epoch 3/10 loss -0.0136
# Epoch 4/10 loss -0.2058
# Epoch 5/10 loss -0.1917
# Epoch 6/10 loss -0.3605
# Epoch 7/10 loss -0.2820
# Epoch 8/10 loss -0.3255
# Epoch 9/10 loss -0.2694
# 9 / 20
# Epoch 0/10 loss -0.2377
# Epoch 1/10 loss -0.3690
# Epoch 2/10 loss -0.4061
# Epoch 3/10 loss -0.4447
# Epoch 4/10 loss -0.3204
# Epoch 5/10 loss -0.3367
# Epoch 6/10 loss -0.3194
# Epoch 7/10 loss -0.3640
# Epoch 8/10 loss -0.2609
# Epoch 9/10 loss -0.3099
# 10 / 20
# Epoch 0/10 loss -0.3368
# Epoch 1/10 loss -0.3864
# Epoch 2/10 loss -0.2276
# Epoch 3/10 loss -0.4228
# Epoch 4/10 loss -0.4440
# Epoch 5/10 loss -0.4399
# Epoch 6/10 loss -0.3792
# Epoch 7/10 loss -0.4071
# Epoch 8/10 loss -0.4505
# Epoch 9/10 loss -0.3863
# 11 / 20
# Epoch 0/10 loss -0.5294
# Epoch 1/10 loss -0.4848
# Epoch 2/10 loss -0.2711
# Epoch 3/10 loss -0.4829
# Epoch 4/10 loss -0.4565
# Epoch 5/10 loss -0.5474
# Epoch 6/10 loss -0.4528
# Epoch 7/10 loss -0.3575
# Epoch 8/10 loss -0.3573
# Epoch 9/10 loss -0.4279
# 12 / 20
# Epoch 0/10 loss -0.5876
# Epoch 1/10 loss -0.4258
# Epoch 2/10 loss -0.5540
# Epoch 3/10 loss -0.5206
# Epoch 4/10 loss -0.3583
# Epoch 5/10 loss -0.4398
# Epoch 6/10 loss -0.4296
# Epoch 7/10 loss -0.5693
# Epoch 8/10 loss -0.4541
# Epoch 9/10 loss -0.4596
# 13 / 20
# Epoch 0/10 loss -0.4802
# Epoch 1/10 loss -0.4430
# Epoch 2/10 loss -0.3284
# Epoch 3/10 loss -0.4281
# Epoch 4/10 loss -0.5181
# Epoch 5/10 loss -0.3969
# Epoch 6/10 loss -0.4883
# Epoch 7/10 loss -0.5207
# Epoch 8/10 loss -0.4930
# Epoch 9/10 loss -0.5047
# 14 / 20
# Epoch 0/10 loss -0.5541
# Epoch 1/10 loss -0.3684
# Epoch 2/10 loss -0.4482
# Epoch 3/10 loss -0.5498
# Epoch 4/10 loss -0.6051
# Epoch 5/10 loss -0.4469
# Epoch 6/10 loss -0.4145
# Epoch 7/10 loss -0.4469
# Epoch 8/10 loss -0.5156
# Epoch 9/10 loss -0.5719
# 15 / 20
# Epoch 0/10 loss -0.5653
# Epoch 1/10 loss -0.4511
# Epoch 2/10 loss -0.5990
# Epoch 3/10 loss -0.2866
# Epoch 4/10 loss -0.3730
# Epoch 5/10 loss -0.4856
# Epoch 6/10 loss -0.4262
# Epoch 7/10 loss -0.4910
# Epoch 8/10 loss -0.4861
# Epoch 9/10 loss -0.5908
# 16 / 20
# Epoch 0/10 loss -0.4215
# Epoch 1/10 loss -0.5689
# Epoch 2/10 loss -0.4784
# Epoch 3/10 loss -0.3855
# Epoch 4/10 loss -0.4222
# Epoch 5/10 loss -0.4941
# Epoch 6/10 loss -0.5338
# Epoch 7/10 loss -0.4133
# Epoch 8/10 loss -0.4735
# Epoch 9/10 loss -0.5260
# 17 / 20
# Epoch 0/10 loss -0.4980
# Epoch 1/10 loss -0.5602
# Epoch 2/10 loss -0.4824
# Epoch 3/10 loss -0.4593
# Epoch 4/10 loss -0.4879
# Epoch 5/10 loss -0.4344
# Epoch 6/10 loss -0.4332
# Epoch 7/10 loss -0.5479
# Epoch 8/10 loss -0.4620
# Epoch 9/10 loss -0.4903
# 18 / 20
# Epoch 0/10 loss -0.2896
# Epoch 1/10 loss -0.5065
# Epoch 2/10 loss -0.4633
# Epoch 3/10 loss -0.5563
# Epoch 4/10 loss -0.3241
# Epoch 5/10 loss -0.4537
# Epoch 6/10 loss -0.5948
# Epoch 7/10 loss -0.4069
# Epoch 8/10 loss -0.5626
# Epoch 9/10 loss -0.5774
# 19 / 20
# Epoch 0/10 loss -0.4980
# Epoch 1/10 loss -0.5790
# Epoch 2/10 loss -0.5965
# Epoch 3/10 loss -0.4805
# Epoch 4/10 loss -0.5899
# Epoch 5/10 loss -0.4720
# Epoch 6/10 loss -0.2762
# Epoch 7/10 loss -0.5598
# Epoch 8/10 loss -0.3722
# Epoch 9/10 loss -0.5957

# %%
flextrainer1 = FlexibleTrainer(bg1, lr=0.0001, batch_size=batchsize_KL, high_energy=10000, w_ML=1.0, w_KL=1.0, 
                               temperature=temperature, weigh_ML=False)
flextrainer2 = FlexibleTrainer(bg2, lr=0.0001, batch_size=batchsize_KL, high_energy=10000, w_ML=1.0, w_KL=1.0, 
                               temperature=temperature, weigh_ML=False)

# %%
F1_KL_by_temp = train_and_sample_free_energy(flextrainer1, double_well, traj_left, temperatures_analysis, 
                                             nsample=1000, nepochs_per_iter=10, niter=50)
F2_KL_by_temp = train_and_sample_free_energy(flextrainer2, double_well, traj_right, temperatures_analysis, 
                                             nsample=1000, nepochs_per_iter=10, niter=50)
# Out:
# 0 / 50
# Epoch 0/10 loss -7.6925 index_layer_15_loss -0.4835 index_layer_18_loss -7.2090
# Epoch 1/10 loss -7.8031 index_layer_15_loss -0.4961 index_layer_18_loss -7.3070
# Epoch 2/10 loss -7.8478 index_layer_15_loss -0.5091 index_layer_18_loss -7.3387
# Epoch 3/10 loss -7.7220 index_layer_15_loss -0.4603 index_layer_18_loss -7.2617
# Epoch 4/10 loss -7.7624 index_layer_15_loss -0.5066 index_layer_18_loss -7.2558
# Epoch 5/10 loss -7.7989 index_layer_15_loss -0.4921 index_layer_18_loss -7.3068
# Epoch 6/10 loss -7.8828 index_layer_15_loss -0.5084 index_layer_18_loss -7.3745
# Epoch 7/10 loss -7.7620 index_layer_15_loss -0.4726 index_layer_18_loss -7.2894
# Epoch 8/10 loss -7.8879 index_layer_15_loss -0.5088 index_layer_18_loss -7.3792
# Epoch 9/10 loss -7.6768 index_layer_15_loss -0.4484 index_layer_18_loss -7.2283
# 1 / 50
# Epoch 0/10 loss -7.6967 index_layer_15_loss -0.4720 index_layer_18_loss -7.2248
# Epoch 1/10 loss -7.8984 index_layer_15_loss -0.4659 index_layer_18_loss -7.4325
# Epoch 2/10 loss -7.7114 index_layer_15_loss -0.4537 index_layer_18_loss -7.2576
# Epoch 3/10 loss -7.8959 index_layer_15_loss -0.5001 index_layer_18_loss -7.3958
# Epoch 4/10 loss -7.7795 index_layer_15_loss -0.4721 index_layer_18_loss -7.3074
# Epoch 5/10 loss -7.8182 index_layer_15_loss -0.4569 index_layer_18_loss -7.3613
# Epoch 6/10 loss -7.8137 index_layer_15_loss -0.5349 index_layer_18_loss -7.2789
# Epoch 7/10 loss -7.7558 index_layer_15_loss -0.4589 index_layer_18_loss -7.2969
# Epoch 8/10 loss -7.9007 index_layer_15_loss -0.5199 index_layer_18_loss -7.3808
# Epoch 9/10 loss -7.8311 index_layer_15_loss -0.4931 index_layer_18_loss -7.3380
# 2 / 50
# Epoch 0/10 loss -7.9415 index_layer_15_loss -0.5406 index_layer_18_loss -7.4009
# Epoch 1/10 loss -7.7346 index_layer_15_loss -0.4997 index_layer_18_loss -7.2349
# Epoch 2/10 loss -7.8234 index_layer_15_loss -0.4620 index_layer_18_loss -7.3615
# Epoch 3/10 loss -7.8394 index_layer_15_loss -0.5010 index_layer_18_loss -7.3384
# Epoch 4/10 loss -7.9342 index_layer_15_loss -0.5309 index_layer_18_loss -7.4033
# Epoch 5/10 loss -7.8804 index_layer_15_loss -0.4674 index_layer_18_loss -7.4131
# Epoch 6/10 loss -7.7405 index_layer_15_loss -0.4356 index_layer_18_loss -7.3049
# Epoch 7/10 loss -7.8568 index_layer_15_loss -0.5013 index_layer_18_loss -7.3555
# Epoch 8/10 loss -7.8409 index_layer_15_loss -0.4707 index_layer_18_loss -7.3703
# Epoch 9/10 loss -7.8929 index_layer_15_loss -0.4746 index_layer_18_loss -7.4183
# 3 / 50
# Epoch 0/10 loss -7.8048 index_layer_15_loss -0.4592 index_layer_18_loss -7.3456
# Epoch 1/10 loss -7.8790 index_layer_15_loss -0.4962 index_layer_18_loss -7.3828
# Epoch 2/10 loss -7.8838 index_layer_15_loss -0.4742 index_layer_18_loss -7.4096
# Epoch 3/10 loss -7.8766 index_layer_15_loss -0.4966 index_layer_18_loss -7.3800
# Epoch 4/10 loss -7.8714 index_layer_15_loss -0.4512 index_layer_18_loss -7.4202
# Epoch 5/10 loss -7.9048 index_layer_15_loss -0.5027 index_layer_18_loss -7.4021
# Epoch 6/10 loss -7.8909 index_layer_15_loss -0.4858 index_layer_18_loss -7.4051
# Epoch 7/10 loss -7.8260 index_layer_15_loss -0.5305 index_layer_18_loss -7.2955
# Epoch 8/10 loss -7.9484 index_layer_15_loss -0.5416 index_layer_18_loss -7.4068
# Epoch 9/10 loss -7.9221 index_layer_15_loss -0.5028 index_layer_18_loss -7.4193
# 4 / 50
# Epoch 0/10 loss -7.7994 index_layer_15_loss -0.4593 index_layer_18_loss -7.3401
# Epoch 1/10 loss -7.8267 index_layer_15_loss -0.4682 index_layer_18_loss -7.3584
# Epoch 2/10 loss -7.9435 index_layer_15_loss -0.4991 index_layer_18_loss -7.4443
# Epoch 3/10 loss -7.8759 index_layer_15_loss -0.5067 index_layer_18_loss -7.3692
# Epoch 4/10 loss -7.8998 index_layer_15_loss -0.4773 index_layer_18_loss -7.4225
# Epoch 5/10 loss -7.8043 index_layer_15_loss -0.4556 index_layer_18_loss -7.3487
# Epoch 6/10 loss -7.8790 index_layer_15_loss -0.4690 index_layer_18_loss -7.4100
# Epoch 7/10 loss -7.8505 index_layer_15_loss -0.4686 index_layer_18_loss -7.3819
# Epoch 8/10 loss -7.9452 index_layer_15_loss -0.5372 index_layer_18_loss -7.4080
# Epoch 9/10 loss -7.7735 index_layer_15_loss -0.4875 index_layer_18_loss -7.2861
# 5 / 50
# Epoch 0/10 loss -7.9480 index_layer_15_loss -0.5312 index_layer_18_loss -7.4169
# Epoch 1/10 loss -7.9019 index_layer_15_loss -0.5318 index_layer_18_loss -7.3701
# Epoch 2/10 loss -7.8533 index_layer_15_loss -0.4733 index_layer_18_loss -7.3799
# Epoch 3/10 loss -7.8924 index_layer_15_loss -0.4907 index_layer_18_loss -7.4016
# Epoch 4/10 loss -7.8902 index_layer_15_loss -0.4998 index_layer_18_loss -7.3903
# Epoch 5/10 loss -7.9046 index_layer_15_loss -0.4642 index_layer_18_loss -7.4405
# Epoch 6/10 loss -7.8321 index_layer_15_loss -0.4730 index_layer_18_loss -7.3591
# Epoch 7/10 loss -7.9412 index_layer_15_loss -0.5055 index_layer_18_loss -7.4358
# Epoch 8/10 loss -7.9303 index_layer_15_loss -0.5470 index_layer_18_loss -7.3833
# Epoch 9/10 loss -7.8220 index_layer_15_loss -0.4468 index_layer_18_loss -7.3752
# 6 / 50
# Epoch 0/10 loss -7.8791 index_layer_15_loss -0.5069 index_layer_18_loss -7.3722
# Epoch 1/10 loss -7.8179 index_layer_15_loss -0.4975 index_layer_18_loss -7.3204
# Epoch 2/10 loss -7.8056 index_layer_15_loss -0.4900 index_layer_18_loss -7.3155
# Epoch 3/10 loss -7.8544 index_layer_15_loss -0.4852 index_layer_18_loss -7.3692
# Epoch 4/10 loss -7.7785 index_layer_15_loss -0.4567 index_layer_18_loss -7.3218
# Epoch 5/10 loss -7.8976 index_layer_15_loss -0.4768 index_layer_18_loss -7.4207
# Epoch 6/10 loss -7.8097 index_layer_15_loss -0.4437 index_layer_18_loss -7.3659
# Epoch 7/10 loss -7.9468 index_layer_15_loss -0.5263 index_layer_18_loss -7.4205
# Epoch 8/10 loss -7.8709 index_layer_15_loss -0.4512 index_layer_18_loss -7.4197
# Epoch 9/10 loss -7.8379 index_layer_15_loss -0.4366 index_layer_18_loss -7.4014
# 7 / 50
# Epoch 0/10 loss -7.8820 index_layer_15_loss -0.4914 index_layer_18_loss -7.3906
# Epoch 1/10 loss -7.9154 index_layer_15_loss -0.4763 index_layer_18_loss -7.4391
# Epoch 2/10 loss -7.8503 index_layer_15_loss -0.4625 index_layer_18_loss -7.3878
# Epoch 3/10 loss -7.7851 index_layer_15_loss -0.4439 index_layer_18_loss -7.3412
# Epoch 4/10 loss -7.8507 index_layer_15_loss -0.4330 index_layer_18_loss -7.4177
# Epoch 5/10 loss -7.8429 index_layer_15_loss -0.4690 index_layer_18_loss -7.3739
# Epoch 6/10 loss -7.8822 index_layer_15_loss -0.4514 index_layer_18_loss -7.4308
# Epoch 7/10 loss -7.8751 index_layer_15_loss -0.4437 index_layer_18_loss -7.4313
# Epoch 8/10 loss -7.8634 index_layer_15_loss -0.5118 index_layer_18_loss -7.3516
# Epoch 9/10 loss -7.8886 index_layer_15_loss -0.4727 index_layer_18_loss -7.4159
# 8 / 50
# Epoch 0/10 loss -7.8243 index_layer_15_loss -0.4423 index_layer_18_loss -7.3820
# Epoch 1/10 loss -7.8178 index_layer_15_loss -0.4788 index_layer_18_loss -7.3390
# Epoch 2/10 loss -7.9446 index_layer_15_loss -0.5085 index_layer_18_loss -7.4361
# Epoch 3/10 loss -7.9083 index_layer_15_loss -0.4793 index_layer_18_loss -7.4290
# Epoch 4/10 loss -7.8669 index_layer_15_loss -0.4546 index_layer_18_loss -7.4123
# Epoch 5/10 loss -7.8321 index_layer_15_loss -0.4615 index_layer_18_loss -7.3706
# Epoch 6/10 loss -7.8490 index_layer_15_loss -0.5058 index_layer_18_loss -7.3431
# Epoch 7/10 loss -7.8843 index_layer_15_loss -0.4294 index_layer_18_loss -7.4549
# Epoch 8/10 loss -7.9168 index_layer_15_loss -0.5244 index_layer_18_loss -7.3924
# Epoch 9/10 loss -7.8913 index_layer_15_loss -0.4982 index_layer_18_loss -7.3931
# 9 / 50
# Epoch 0/10 loss -7.8450 index_layer_15_loss -0.4703 index_layer_18_loss -7.3747
# Epoch 1/10 loss -8.0014 index_layer_15_loss -0.4998 index_layer_18_loss -7.5016
# Epoch 2/10 loss -7.8246 index_layer_15_loss -0.4868 index_layer_18_loss -7.3378
# Epoch 3/10 loss -7.9446 index_layer_15_loss -0.5048 index_layer_18_loss -7.4398
# Epoch 4/10 loss -7.9610 index_layer_15_loss -0.4836 index_layer_18_loss -7.4774
# Epoch 5/10 loss -7.8923 index_layer_15_loss -0.5350 index_layer_18_loss -7.3573
# Epoch 6/10 loss -7.8405 index_layer_15_loss -0.4508 index_layer_18_loss -7.3897
# Epoch 7/10 loss -7.8961 index_layer_15_loss -0.4638 index_layer_18_loss -7.4323
# Epoch 8/10 loss -7.8933 index_layer_15_loss -0.5019 index_layer_18_loss -7.3915
# Epoch 9/10 loss -8.0212 index_layer_15_loss -0.5659 index_layer_18_loss -7.4553
# 10 / 50
# Epoch 0/10 loss -7.9266 index_layer_15_loss -0.5347 index_layer_18_loss -7.3919
# Epoch 1/10 loss -7.9470 index_layer_15_loss -0.4921 index_layer_18_loss -7.4549
# Epoch 2/10 loss -8.0244 index_layer_15_loss -0.5687 index_layer_18_loss -7.4557
# Epoch 3/10 loss -7.8289 index_layer_15_loss -0.4495 index_layer_18_loss -7.3794
# Epoch 4/10 loss -7.9215 index_layer_15_loss -0.4761 index_layer_18_loss -7.4454
# Epoch 5/10 loss -7.9485 index_layer_15_loss -0.5481 index_layer_18_loss -7.4003
# Epoch 6/10 loss -7.9024 index_layer_15_loss -0.4892 index_layer_18_loss -7.4132
# Epoch 7/10 loss -7.9722 index_layer_15_loss -0.5245 index_layer_18_loss -7.4476
# Epoch 8/10 loss -7.9436 index_layer_15_loss -0.4922 index_layer_18_loss -7.4514
# Epoch 9/10 loss -7.9303 index_layer_15_loss -0.4678 index_layer_18_loss -7.4625
# 11 / 50
# Epoch 0/10 loss -7.9566 index_layer_15_loss -0.5099 index_layer_18_loss -7.4467
# Epoch 1/10 loss -7.8666 index_layer_15_loss -0.5260 index_layer_18_loss -7.3406
# Epoch 2/10 loss -7.9020 index_layer_15_loss -0.4637 index_layer_18_loss -7.4383
# Epoch 3/10 loss -7.8944 index_layer_15_loss -0.5086 index_layer_18_loss -7.3858
# Epoch 4/10 loss -7.8725 index_layer_15_loss -0.5007 index_layer_18_loss -7.3718
# Epoch 5/10 loss -7.9210 index_layer_15_loss -0.4850 index_layer_18_loss -7.4360
# Epoch 6/10 loss -7.9647 index_layer_15_loss -0.5143 index_layer_18_loss -7.4505
# Epoch 7/10 loss -7.9677 index_layer_15_loss -0.5343 index_layer_18_loss -7.4334
# Epoch 8/10 loss -7.8659 index_layer_15_loss -0.4536 index_layer_18_loss -7.4123
# Epoch 9/10 loss -7.7707 index_layer_15_loss -0.4468 index_layer_18_loss -7.3239
# 12 / 50
# Epoch 0/10 loss -7.9374 index_layer_15_loss -0.5142 index_layer_18_loss -7.4233
# Epoch 1/10 loss -7.9401 index_layer_15_loss -0.5162 index_layer_18_loss -7.4239
# Epoch 2/10 loss -8.0071 index_layer_15_loss -0.5432 index_layer_18_loss -7.4639
# Epoch 3/10 loss -7.8927 index_layer_15_loss -0.4610 index_layer_18_loss -7.4317
# Epoch 4/10 loss -7.9231 index_layer_15_loss -0.4851 index_layer_18_loss -7.4380
# Epoch 5/10 loss -7.9218 index_layer_15_loss -0.4730 index_layer_18_loss -7.4488
# Epoch 6/10 loss -7.8958 index_layer_15_loss -0.4561 index_layer_18_loss -7.4397
# Epoch 7/10 loss -7.8977 index_layer_15_loss -0.4826 index_layer_18_loss -7.4151
# Epoch 8/10 loss -7.9420 index_layer_15_loss -0.5349 index_layer_18_loss -7.4071
# Epoch 9/10 loss -7.9519 index_layer_15_loss -0.5084 index_layer_18_loss -7.4435
# 13 / 50
# Epoch 0/10 loss -7.9083 index_layer_15_loss -0.4342 index_layer_18_loss -7.4742
# Epoch 1/10 loss -7.8631 index_layer_15_loss -0.4898 index_layer_18_loss -7.3734
# Epoch 2/10 loss -7.8257 index_layer_15_loss -0.4410 index_layer_18_loss -7.3847
# Epoch 3/10 loss -7.9251 index_layer_15_loss -0.4922 index_layer_18_loss -7.4329
# Epoch 4/10 loss -7.8803 index_layer_15_loss -0.4916 index_layer_18_loss -7.3886
# Epoch 5/10 loss -7.9327 index_layer_15_loss -0.5121 index_layer_18_loss -7.4206
# Epoch 6/10 loss -7.9136 index_layer_15_loss -0.4755 index_layer_18_loss -7.4381
# Epoch 7/10 loss -7.8967 index_layer_15_loss -0.5255 index_layer_18_loss -7.3713
# Epoch 8/10 loss -7.9586 index_layer_15_loss -0.5219 index_layer_18_loss -7.4367
# Epoch 9/10 loss -7.9534 index_layer_15_loss -0.4852 index_layer_18_loss -7.4683
# 14 / 50
# Epoch 0/10 loss -7.8430 index_layer_15_loss -0.4361 index_layer_18_loss -7.4068
# Epoch 1/10 loss -7.9553 index_layer_15_loss -0.5293 index_layer_18_loss -7.4259
# Epoch 2/10 loss -7.8501 index_layer_15_loss -0.4720 index_layer_18_loss -7.3781
# Epoch 3/10 loss -7.8813 index_layer_15_loss -0.4817 index_layer_18_loss -7.3995
# Epoch 4/10 loss -7.8367 index_layer_15_loss -0.4566 index_layer_18_loss -7.3801
# Epoch 5/10 loss -7.9523 index_layer_15_loss -0.4734 index_layer_18_loss -7.4790
# Epoch 6/10 loss -7.8889 index_layer_15_loss -0.5423 index_layer_18_loss -7.3466
# Epoch 7/10 loss -7.9419 index_layer_15_loss -0.4471 index_layer_18_loss -7.4948
# Epoch 8/10 loss -7.9058 index_layer_15_loss -0.5102 index_layer_18_loss -7.3957
# Epoch 9/10 loss -7.9478 index_layer_15_loss -0.4894 index_layer_18_loss -7.4584
# 15 / 50
# Epoch 0/10 loss -7.9891 index_layer_15_loss -0.5599 index_layer_18_loss -7.4292
# Epoch 1/10 loss -7.8316 index_layer_15_loss -0.4633 index_layer_18_loss -7.3683
# Epoch 2/10 loss -7.8691 index_layer_15_loss -0.4958 index_layer_18_loss -7.3733
# Epoch 3/10 loss -7.9295 index_layer_15_loss -0.4941 index_layer_18_loss -7.4354
# Epoch 4/10 loss -7.8824 index_layer_15_loss -0.4452 index_layer_18_loss -7.4371
# Epoch 5/10 loss -7.8986 index_layer_15_loss -0.4136 index_layer_18_loss -7.4850
# Epoch 6/10 loss -7.9260 index_layer_15_loss -0.5333 index_layer_18_loss -7.3927
# Epoch 7/10 loss -7.9121 index_layer_15_loss -0.5079 index_layer_18_loss -7.4042
# Epoch 8/10 loss -7.8409 index_layer_15_loss -0.4572 index_layer_18_loss -7.3837
# Epoch 9/10 loss -7.8773 index_layer_15_loss -0.4547 index_layer_18_loss -7.4226
# 16 / 50
# Epoch 0/10 loss -7.9638 index_layer_15_loss -0.5393 index_layer_18_loss -7.4245
# Epoch 1/10 loss -7.8473 index_layer_15_loss -0.4429 index_layer_18_loss -7.4044
# Epoch 2/10 loss -7.9375 index_layer_15_loss -0.5056 index_layer_18_loss -7.4319
# Epoch 3/10 loss -7.9384 index_layer_15_loss -0.4791 index_layer_18_loss -7.4593
# Epoch 4/10 loss -7.8393 index_layer_15_loss -0.4801 index_layer_18_loss -7.3592
# Epoch 5/10 loss -7.8847 index_layer_15_loss -0.4894 index_layer_18_loss -7.3953
# Epoch 6/10 loss -7.9294 index_layer_15_loss -0.4977 index_layer_18_loss -7.4317
# Epoch 7/10 loss -7.8639 index_layer_15_loss -0.4491 index_layer_18_loss -7.4148
# Epoch 8/10 loss -7.9999 index_layer_15_loss -0.5090 index_layer_18_loss -7.4908
# Epoch 9/10 loss -7.8696 index_layer_15_loss -0.4842 index_layer_18_loss -7.3854
# 17 / 50
# Epoch 0/10 loss -7.8742 index_layer_15_loss -0.4720 index_layer_18_loss -7.4022
# Epoch 1/10 loss -7.9792 index_layer_15_loss -0.4995 index_layer_18_loss -7.4796
# Epoch 2/10 loss -7.9745 index_layer_15_loss -0.5310 index_layer_18_loss -7.4435
# Epoch 3/10 loss -7.9475 index_layer_15_loss -0.4824 index_layer_18_loss -7.4651
# Epoch 4/10 loss -7.8957 index_layer_15_loss -0.4677 index_layer_18_loss -7.4280
# Epoch 5/10 loss -7.8803 index_layer_15_loss -0.4859 index_layer_18_loss -7.3945
# Epoch 6/10 loss -7.9305 index_layer_15_loss -0.4663 index_layer_18_loss -7.4642
# Epoch 7/10 loss -7.8831 index_layer_15_loss -0.4852 index_layer_18_loss -7.3979
# Epoch 8/10 loss -7.9010 index_layer_15_loss -0.4543 index_layer_18_loss -7.4466
# Epoch 9/10 loss -7.9302 index_layer_15_loss -0.4167 index_layer_18_loss -7.5134
# 18 / 50
# Epoch 0/10 loss -7.8755 index_layer_15_loss -0.4749 index_layer_18_loss -7.4006
# Epoch 1/10 loss -7.9649 index_layer_15_loss -0.4463 index_layer_18_loss -7.5187
# Epoch 2/10 loss -7.9521 index_layer_15_loss -0.4788 index_layer_18_loss -7.4733
# Epoch 3/10 loss -7.9309 index_layer_15_loss -0.4675 index_layer_18_loss -7.4634
# Epoch 4/10 loss -7.8862 index_layer_15_loss -0.4674 index_layer_18_loss -7.4188
# Epoch 5/10 loss -7.9143 index_layer_15_loss -0.4589 index_layer_18_loss -7.4554
# Epoch 6/10 loss -7.9491 index_layer_15_loss -0.5121 index_layer_18_loss -7.4370
# Epoch 7/10 loss -7.9645 index_layer_15_loss -0.5408 index_layer_18_loss -7.4237
# Epoch 8/10 loss -7.8901 index_layer_15_loss -0.4937 index_layer_18_loss -7.3964
# Epoch 9/10 loss -7.9821 index_layer_15_loss -0.5510 index_layer_18_loss -7.4310
# 19 / 50
# Epoch 0/10 loss -7.8682 index_layer_15_loss -0.4337 index_layer_18_loss -7.4345
# Epoch 1/10 loss -7.9088 index_layer_15_loss -0.4810 index_layer_18_loss -7.4278
# Epoch 2/10 loss -7.9658 index_layer_15_loss -0.4995 index_layer_18_loss -7.4663
# Epoch 3/10 loss -8.0009 index_layer_15_loss -0.5129 index_layer_18_loss -7.4879
# Epoch 4/10 loss -7.9690 index_layer_15_loss -0.5147 index_layer_18_loss -7.4543
# Epoch 5/10 loss -7.9575 index_layer_15_loss -0.5343 index_layer_18_loss -7.4232
# Epoch 6/10 loss -7.9155 index_layer_15_loss -0.4881 index_layer_18_loss -7.4274
# Epoch 7/10 loss -8.0004 index_layer_15_loss -0.5435 index_layer_18_loss -7.4569
# Epoch 8/10 loss -7.9618 index_layer_15_loss -0.4686 index_layer_18_loss -7.4932
# Epoch 9/10 loss -7.9446 index_layer_15_loss -0.4913 index_layer_18_loss -7.4533
# 20 / 50
# Epoch 0/10 loss -7.9252 index_layer_15_loss -0.4776 index_layer_18_loss -7.4476
# Epoch 1/10 loss -7.9747 index_layer_15_loss -0.5218 index_layer_18_loss -7.4528
# Epoch 2/10 loss -7.9722 index_layer_15_loss -0.5140 index_layer_18_loss -7.4582
# Epoch 3/10 loss -7.9564 index_layer_15_loss -0.4730 index_layer_18_loss -7.4834
# Epoch 4/10 loss -7.9426 index_layer_15_loss -0.5130 index_layer_18_loss -7.4296
# Epoch 5/10 loss -7.8219 index_layer_15_loss -0.4709 index_layer_18_loss -7.3510
# Epoch 6/10 loss -7.9329 index_layer_15_loss -0.4688 index_layer_18_loss -7.4641
# Epoch 7/10 loss -7.9381 index_layer_15_loss -0.4545 index_layer_18_loss -7.4836
# Epoch 8/10 loss -7.9680 index_layer_15_loss -0.4789 index_layer_18_loss -7.4891
# Epoch 9/10 loss -7.9465 index_layer_15_loss -0.4627 index_layer_18_loss -7.4839
# 21 / 50
# Epoch 0/10 loss -7.9812 index_layer_15_loss -0.5052 index_layer_18_loss -7.4760
# Epoch 1/10 loss -7.8372 index_layer_15_loss -0.4618 index_layer_18_loss -7.3753
# Epoch 2/10 loss -7.9356 index_layer_15_loss -0.4744 index_layer_18_loss -7.4612
# Epoch 3/10 loss -7.9979 index_layer_15_loss -0.4783 index_layer_18_loss -7.5196
# Epoch 4/10 loss -8.0202 index_layer_15_loss -0.5591 index_layer_18_loss -7.4611
# Epoch 5/10 loss -7.9063 index_layer_15_loss -0.4952 index_layer_18_loss -7.4110
# Epoch 6/10 loss -7.9222 index_layer_15_loss -0.4935 index_layer_18_loss -7.4287
# Epoch 7/10 loss -7.9916 index_layer_15_loss -0.5135 index_layer_18_loss -7.4781
# Epoch 8/10 loss -7.8832 index_layer_15_loss -0.4745 index_layer_18_loss -7.4087
# Epoch 9/10 loss -7.9608 index_layer_15_loss -0.4935 index_layer_18_loss -7.4673
# 22 / 50
# Epoch 0/10 loss -8.0018 index_layer_15_loss -0.5314 index_layer_18_loss -7.4704
# Epoch 1/10 loss -7.9437 index_layer_15_loss -0.4621 index_layer_18_loss -7.4816
# Epoch 2/10 loss -7.9251 index_layer_15_loss -0.4963 index_layer_18_loss -7.4288
# Epoch 3/10 loss -7.9214 index_layer_15_loss -0.5186 index_layer_18_loss -7.4027
# Epoch 4/10 loss -7.9960 index_layer_15_loss -0.5214 index_layer_18_loss -7.4746
# Epoch 5/10 loss -7.9613 index_layer_15_loss -0.5531 index_layer_18_loss -7.4082
# Epoch 6/10 loss -7.8327 index_layer_15_loss -0.4508 index_layer_18_loss -7.3819
# Epoch 7/10 loss -7.9461 index_layer_15_loss -0.4800 index_layer_18_loss -7.4661
# Epoch 8/10 loss -8.0025 index_layer_15_loss -0.4673 index_layer_18_loss -7.5351
# Epoch 9/10 loss -7.9689 index_layer_15_loss -0.5100 index_layer_18_loss -7.4589
# 23 / 50
# Epoch 0/10 loss -7.9118 index_layer_15_loss -0.5019 index_layer_18_loss -7.4099
# Epoch 1/10 loss -7.9029 index_layer_15_loss -0.4537 index_layer_18_loss -7.4491
# Epoch 2/10 loss -7.9407 index_layer_15_loss -0.5289 index_layer_18_loss -7.4118
# Epoch 3/10 loss -7.9644 index_layer_15_loss -0.5259 index_layer_18_loss -7.4385
# Epoch 4/10 loss -7.9379 index_layer_15_loss -0.4870 index_layer_18_loss -7.4509
# Epoch 5/10 loss -7.9613 index_layer_15_loss -0.5298 index_layer_18_loss -7.4315
# Epoch 6/10 loss -8.0205 index_layer_15_loss -0.5148 index_layer_18_loss -7.5057
# Epoch 7/10 loss -8.0002 index_layer_15_loss -0.5096 index_layer_18_loss -7.4906
# Epoch 8/10 loss -7.9871 index_layer_15_loss -0.4934 index_layer_18_loss -7.4937
# Epoch 9/10 loss -7.9388 index_layer_15_loss -0.4671 index_layer_18_loss -7.4717
# 24 / 50
# Epoch 0/10 loss -7.8792 index_layer_15_loss -0.4522 index_layer_18_loss -7.4269
# Epoch 1/10 loss -8.0263 index_layer_15_loss -0.5074 index_layer_18_loss -7.5189
# Epoch 2/10 loss -7.9208 index_layer_15_loss -0.4693 index_layer_18_loss -7.4515
# Epoch 3/10 loss -7.9139 index_layer_15_loss -0.4688 index_layer_18_loss -7.4452
# Epoch 4/10 loss -7.9376 index_layer_15_loss -0.5008 index_layer_18_loss -7.4369
# Epoch 5/10 loss -8.0099 index_layer_15_loss -0.5397 index_layer_18_loss -7.4703
# Epoch 6/10 loss -7.9431 index_layer_15_loss -0.4733 index_layer_18_loss -7.4699
# Epoch 7/10 loss -7.9649 index_layer_15_loss -0.5629 index_layer_18_loss -7.4020
# Epoch 8/10 loss -7.9055 index_layer_15_loss -0.4697 index_layer_18_loss -7.4357
# Epoch 9/10 loss -7.9515 index_layer_15_loss -0.4771 index_layer_18_loss -7.4744
# 25 / 50
# Epoch 0/10 loss -8.0243 index_layer_15_loss -0.5563 index_layer_18_loss -7.4680
# Epoch 1/10 loss -7.8659 index_layer_15_loss -0.4517 index_layer_18_loss -7.4142
# Epoch 2/10 loss -7.9529 index_layer_15_loss -0.5232 index_layer_18_loss -7.4297
# Epoch 3/10 loss -7.9069 index_layer_15_loss -0.4486 index_layer_18_loss -7.4584
# Epoch 4/10 loss -7.9453 index_layer_15_loss -0.5015 index_layer_18_loss -7.4438
# Epoch 5/10 loss -7.9598 index_layer_15_loss -0.5231 index_layer_18_loss -7.4367
# Epoch 6/10 loss -7.9262 index_layer_15_loss -0.5399 index_layer_18_loss -7.3863
# Epoch 7/10 loss -7.9664 index_layer_15_loss -0.5319 index_layer_18_loss -7.4345
# Epoch 8/10 loss -7.9338 index_layer_15_loss -0.4963 index_layer_18_loss -7.4375
# Epoch 9/10 loss -8.0162 index_layer_15_loss -0.5039 index_layer_18_loss -7.5123
# 26 / 50
# Epoch 0/10 loss -7.9436 index_layer_15_loss -0.4820 index_layer_18_loss -7.4616
# Epoch 1/10 loss -7.8932 index_layer_15_loss -0.4562 index_layer_18_loss -7.4370
# Epoch 2/10 loss -7.9606 index_layer_15_loss -0.4971 index_layer_18_loss -7.4635
# Epoch 3/10 loss -7.9452 index_layer_15_loss -0.4808 index_layer_18_loss -7.4643
# Epoch 4/10 loss -7.9803 index_layer_15_loss -0.5235 index_layer_18_loss -7.4568
# Epoch 5/10 loss -7.9617 index_layer_15_loss -0.4802 index_layer_18_loss -7.4816
# Epoch 6/10 loss -7.9435 index_layer_15_loss -0.5346 index_layer_18_loss -7.4089
# Epoch 7/10 loss -7.9506 index_layer_15_loss -0.4543 index_layer_18_loss -7.4964
# Epoch 8/10 loss -7.9147 index_layer_15_loss -0.4721 index_layer_18_loss -7.4426
# Epoch 9/10 loss -7.9122 index_layer_15_loss -0.4724 index_layer_18_loss -7.4398
# 27 / 50
# Epoch 0/10 loss -7.9076 index_layer_15_loss -0.4998 index_layer_18_loss -7.4078
# Epoch 1/10 loss -7.9263 index_layer_15_loss -0.4774 index_layer_18_loss -7.4490
# Epoch 2/10 loss -7.9107 index_layer_15_loss -0.4477 index_layer_18_loss -7.4630
# Epoch 3/10 loss -7.9234 index_layer_15_loss -0.4475 index_layer_18_loss -7.4759
# Epoch 4/10 loss -8.0093 index_layer_15_loss -0.5343 index_layer_18_loss -7.4750
# Epoch 5/10 loss -7.9592 index_layer_15_loss -0.4760 index_layer_18_loss -7.4833
# Epoch 6/10 loss -8.0020 index_layer_15_loss -0.4641 index_layer_18_loss -7.5380
# Epoch 7/10 loss -7.9942 index_layer_15_loss -0.5420 index_layer_18_loss -7.4523
# Epoch 8/10 loss -7.9579 index_layer_15_loss -0.5357 index_layer_18_loss -7.4222
# Epoch 9/10 loss -8.0131 index_layer_15_loss -0.5122 index_layer_18_loss -7.5009
# 28 / 50
# Epoch 0/10 loss -7.9307 index_layer_15_loss -0.4770 index_layer_18_loss -7.4537
# Epoch 1/10 loss -7.9100 index_layer_15_loss -0.4547 index_layer_18_loss -7.4553
# Epoch 2/10 loss -7.9278 index_layer_15_loss -0.4602 index_layer_18_loss -7.4676
# Epoch 3/10 loss -7.9565 index_layer_15_loss -0.5058 index_layer_18_loss -7.4507
# Epoch 4/10 loss -7.9329 index_layer_15_loss -0.4909 index_layer_18_loss -7.4420
# Epoch 5/10 loss -7.8914 index_layer_15_loss -0.4489 index_layer_18_loss -7.4425
# Epoch 6/10 loss -8.0238 index_layer_15_loss -0.5082 index_layer_18_loss -7.5156
# Epoch 7/10 loss -7.8956 index_layer_15_loss -0.5062 index_layer_18_loss -7.3894
# Epoch 8/10 loss -7.9650 index_layer_15_loss -0.4979 index_layer_18_loss -7.4671
# Epoch 9/10 loss -7.9400 index_layer_15_loss -0.4825 index_layer_18_loss -7.4575
# 29 / 50
# Epoch 0/10 loss -7.9509 index_layer_15_loss -0.4943 index_layer_18_loss -7.4565
# Epoch 1/10 loss -8.0184 index_layer_15_loss -0.5150 index_layer_18_loss -7.5034
# Epoch 2/10 loss -7.9582 index_layer_15_loss -0.4747 index_layer_18_loss -7.4835
# Epoch 3/10 loss -7.9471 index_layer_15_loss -0.4857 index_layer_18_loss -7.4614
# Epoch 4/10 loss -7.9777 index_layer_15_loss -0.4876 index_layer_18_loss -7.4902
# Epoch 5/10 loss -7.9958 index_layer_15_loss -0.5310 index_layer_18_loss -7.4648
# Epoch 6/10 loss -7.9259 index_layer_15_loss -0.4783 index_layer_18_loss -7.4476
# Epoch 7/10 loss -7.9009 index_layer_15_loss -0.4727 index_layer_18_loss -7.4282
# Epoch 8/10 loss -7.9671 index_layer_15_loss -0.5104 index_layer_18_loss -7.4567
# Epoch 9/10 loss -8.0024 index_layer_15_loss -0.4821 index_layer_18_loss -7.5203
# 30 / 50
# Epoch 0/10 loss -7.8839 index_layer_15_loss -0.4618 index_layer_18_loss -7.4221
# Epoch 1/10 loss -7.9681 index_layer_15_loss -0.5180 index_layer_18_loss -7.4502
# Epoch 2/10 loss -7.9932 index_layer_15_loss -0.5048 index_layer_18_loss -7.4884
# Epoch 3/10 loss -7.9180 index_layer_15_loss -0.4013 index_layer_18_loss -7.5167
# Epoch 4/10 loss -8.0722 index_layer_15_loss -0.5236 index_layer_18_loss -7.5486
# Epoch 5/10 loss -7.8951 index_layer_15_loss -0.4557 index_layer_18_loss -7.4394
# Epoch 6/10 loss -7.9513 index_layer_15_loss -0.4995 index_layer_18_loss -7.4517
# Epoch 7/10 loss -7.9051 index_layer_15_loss -0.4649 index_layer_18_loss -7.4401
# Epoch 8/10 loss -8.0249 index_layer_15_loss -0.5423 index_layer_18_loss -7.4827
# Epoch 9/10 loss -8.0284 index_layer_15_loss -0.5305 index_layer_18_loss -7.4979
# 31 / 50
# Epoch 0/10 loss -7.9489 index_layer_15_loss -0.5087 index_layer_18_loss -7.4402
# Epoch 1/10 loss -7.9373 index_layer_15_loss -0.4877 index_layer_18_loss -7.4496
# Epoch 2/10 loss -7.9437 index_layer_15_loss -0.4992 index_layer_18_loss -7.4445
# Epoch 3/10 loss -7.8788 index_layer_15_loss -0.4499 index_layer_18_loss -7.4290
# Epoch 4/10 loss -7.9865 index_layer_15_loss -0.4783 index_layer_18_loss -7.5082
# Epoch 5/10 loss -7.9229 index_layer_15_loss -0.5144 index_layer_18_loss -7.4084
# Epoch 6/10 loss -7.9605 index_layer_15_loss -0.5262 index_layer_18_loss -7.4343
# Epoch 7/10 loss -7.8934 index_layer_15_loss -0.4622 index_layer_18_loss -7.4313
# Epoch 8/10 loss -7.9852 index_layer_15_loss -0.4821 index_layer_18_loss -7.5031
# Epoch 9/10 loss -7.9435 index_layer_15_loss -0.4939 index_layer_18_loss -7.4496
# 32 / 50
# Epoch 0/10 loss -7.9534 index_layer_15_loss -0.5302 index_layer_18_loss -7.4232
# Epoch 1/10 loss -7.9732 index_layer_15_loss -0.5041 index_layer_18_loss -7.4691
# Epoch 2/10 loss -7.8896 index_layer_15_loss -0.4895 index_layer_18_loss -7.4001
# Epoch 3/10 loss -7.9376 index_layer_15_loss -0.4754 index_layer_18_loss -7.4622
# Epoch 4/10 loss -7.9859 index_layer_15_loss -0.5095 index_layer_18_loss -7.4764
# Epoch 5/10 loss -8.0278 index_layer_15_loss -0.5326 index_layer_18_loss -7.4952
# Epoch 6/10 loss -7.9469 index_layer_15_loss -0.4907 index_layer_18_loss -7.4563
# Epoch 7/10 loss -8.0181 index_layer_15_loss -0.5415 index_layer_18_loss -7.4766
# Epoch 8/10 loss -7.9347 index_layer_15_loss -0.4668 index_layer_18_loss -7.4679
# Epoch 9/10 loss -7.9343 index_layer_15_loss -0.4722 index_layer_18_loss -7.4621
# 33 / 50
# Epoch 0/10 loss -7.9086 index_layer_15_loss -0.4363 index_layer_18_loss -7.4722
# Epoch 1/10 loss -8.0286 index_layer_15_loss -0.5585 index_layer_18_loss -7.4701
# Epoch 2/10 loss -7.9956 index_layer_15_loss -0.5122 index_layer_18_loss -7.4834
# Epoch 3/10 loss -7.9944 index_layer_15_loss -0.5355 index_layer_18_loss -7.4590
# Epoch 4/10 loss -7.9304 index_layer_15_loss -0.4886 index_layer_18_loss -7.4418
# Epoch 5/10 loss -7.9793 index_layer_15_loss -0.4971 index_layer_18_loss -7.4822
# Epoch 6/10 loss -7.8936 index_layer_15_loss -0.4534 index_layer_18_loss -7.4402
# Epoch 7/10 loss -7.9219 index_layer_15_loss -0.5139 index_layer_18_loss -7.4080
# Epoch 8/10 loss -7.9253 index_layer_15_loss -0.4875 index_layer_18_loss -7.4379
# Epoch 9/10 loss -7.9172 index_layer_15_loss -0.4510 index_layer_18_loss -7.4662
# 34 / 50
# Epoch 0/10 loss -7.9949 index_layer_15_loss -0.5132 index_layer_18_loss -7.4816
# Epoch 1/10 loss -7.9980 index_layer_15_loss -0.4893 index_layer_18_loss -7.5087
# Epoch 2/10 loss -8.0306 index_layer_15_loss -0.5241 index_layer_18_loss -7.5065
# Epoch 3/10 loss -7.9600 index_layer_15_loss -0.5059 index_layer_18_loss -7.4540
# Epoch 4/10 loss -7.9838 index_layer_15_loss -0.5346 index_layer_18_loss -7.4492
# Epoch 5/10 loss -8.0518 index_layer_15_loss -0.5133 index_layer_18_loss -7.5385
# Epoch 6/10 loss -7.9497 index_layer_15_loss -0.4795 index_layer_18_loss -7.4702
# Epoch 7/10 loss -7.9102 index_layer_15_loss -0.4709 index_layer_18_loss -7.4393
# Epoch 8/10 loss -7.9125 index_layer_15_loss -0.4469 index_layer_18_loss -7.4656
# Epoch 9/10 loss -8.0211 index_layer_15_loss -0.5373 index_layer_18_loss -7.4838
# 35 / 50
# Epoch 0/10 loss -7.9231 index_layer_15_loss -0.4716 index_layer_18_loss -7.4515
# Epoch 1/10 loss -8.0463 index_layer_15_loss -0.5128 index_layer_18_loss -7.5334
# Epoch 2/10 loss -7.8977 index_layer_15_loss -0.5103 index_layer_18_loss -7.3874
# Epoch 3/10 loss -7.9980 index_layer_15_loss -0.4977 index_layer_18_loss -7.5003
# Epoch 4/10 loss -7.9971 index_layer_15_loss -0.5042 index_layer_18_loss -7.4929
# Epoch 5/10 loss -7.9715 index_layer_15_loss -0.4871 index_layer_18_loss -7.4844
# Epoch 6/10 loss -7.9875 index_layer_15_loss -0.5352 index_layer_18_loss -7.4523
# Epoch 7/10 loss -8.0828 index_layer_15_loss -0.5511 index_layer_18_loss -7.5318
# Epoch 8/10 loss -7.9466 index_layer_15_loss -0.5040 index_layer_18_loss -7.4426
# Epoch 9/10 loss -7.9538 index_layer_15_loss -0.5237 index_layer_18_loss -7.4301
# 36 / 50
# Epoch 0/10 loss -8.0065 index_layer_15_loss -0.5014 index_layer_18_loss -7.5051
# Epoch 1/10 loss -8.0132 index_layer_15_loss -0.5189 index_layer_18_loss -7.4943
# Epoch 2/10 loss -7.9978 index_layer_15_loss -0.4976 index_layer_18_loss -7.5002
# Epoch 3/10 loss -7.9889 index_layer_15_loss -0.5293 index_layer_18_loss -7.4596
# Epoch 4/10 loss -7.9204 index_layer_15_loss -0.4607 index_layer_18_loss -7.4597
# Epoch 5/10 loss -7.9766 index_layer_15_loss -0.5141 index_layer_18_loss -7.4625
# Epoch 6/10 loss -8.0587 index_layer_15_loss -0.5461 index_layer_18_loss -7.5126
# Epoch 7/10 loss -8.0223 index_layer_15_loss -0.5279 index_layer_18_loss -7.4944
# Epoch 8/10 loss -7.9510 index_layer_15_loss -0.5099 index_layer_18_loss -7.4411
# Epoch 9/10 loss -7.9048 index_layer_15_loss -0.4483 index_layer_18_loss -7.4565
# 37 / 50
# Epoch 0/10 loss -7.9997 index_layer_15_loss -0.5307 index_layer_18_loss -7.4690
# Epoch 1/10 loss -7.9909 index_layer_15_loss -0.5430 index_layer_18_loss -7.4479
# Epoch 2/10 loss -7.9699 index_layer_15_loss -0.4864 index_layer_18_loss -7.4834
# Epoch 3/10 loss -7.9189 index_layer_15_loss -0.4827 index_layer_18_loss -7.4362
# Epoch 4/10 loss -7.9232 index_layer_15_loss -0.4978 index_layer_18_loss -7.4255
# Epoch 5/10 loss -7.9879 index_layer_15_loss -0.5416 index_layer_18_loss -7.4463
# Epoch 6/10 loss -7.9876 index_layer_15_loss -0.5195 index_layer_18_loss -7.4681
# Epoch 7/10 loss -8.0123 index_layer_15_loss -0.5341 index_layer_18_loss -7.4782
# Epoch 8/10 loss -7.8918 index_layer_15_loss -0.4820 index_layer_18_loss -7.4099
# Epoch 9/10 loss -7.9829 index_layer_15_loss -0.4991 index_layer_18_loss -7.4838
# 38 / 50
# Epoch 0/10 loss -7.9001 index_layer_15_loss -0.4535 index_layer_18_loss -7.4466
# Epoch 1/10 loss -8.0218 index_layer_15_loss -0.5239 index_layer_18_loss -7.4980
# Epoch 2/10 loss -7.9542 index_layer_15_loss -0.5366 index_layer_18_loss -7.4176
# Epoch 3/10 loss -7.9513 index_layer_15_loss -0.4978 index_layer_18_loss -7.4535
# Epoch 4/10 loss -7.9678 index_layer_15_loss -0.4558 index_layer_18_loss -7.5120
# Epoch 5/10 loss -7.9472 index_layer_15_loss -0.4945 index_layer_18_loss -7.4527
# Epoch 6/10 loss -7.9499 index_layer_15_loss -0.5103 index_layer_18_loss -7.4396
# Epoch 7/10 loss -7.9208 index_layer_15_loss -0.4717 index_layer_18_loss -7.4491
# Epoch 8/10 loss -7.9682 index_layer_15_loss -0.5093 index_layer_18_loss -7.4589
# Epoch 9/10 loss -8.0150 index_layer_15_loss -0.5249 index_layer_18_loss -7.4901
# 39 / 50
# Epoch 0/10 loss -7.9195 index_layer_15_loss -0.4701 index_layer_18_loss -7.4494
# Epoch 1/10 loss -7.9329 index_layer_15_loss -0.5232 index_layer_18_loss -7.4098
# Epoch 2/10 loss -7.9522 index_layer_15_loss -0.4871 index_layer_18_loss -7.4651
# Epoch 3/10 loss -7.9642 index_layer_15_loss -0.4901 index_layer_18_loss -7.4740
# Epoch 4/10 loss -8.0275 index_layer_15_loss -0.5272 index_layer_18_loss -7.5003
# Epoch 5/10 loss -7.9945 index_layer_15_loss -0.5075 index_layer_18_loss -7.4870
# Epoch 6/10 loss -7.9674 index_layer_15_loss -0.5590 index_layer_18_loss -7.4085
# Epoch 7/10 loss -7.9384 index_layer_15_loss -0.5024 index_layer_18_loss -7.4360
# Epoch 8/10 loss -8.0070 index_layer_15_loss -0.5233 index_layer_18_loss -7.4837
# Epoch 9/10 loss -8.0187 index_layer_15_loss -0.5197 index_layer_18_loss -7.4991
# 40 / 50
# Epoch 0/10 loss -7.9385 index_layer_15_loss -0.4828 index_layer_18_loss -7.4557
# Epoch 1/10 loss -7.9590 index_layer_15_loss -0.4982 index_layer_18_loss -7.4608
# Epoch 2/10 loss -7.9826 index_layer_15_loss -0.5119 index_layer_18_loss -7.4706
# Epoch 3/10 loss -7.9831 index_layer_15_loss -0.4824 index_layer_18_loss -7.5007
# Epoch 4/10 loss -7.8949 index_layer_15_loss -0.4625 index_layer_18_loss -7.4324
# Epoch 5/10 loss -7.9520 index_layer_15_loss -0.4508 index_layer_18_loss -7.5012
# Epoch 6/10 loss -7.9472 index_layer_15_loss -0.5246 index_layer_18_loss -7.4225
# Epoch 7/10 loss -7.8307 index_layer_15_loss -0.3913 index_layer_18_loss -7.4394
# Epoch 8/10 loss -7.9104 index_layer_15_loss -0.4781 index_layer_18_loss -7.4323
# Epoch 9/10 loss -8.0016 index_layer_15_loss -0.5059 index_layer_18_loss -7.4957
# 41 / 50
# Epoch 0/10 loss -7.9910 index_layer_15_loss -0.5191 index_layer_18_loss -7.4719
# Epoch 1/10 loss -7.9150 index_layer_15_loss -0.4562 index_layer_18_loss -7.4588
# Epoch 2/10 loss -7.9252 index_layer_15_loss -0.5046 index_layer_18_loss -7.4205
# Epoch 3/10 loss -7.9878 index_layer_15_loss -0.4938 index_layer_18_loss -7.4940
# Epoch 4/10 loss -7.9177 index_layer_15_loss -0.4767 index_layer_18_loss -7.4410
# Epoch 5/10 loss -7.9796 index_layer_15_loss -0.4592 index_layer_18_loss -7.5204
# Epoch 6/10 loss -7.9387 index_layer_15_loss -0.4824 index_layer_18_loss -7.4564
# Epoch 7/10 loss -7.9522 index_layer_15_loss -0.4879 index_layer_18_loss -7.4643
# Epoch 8/10 loss -7.9939 index_layer_15_loss -0.4571 index_layer_18_loss -7.5368
# Epoch 9/10 loss -7.8969 index_layer_15_loss -0.4498 index_layer_18_loss -7.4471
# 42 / 50
# Epoch 0/10 loss -7.9445 index_layer_15_loss -0.5150 index_layer_18_loss -7.4295
# Epoch 1/10 loss -7.9299 index_layer_15_loss -0.4437 index_layer_18_loss -7.4862
# Epoch 2/10 loss -7.9857 index_layer_15_loss -0.5108 index_layer_18_loss -7.4749
# Epoch 3/10 loss -7.9812 index_layer_15_loss -0.5138 index_layer_18_loss -7.4674
# Epoch 4/10 loss -8.0493 index_layer_15_loss -0.4934 index_layer_18_loss -7.5560
# Epoch 5/10 loss -7.9620 index_layer_15_loss -0.5043 index_layer_18_loss -7.4577
# Epoch 6/10 loss -7.9908 index_layer_15_loss -0.4805 index_layer_18_loss -7.5103
# Epoch 7/10 loss -8.0073 index_layer_15_loss -0.4712 index_layer_18_loss -7.5361
# Epoch 8/10 loss -8.0584 index_layer_15_loss -0.5426 index_layer_18_loss -7.5157
# Epoch 9/10 loss -7.9609 index_layer_15_loss -0.4600 index_layer_18_loss -7.5008
# 43 / 50
# Epoch 0/10 loss -8.0175 index_layer_15_loss -0.5214 index_layer_18_loss -7.4961
# Epoch 1/10 loss -7.9189 index_layer_15_loss -0.4936 index_layer_18_loss -7.4253
# Epoch 2/10 loss -7.9704 index_layer_15_loss -0.4916 index_layer_18_loss -7.4788
# Epoch 3/10 loss -7.9972 index_layer_15_loss -0.5010 index_layer_18_loss -7.4962
# Epoch 4/10 loss -8.0291 index_layer_15_loss -0.5190 index_layer_18_loss -7.5100
# Epoch 5/10 loss -7.9521 index_layer_15_loss -0.5016 index_layer_18_loss -7.4505
# Epoch 6/10 loss -7.9730 index_layer_15_loss -0.5033 index_layer_18_loss -7.4697
# Epoch 7/10 loss -8.0548 index_layer_15_loss -0.4997 index_layer_18_loss -7.5551
# Epoch 8/10 loss -8.0198 index_layer_15_loss -0.5491 index_layer_18_loss -7.4707
# Epoch 9/10 loss -8.0037 index_layer_15_loss -0.5271 index_layer_18_loss -7.4766
# 44 / 50
# Epoch 0/10 loss -7.9669 index_layer_15_loss -0.5128 index_layer_18_loss -7.4540
# Epoch 1/10 loss -7.9128 index_layer_15_loss -0.4768 index_layer_18_loss -7.4360
# Epoch 2/10 loss -7.9445 index_layer_15_loss -0.5138 index_layer_18_loss -7.4307
# Epoch 3/10 loss -7.9572 index_layer_15_loss -0.5073 index_layer_18_loss -7.4500
# Epoch 4/10 loss -8.0477 index_layer_15_loss -0.5252 index_layer_18_loss -7.5225
# Epoch 5/10 loss -7.9749 index_layer_15_loss -0.5287 index_layer_18_loss -7.4462
# Epoch 6/10 loss -7.9395 index_layer_15_loss -0.4314 index_layer_18_loss -7.5081
# Epoch 7/10 loss -7.9806 index_layer_15_loss -0.4805 index_layer_18_loss -7.5002
# Epoch 8/10 loss -8.0001 index_layer_15_loss -0.5446 index_layer_18_loss -7.4555
# Epoch 9/10 loss -7.9326 index_layer_15_loss -0.4835 index_layer_18_loss -7.4492
# 45 / 50
# Epoch 0/10 loss -7.9083 index_layer_15_loss -0.4715 index_layer_18_loss -7.4368
# Epoch 1/10 loss -7.8875 index_layer_15_loss -0.4956 index_layer_18_loss -7.3919
# Epoch 2/10 loss -7.9455 index_layer_15_loss -0.4564 index_layer_18_loss -7.4892
# Epoch 3/10 loss -8.0754 index_layer_15_loss -0.5872 index_layer_18_loss -7.4883
# Epoch 4/10 loss -7.8953 index_layer_15_loss -0.4635 index_layer_18_loss -7.4318
# Epoch 5/10 loss -7.9271 index_layer_15_loss -0.4556 index_layer_18_loss -7.4715
# Epoch 6/10 loss -7.9889 index_layer_15_loss -0.5051 index_layer_18_loss -7.4838
# Epoch 7/10 loss -7.9926 index_layer_15_loss -0.4964 index_layer_18_loss -7.4961
# Epoch 8/10 loss -7.9060 index_layer_15_loss -0.4866 index_layer_18_loss -7.4194
# Epoch 9/10 loss -7.9458 index_layer_15_loss -0.4614 index_layer_18_loss -7.4844
# 46 / 50
# Epoch 0/10 loss -7.9773 index_layer_15_loss -0.5016 index_layer_18_loss -7.4757
# Epoch 1/10 loss -8.0508 index_layer_15_loss -0.5256 index_layer_18_loss -7.5252
# Epoch 2/10 loss -7.8765 index_layer_15_loss -0.4406 index_layer_18_loss -7.4359
# Epoch 3/10 loss -7.9469 index_layer_15_loss -0.4712 index_layer_18_loss -7.4757
# Epoch 4/10 loss -7.9432 index_layer_15_loss -0.5215 index_layer_18_loss -7.4217
# Epoch 5/10 loss -7.8975 index_layer_15_loss -0.4646 index_layer_18_loss -7.4329
# Epoch 6/10 loss -7.9571 index_layer_15_loss -0.5062 index_layer_18_loss -7.4509
# Epoch 7/10 loss -7.9693 index_layer_15_loss -0.4825 index_layer_18_loss -7.4868
# Epoch 8/10 loss -7.9332 index_layer_15_loss -0.4628 index_layer_18_loss -7.4704
# Epoch 9/10 loss -7.9845 index_layer_15_loss -0.4770 index_layer_18_loss -7.5076
# 47 / 50
# Epoch 0/10 loss -7.9912 index_layer_15_loss -0.4676 index_layer_18_loss -7.5236
# Epoch 1/10 loss -7.9608 index_layer_15_loss -0.4487 index_layer_18_loss -7.5121
# Epoch 2/10 loss -7.9139 index_layer_15_loss -0.4829 index_layer_18_loss -7.4311
# Epoch 3/10 loss -7.9005 index_layer_15_loss -0.4896 index_layer_18_loss -7.4109
# Epoch 4/10 loss -7.9360 index_layer_15_loss -0.4980 index_layer_18_loss -7.4380
# Epoch 5/10 loss -7.9148 index_layer_15_loss -0.4633 index_layer_18_loss -7.4515
# Epoch 6/10 loss -7.9286 index_layer_15_loss -0.4900 index_layer_18_loss -7.4385
# Epoch 7/10 loss -7.9996 index_layer_15_loss -0.4883 index_layer_18_loss -7.5113
# Epoch 8/10 loss -7.9404 index_layer_15_loss -0.4376 index_layer_18_loss -7.5028
# Epoch 9/10 loss -7.9734 index_layer_15_loss -0.4840 index_layer_18_loss -7.4894
# 48 / 50
# Epoch 0/10 loss -7.8894 index_layer_15_loss -0.4730 index_layer_18_loss -7.4164
# Epoch 1/10 loss -7.8895 index_layer_15_loss -0.4597 index_layer_18_loss -7.4297
# Epoch 2/10 loss -8.0209 index_layer_15_loss -0.4922 index_layer_18_loss -7.5287
# Epoch 3/10 loss -7.9694 index_layer_15_loss -0.4815 index_layer_18_loss -7.4879
# Epoch 4/10 loss -7.9559 index_layer_15_loss -0.4669 index_layer_18_loss -7.4890
# Epoch 5/10 loss -7.8228 index_layer_15_loss -0.4241 index_layer_18_loss -7.3987
# Epoch 6/10 loss -8.0407 index_layer_15_loss -0.4889 index_layer_18_loss -7.5517
# Epoch 7/10 loss -7.9961 index_layer_15_loss -0.5356 index_layer_18_loss -7.4605
# Epoch 8/10 loss -7.9527 index_layer_15_loss -0.4991 index_layer_18_loss -7.4537
# Epoch 9/10 loss -7.9501 index_layer_15_loss -0.4702 index_layer_18_loss -7.4800
# 49 / 50
# Epoch 0/10 loss -7.9236 index_layer_15_loss -0.4589 index_layer_18_loss -7.4647
# Epoch 1/10 loss -7.9742 index_layer_15_loss -0.4654 index_layer_18_loss -7.5088
# Epoch 2/10 loss -7.9571 index_layer_15_loss -0.5039 index_layer_18_loss -7.4532
# Epoch 3/10 loss -8.0297 index_layer_15_loss -0.4971 index_layer_18_loss -7.5326
# Epoch 4/10 loss -8.0014 index_layer_15_loss -0.5444 index_layer_18_loss -7.4569
# Epoch 5/10 loss -7.9663 index_layer_15_loss -0.4836 index_layer_18_loss -7.4828
# Epoch 6/10 loss -7.9699 index_layer_15_loss -0.5240 index_layer_18_loss -7.4459
# Epoch 7/10 loss -8.0566 index_layer_15_loss -0.5187 index_layer_18_loss -7.5379
# Epoch 8/10 loss -8.0113 index_layer_15_loss -0.4916 index_layer_18_loss -7.5197
# Epoch 9/10 loss -8.0054 index_layer_15_loss -0.5001 index_layer_18_loss -7.5053
# 0 / 50
# Epoch 0/10 loss -4.5255 index_layer_21_loss -0.4986 index_layer_24_loss -4.0269
# Epoch 1/10 loss -4.4144 index_layer_21_loss -0.5093 index_layer_24_loss -3.9052
# Epoch 2/10 loss -4.4943 index_layer_21_loss -0.4787 index_layer_24_loss -4.0156
# Epoch 3/10 loss -4.5741 index_layer_21_loss -0.5255 index_layer_24_loss -4.0486
# Epoch 4/10 loss -4.6341 index_layer_21_loss -0.4686 index_layer_24_loss -4.1654
# Epoch 5/10 loss -4.4097 index_layer_21_loss -0.4604 index_layer_24_loss -3.9493
# Epoch 6/10 loss -4.4057 index_layer_21_loss -0.5165 index_layer_24_loss -3.8892
# Epoch 7/10 loss -4.5265 index_layer_21_loss -0.4996 index_layer_24_loss -4.0270
# Epoch 8/10 loss -4.5412 index_layer_21_loss -0.4845 index_layer_24_loss -4.0567
# Epoch 9/10 loss -4.4185 index_layer_21_loss -0.4512 index_layer_24_loss -3.9672
# 1 / 50
# Epoch 0/10 loss -4.5927 index_layer_21_loss -0.4820 index_layer_24_loss -4.1107
# Epoch 1/10 loss -4.5346 index_layer_21_loss -0.5208 index_layer_24_loss -4.0138
# Epoch 2/10 loss -4.6433 index_layer_21_loss -0.4434 index_layer_24_loss -4.1999
# Epoch 3/10 loss -4.4643 index_layer_21_loss -0.5113 index_layer_24_loss -3.9531
# Epoch 4/10 loss -4.6340 index_layer_21_loss -0.5233 index_layer_24_loss -4.1107
# Epoch 5/10 loss -4.7134 index_layer_21_loss -0.5142 index_layer_24_loss -4.1991
# Epoch 6/10 loss -4.5230 index_layer_21_loss -0.4560 index_layer_24_loss -4.0670
# Epoch 7/10 loss -4.5940 index_layer_21_loss -0.4998 index_layer_24_loss -4.0942
# Epoch 8/10 loss -4.5481 index_layer_21_loss -0.5035 index_layer_24_loss -4.0447
# Epoch 9/10 loss -4.5178 index_layer_21_loss -0.4706 index_layer_24_loss -4.0471
# 2 / 50
# Epoch 0/10 loss -4.6961 index_layer_21_loss -0.5371 index_layer_24_loss -4.1589
# Epoch 1/10 loss -4.6842 index_layer_21_loss -0.4968 index_layer_24_loss -4.1874
# Epoch 2/10 loss -4.6032 index_layer_21_loss -0.4800 index_layer_24_loss -4.1232
# Epoch 3/10 loss -4.5949 index_layer_21_loss -0.5351 index_layer_24_loss -4.0598
# Epoch 4/10 loss -4.5931 index_layer_21_loss -0.4496 index_layer_24_loss -4.1435
# Epoch 5/10 loss -4.6616 index_layer_21_loss -0.4956 index_layer_24_loss -4.1661
# Epoch 6/10 loss -4.7128 index_layer_21_loss -0.5089 index_layer_24_loss -4.2039
# Epoch 7/10 loss -4.5982 index_layer_21_loss -0.4397 index_layer_24_loss -4.1585
# Epoch 8/10 loss -4.5089 index_layer_21_loss -0.4638 index_layer_24_loss -4.0451
# Epoch 9/10 loss -4.6683 index_layer_21_loss -0.5541 index_layer_24_loss -4.1142
# 3 / 50
# Epoch 0/10 loss -4.7244 index_layer_21_loss -0.5611 index_layer_24_loss -4.1634
# Epoch 1/10 loss -4.6360 index_layer_21_loss -0.5202 index_layer_24_loss -4.1158
# Epoch 2/10 loss -4.7544 index_layer_21_loss -0.5692 index_layer_24_loss -4.1852
# Epoch 3/10 loss -4.7465 index_layer_21_loss -0.5471 index_layer_24_loss -4.1994
# Epoch 4/10 loss -4.6457 index_layer_21_loss -0.4497 index_layer_24_loss -4.1960
# Epoch 5/10 loss -4.5228 index_layer_21_loss -0.4764 index_layer_24_loss -4.0464
# Epoch 6/10 loss -4.6421 index_layer_21_loss -0.4283 index_layer_24_loss -4.2138
# Epoch 7/10 loss -4.5793 index_layer_21_loss -0.4630 index_layer_24_loss -4.1163
# Epoch 8/10 loss -4.6124 index_layer_21_loss -0.4824 index_layer_24_loss -4.1300
# Epoch 9/10 loss -4.7353 index_layer_21_loss -0.5032 index_layer_24_loss -4.2321
# 4 / 50
# Epoch 0/10 loss -4.5947 index_layer_21_loss -0.4674 index_layer_24_loss -4.1274
# Epoch 1/10 loss -4.6761 index_layer_21_loss -0.5151 index_layer_24_loss -4.1611
# Epoch 2/10 loss -4.5725 index_layer_21_loss -0.4697 index_layer_24_loss -4.1028
# Epoch 3/10 loss -4.6831 index_layer_21_loss -0.4584 index_layer_24_loss -4.2247
# Epoch 4/10 loss -4.6457 index_layer_21_loss -0.4352 index_layer_24_loss -4.2105
# Epoch 5/10 loss -4.6453 index_layer_21_loss -0.5111 index_layer_24_loss -4.1342
# Epoch 6/10 loss -4.6440 index_layer_21_loss -0.4638 index_layer_24_loss -4.1802
# Epoch 7/10 loss -4.7407 index_layer_21_loss -0.5057 index_layer_24_loss -4.2349
# Epoch 8/10 loss -4.6442 index_layer_21_loss -0.4541 index_layer_24_loss -4.1902
# Epoch 9/10 loss -4.6345 index_layer_21_loss -0.4651 index_layer_24_loss -4.1694
# 5 / 50
# Epoch 0/10 loss -4.6395 index_layer_21_loss -0.4976 index_layer_24_loss -4.1419
# Epoch 1/10 loss -4.4923 index_layer_21_loss -0.4289 index_layer_24_loss -4.0634
# Epoch 2/10 loss -4.6585 index_layer_21_loss -0.4789 index_layer_24_loss -4.1796
# Epoch 3/10 loss -4.7104 index_layer_21_loss -0.4797 index_layer_24_loss -4.2308
# Epoch 4/10 loss -4.6928 index_layer_21_loss -0.4550 index_layer_24_loss -4.2378
# Epoch 5/10 loss -4.7070 index_layer_21_loss -0.4571 index_layer_24_loss -4.2500
# Epoch 6/10 loss -4.6582 index_layer_21_loss -0.4921 index_layer_24_loss -4.1662
# Epoch 7/10 loss -4.6872 index_layer_21_loss -0.5049 index_layer_24_loss -4.1824
# Epoch 8/10 loss -4.7052 index_layer_21_loss -0.4926 index_layer_24_loss -4.2127
# Epoch 9/10 loss -4.7099 index_layer_21_loss -0.5043 index_layer_24_loss -4.2056
# 6 / 50
# Epoch 0/10 loss -4.7366 index_layer_21_loss -0.4969 index_layer_24_loss -4.2398
# Epoch 1/10 loss -4.6566 index_layer_21_loss -0.4775 index_layer_24_loss -4.1791
# Epoch 2/10 loss -4.7386 index_layer_21_loss -0.4879 index_layer_24_loss -4.2507
# Epoch 3/10 loss -4.7145 index_layer_21_loss -0.5339 index_layer_24_loss -4.1806
# Epoch 4/10 loss -4.7505 index_layer_21_loss -0.5187 index_layer_24_loss -4.2318
# Epoch 5/10 loss -4.7308 index_layer_21_loss -0.4958 index_layer_24_loss -4.2350
# Epoch 6/10 loss -4.6994 index_layer_21_loss -0.5056 index_layer_24_loss -4.1937
# Epoch 7/10 loss -4.7124 index_layer_21_loss -0.5002 index_layer_24_loss -4.2123
# Epoch 8/10 loss -4.5716 index_layer_21_loss -0.4703 index_layer_24_loss -4.1012
# Epoch 9/10 loss -4.6941 index_layer_21_loss -0.4550 index_layer_24_loss -4.2391
# 7 / 50
# Epoch 0/10 loss -4.7137 index_layer_21_loss -0.5133 index_layer_24_loss -4.2004
# Epoch 1/10 loss -4.6758 index_layer_21_loss -0.4443 index_layer_24_loss -4.2315
# Epoch 2/10 loss -4.7082 index_layer_21_loss -0.5373 index_layer_24_loss -4.1708
# Epoch 3/10 loss -4.6978 index_layer_21_loss -0.4868 index_layer_24_loss -4.2110
# Epoch 4/10 loss -4.7277 index_layer_21_loss -0.5127 index_layer_24_loss -4.2150
# Epoch 5/10 loss -4.6915 index_layer_21_loss -0.4515 index_layer_24_loss -4.2400
# Epoch 6/10 loss -4.6769 index_layer_21_loss -0.4711 index_layer_24_loss -4.2058
# Epoch 7/10 loss -4.6649 index_layer_21_loss -0.4872 index_layer_24_loss -4.1778
# Epoch 8/10 loss -4.7004 index_layer_21_loss -0.5333 index_layer_24_loss -4.1672
# Epoch 9/10 loss -4.7031 index_layer_21_loss -0.4711 index_layer_24_loss -4.2320
# 8 / 50
# Epoch 0/10 loss -4.6529 index_layer_21_loss -0.4462 index_layer_24_loss -4.2067
# Epoch 1/10 loss -4.6867 index_layer_21_loss -0.4413 index_layer_24_loss -4.2454
# Epoch 2/10 loss -4.7548 index_layer_21_loss -0.4779 index_layer_24_loss -4.2768
# Epoch 3/10 loss -4.6341 index_layer_21_loss -0.4428 index_layer_24_loss -4.1913
# Epoch 4/10 loss -4.6973 index_layer_21_loss -0.4882 index_layer_24_loss -4.2091
# Epoch 5/10 loss -4.6106 index_layer_21_loss -0.5008 index_layer_24_loss -4.1098
# Epoch 6/10 loss -4.6097 index_layer_21_loss -0.5128 index_layer_24_loss -4.0970
# ...
# Epoch 5/10 loss -4.7530 index_layer_21_loss -0.4668 index_layer_24_loss -4.2861
# Epoch 6/10 loss -4.7625 index_layer_21_loss -0.5201 index_layer_24_loss -4.2424
# Epoch 7/10 loss -4.8326 index_layer_21_loss -0.5258 index_layer_24_loss -4.3069
# Epoch 8/10 loss -4.7122 index_layer_21_loss -0.5058 index_layer_24_loss -4.2064
# Epoch 9/10 loss -4.8505 index_layer_21_loss -0.5493 index_layer_24_loss -4.3012
# 31 / 50
# Epoch 0/10 loss -4.7189 index_layer_21_loss -0.4422 index_layer_24_loss -4.2767
# Epoch 1/10 loss -4.8201 index_layer_21_loss -0.5136 index_layer_24_loss -4.3065
# Epoch 2/10 loss -4.8538 index_layer_21_loss -0.4929 index_layer_24_loss -4.3609
# Epoch 3/10 loss -4.8275 index_layer_21_loss -0.5072 index_layer_24_loss -4.3203
# Epoch 4/10 loss -4.8055 index_layer_21_loss -0.4991 index_layer_24_loss -4.3064
# Epoch 5/10 loss -4.8055 index_layer_21_loss -0.5237 index_layer_24_loss -4.2817
# Epoch 6/10 loss -4.7064 index_layer_21_loss -0.4649 index_layer_24_loss -4.2415
# Epoch 7/10 loss -4.7604 index_layer_21_loss -0.5039 index_layer_24_loss -4.2565
# Epoch 8/10 loss -4.7235 index_layer_21_loss -0.4613 index_layer_24_loss -4.2622
# Epoch 9/10 loss -4.7384 index_layer_21_loss -0.5063 index_layer_24_loss -4.2320
# 32 / 50
# Epoch 0/10 loss -4.8305 index_layer_21_loss -0.5446 index_layer_24_loss -4.2859
# Epoch 1/10 loss -4.7648 index_layer_21_loss -0.4445 index_layer_24_loss -4.3203
# Epoch 2/10 loss -4.7771 index_layer_21_loss -0.4885 index_layer_24_loss -4.2886
# Epoch 3/10 loss -4.7836 index_layer_21_loss -0.5038 index_layer_24_loss -4.2797
# Epoch 4/10 loss -4.8043 index_layer_21_loss -0.5138 index_layer_24_loss -4.2905
# Epoch 5/10 loss -4.8227 index_layer_21_loss -0.5365 index_layer_24_loss -4.2862
# Epoch 6/10 loss -4.7940 index_layer_21_loss -0.4794 index_layer_24_loss -4.3146
# Epoch 7/10 loss -4.8087 index_layer_21_loss -0.4894 index_layer_24_loss -4.3193
# Epoch 8/10 loss -4.7817 index_layer_21_loss -0.5292 index_layer_24_loss -4.2525
# Epoch 9/10 loss -4.7597 index_layer_21_loss -0.4520 index_layer_24_loss -4.3077
# 33 / 50
# Epoch 0/10 loss -4.7762 index_layer_21_loss -0.5051 index_layer_24_loss -4.2711
# Epoch 1/10 loss -4.7998 index_layer_21_loss -0.4992 index_layer_24_loss -4.3006
# Epoch 2/10 loss -4.7520 index_layer_21_loss -0.5134 index_layer_24_loss -4.2386
# Epoch 3/10 loss -4.8611 index_layer_21_loss -0.5377 index_layer_24_loss -4.3234
# Epoch 4/10 loss -4.7668 index_layer_21_loss -0.4650 index_layer_24_loss -4.3018
# Epoch 5/10 loss -4.8497 index_layer_21_loss -0.5303 index_layer_24_loss -4.3193
# Epoch 6/10 loss -4.7302 index_layer_21_loss -0.4421 index_layer_24_loss -4.2881
# Epoch 7/10 loss -4.7113 index_layer_21_loss -0.4356 index_layer_24_loss -4.2758
# Epoch 8/10 loss -4.8344 index_layer_21_loss -0.4889 index_layer_24_loss -4.3454
# Epoch 9/10 loss -4.7845 index_layer_21_loss -0.5515 index_layer_24_loss -4.2330
# 34 / 50
# Epoch 0/10 loss -4.7741 index_layer_21_loss -0.4807 index_layer_24_loss -4.2934
# Epoch 1/10 loss -4.7882 index_layer_21_loss -0.5175 index_layer_24_loss -4.2707
# Epoch 2/10 loss -4.8071 index_layer_21_loss -0.5054 index_layer_24_loss -4.3017
# Epoch 3/10 loss -4.7705 index_layer_21_loss -0.4708 index_layer_24_loss -4.2996
# Epoch 4/10 loss -4.8156 index_layer_21_loss -0.5005 index_layer_24_loss -4.3151
# Epoch 5/10 loss -4.8292 index_layer_21_loss -0.5310 index_layer_24_loss -4.2982
# Epoch 6/10 loss -4.7559 index_layer_21_loss -0.4813 index_layer_24_loss -4.2746
# Epoch 7/10 loss -4.7330 index_layer_21_loss -0.4981 index_layer_24_loss -4.2348
# Epoch 8/10 loss -4.7184 index_layer_21_loss -0.4680 index_layer_24_loss -4.2504
# Epoch 9/10 loss -4.7714 index_layer_21_loss -0.4671 index_layer_24_loss -4.3043
# 35 / 50
# Epoch 0/10 loss -4.6389 index_layer_21_loss -0.4279 index_layer_24_loss -4.2110
# Epoch 1/10 loss -4.7790 index_layer_21_loss -0.5298 index_layer_24_loss -4.2492
# Epoch 2/10 loss -4.8488 index_layer_21_loss -0.5229 index_layer_24_loss -4.3260
# Epoch 3/10 loss -4.7825 index_layer_21_loss -0.5070 index_layer_24_loss -4.2756
# Epoch 4/10 loss -4.7773 index_layer_21_loss -0.5114 index_layer_24_loss -4.2659
# Epoch 5/10 loss -4.8444 index_layer_21_loss -0.5583 index_layer_24_loss -4.2861
# Epoch 6/10 loss -4.7171 index_layer_21_loss -0.4566 index_layer_24_loss -4.2605
# Epoch 7/10 loss -4.8073 index_layer_21_loss -0.5363 index_layer_24_loss -4.2710
# Epoch 8/10 loss -4.7208 index_layer_21_loss -0.4810 index_layer_24_loss -4.2398
# Epoch 9/10 loss -4.7547 index_layer_21_loss -0.4836 index_layer_24_loss -4.2710
# 36 / 50
# Epoch 0/10 loss -4.7119 index_layer_21_loss -0.4366 index_layer_24_loss -4.2753
# Epoch 1/10 loss -4.7739 index_layer_21_loss -0.5215 index_layer_24_loss -4.2524
# Epoch 2/10 loss -4.7904 index_layer_21_loss -0.4988 index_layer_24_loss -4.2915
# Epoch 3/10 loss -4.7435 index_layer_21_loss -0.4433 index_layer_24_loss -4.3002
# Epoch 4/10 loss -4.7596 index_layer_21_loss -0.4684 index_layer_24_loss -4.2912
# Epoch 5/10 loss -4.7396 index_layer_21_loss -0.4970 index_layer_24_loss -4.2426
# Epoch 6/10 loss -4.7361 index_layer_21_loss -0.4507 index_layer_24_loss -4.2855
# Epoch 7/10 loss -4.8068 index_layer_21_loss -0.5410 index_layer_24_loss -4.2658
# Epoch 8/10 loss -4.7909 index_layer_21_loss -0.4918 index_layer_24_loss -4.2991
# Epoch 9/10 loss -4.8040 index_layer_21_loss -0.5090 index_layer_24_loss -4.2951
# 37 / 50
# Epoch 0/10 loss -4.7661 index_layer_21_loss -0.4456 index_layer_24_loss -4.3205
# Epoch 1/10 loss -4.7942 index_layer_21_loss -0.4826 index_layer_24_loss -4.3116
# Epoch 2/10 loss -4.8125 index_layer_21_loss -0.5406 index_layer_24_loss -4.2719
# Epoch 3/10 loss -4.8275 index_layer_21_loss -0.4786 index_layer_24_loss -4.3489
# Epoch 4/10 loss -4.7314 index_layer_21_loss -0.4885 index_layer_24_loss -4.2429
# Epoch 5/10 loss -4.7861 index_layer_21_loss -0.4957 index_layer_24_loss -4.2904
# Epoch 6/10 loss -4.7801 index_layer_21_loss -0.5027 index_layer_24_loss -4.2774
# Epoch 7/10 loss -4.7963 index_layer_21_loss -0.5317 index_layer_24_loss -4.2646
# Epoch 8/10 loss -4.7872 index_layer_21_loss -0.5198 index_layer_24_loss -4.2674
# Epoch 9/10 loss -4.7933 index_layer_21_loss -0.4984 index_layer_24_loss -4.2949
# 38 / 50
# Epoch 0/10 loss -4.7466 index_layer_21_loss -0.4730 index_layer_24_loss -4.2736
# Epoch 1/10 loss -4.7952 index_layer_21_loss -0.5100 index_layer_24_loss -4.2853
# Epoch 2/10 loss -4.8073 index_layer_21_loss -0.5178 index_layer_24_loss -4.2895
# Epoch 3/10 loss -4.8230 index_layer_21_loss -0.4941 index_layer_24_loss -4.3289
# Epoch 4/10 loss -4.8184 index_layer_21_loss -0.4749 index_layer_24_loss -4.3435
# Epoch 5/10 loss -4.7149 index_layer_21_loss -0.3895 index_layer_24_loss -4.3254
# Epoch 6/10 loss -4.8534 index_layer_21_loss -0.5416 index_layer_24_loss -4.3118
# Epoch 7/10 loss -4.8100 index_layer_21_loss -0.4774 index_layer_24_loss -4.3326
# Epoch 8/10 loss -4.7178 index_layer_21_loss -0.4675 index_layer_24_loss -4.2502
# Epoch 9/10 loss -4.7045 index_layer_21_loss -0.4434 index_layer_24_loss -4.2611
# 39 / 50
# Epoch 0/10 loss -4.7813 index_layer_21_loss -0.5270 index_layer_24_loss -4.2543
# Epoch 1/10 loss -4.7805 index_layer_21_loss -0.4962 index_layer_24_loss -4.2843
# Epoch 2/10 loss -4.7810 index_layer_21_loss -0.4511 index_layer_24_loss -4.3299
# Epoch 3/10 loss -4.8210 index_layer_21_loss -0.4901 index_layer_24_loss -4.3308
# Epoch 4/10 loss -4.6566 index_layer_21_loss -0.4883 index_layer_24_loss -4.1684
# Epoch 5/10 loss -4.8332 index_layer_21_loss -0.5059 index_layer_24_loss -4.3273
# Epoch 6/10 loss -4.7947 index_layer_21_loss -0.5009 index_layer_24_loss -4.2938
# Epoch 7/10 loss -4.7071 index_layer_21_loss -0.4634 index_layer_24_loss -4.2437
# Epoch 8/10 loss -4.7537 index_layer_21_loss -0.5107 index_layer_24_loss -4.2430
# Epoch 9/10 loss -4.7288 index_layer_21_loss -0.4583 index_layer_24_loss -4.2704
# 40 / 50
# Epoch 0/10 loss -4.7292 index_layer_21_loss -0.5002 index_layer_24_loss -4.2290
# Epoch 1/10 loss -4.7850 index_layer_21_loss -0.5294 index_layer_24_loss -4.2556
# Epoch 2/10 loss -4.7879 index_layer_21_loss -0.5063 index_layer_24_loss -4.2817
# Epoch 3/10 loss -4.8162 index_layer_21_loss -0.5003 index_layer_24_loss -4.3159
# Epoch 4/10 loss -4.7752 index_layer_21_loss -0.5426 index_layer_24_loss -4.2326
# Epoch 5/10 loss -4.7866 index_layer_21_loss -0.5237 index_layer_24_loss -4.2629
# Epoch 6/10 loss -4.7206 index_layer_21_loss -0.4724 index_layer_24_loss -4.2482
# Epoch 7/10 loss -4.7324 index_layer_21_loss -0.4558 index_layer_24_loss -4.2766
# Epoch 8/10 loss -4.7913 index_layer_21_loss -0.5123 index_layer_24_loss -4.2790
# Epoch 9/10 loss -4.8290 index_layer_21_loss -0.5095 index_layer_24_loss -4.3195
# 41 / 50
# Epoch 0/10 loss -4.7941 index_layer_21_loss -0.4781 index_layer_24_loss -4.3160
# Epoch 1/10 loss -4.8092 index_layer_21_loss -0.5170 index_layer_24_loss -4.2922
# Epoch 2/10 loss -4.8371 index_layer_21_loss -0.4806 index_layer_24_loss -4.3566
# Epoch 3/10 loss -4.7533 index_layer_21_loss -0.4469 index_layer_24_loss -4.3063
# Epoch 4/10 loss -4.8034 index_layer_21_loss -0.5197 index_layer_24_loss -4.2836
# Epoch 5/10 loss -4.7953 index_layer_21_loss -0.5420 index_layer_24_loss -4.2533
# Epoch 6/10 loss -4.7924 index_layer_21_loss -0.4603 index_layer_24_loss -4.3321
# Epoch 7/10 loss -4.7205 index_layer_21_loss -0.4663 index_layer_24_loss -4.2542
# Epoch 8/10 loss -4.8652 index_layer_21_loss -0.5318 index_layer_24_loss -4.3335
# Epoch 9/10 loss -4.7653 index_layer_21_loss -0.4721 index_layer_24_loss -4.2932
# 42 / 50
# Epoch 0/10 loss -4.8583 index_layer_21_loss -0.5112 index_layer_24_loss -4.3471
# Epoch 1/10 loss -4.8390 index_layer_21_loss -0.5480 index_layer_24_loss -4.2910
# Epoch 2/10 loss -4.8077 index_layer_21_loss -0.5002 index_layer_24_loss -4.3076
# Epoch 3/10 loss -4.7293 index_layer_21_loss -0.4953 index_layer_24_loss -4.2340
# Epoch 4/10 loss -4.7142 index_layer_21_loss -0.4657 index_layer_24_loss -4.2485
# Epoch 5/10 loss -4.7716 index_layer_21_loss -0.4661 index_layer_24_loss -4.3054
# Epoch 6/10 loss -4.8534 index_layer_21_loss -0.4844 index_layer_24_loss -4.3690
# Epoch 7/10 loss -4.7658 index_layer_21_loss -0.4859 index_layer_24_loss -4.2799
# Epoch 8/10 loss -4.7705 index_layer_21_loss -0.4663 index_layer_24_loss -4.3042
# Epoch 9/10 loss -4.7292 index_layer_21_loss -0.4418 index_layer_24_loss -4.2874
# 43 / 50
# Epoch 0/10 loss -4.8051 index_layer_21_loss -0.5031 index_layer_24_loss -4.3020
# Epoch 1/10 loss -4.7529 index_layer_21_loss -0.4740 index_layer_24_loss -4.2789
# Epoch 2/10 loss -4.7664 index_layer_21_loss -0.4341 index_layer_24_loss -4.3323
# Epoch 3/10 loss -4.8173 index_layer_21_loss -0.5014 index_layer_24_loss -4.3159
# Epoch 4/10 loss -4.7326 index_layer_21_loss -0.4819 index_layer_24_loss -4.2507
# Epoch 5/10 loss -4.7530 index_layer_21_loss -0.4650 index_layer_24_loss -4.2880
# Epoch 6/10 loss -4.7533 index_layer_21_loss -0.5015 index_layer_24_loss -4.2518
# Epoch 7/10 loss -4.7366 index_layer_21_loss -0.4884 index_layer_24_loss -4.2482
# Epoch 8/10 loss -4.8081 index_layer_21_loss -0.4735 index_layer_24_loss -4.3347
# Epoch 9/10 loss -4.7724 index_layer_21_loss -0.4600 index_layer_24_loss -4.3124
# 44 / 50
# Epoch 0/10 loss -4.8101 index_layer_21_loss -0.5066 index_layer_24_loss -4.3034
# Epoch 1/10 loss -4.8274 index_layer_21_loss -0.5140 index_layer_24_loss -4.3134
# Epoch 2/10 loss -4.7292 index_layer_21_loss -0.4712 index_layer_24_loss -4.2580
# Epoch 3/10 loss -4.8518 index_layer_21_loss -0.5077 index_layer_24_loss -4.3441
# Epoch 4/10 loss -4.7946 index_layer_21_loss -0.5311 index_layer_24_loss -4.2635
# Epoch 5/10 loss -4.6926 index_layer_21_loss -0.4510 index_layer_24_loss -4.2416
# Epoch 6/10 loss -4.7245 index_layer_21_loss -0.4588 index_layer_24_loss -4.2657
# Epoch 7/10 loss -4.7910 index_layer_21_loss -0.4531 index_layer_24_loss -4.3379
# Epoch 8/10 loss -4.8202 index_layer_21_loss -0.4766 index_layer_24_loss -4.3436
# Epoch 9/10 loss -4.8205 index_layer_21_loss -0.4756 index_layer_24_loss -4.3449
# 45 / 50
# Epoch 0/10 loss -4.7694 index_layer_21_loss -0.4958 index_layer_24_loss -4.2736
# Epoch 1/10 loss -4.7548 index_layer_21_loss -0.4544 index_layer_24_loss -4.3004
# Epoch 2/10 loss -4.7957 index_layer_21_loss -0.4673 index_layer_24_loss -4.3285
# Epoch 3/10 loss -4.7444 index_layer_21_loss -0.4530 index_layer_24_loss -4.2914
# Epoch 4/10 loss -4.7969 index_layer_21_loss -0.4988 index_layer_24_loss -4.2981
# Epoch 5/10 loss -4.8153 index_layer_21_loss -0.4180 index_layer_24_loss -4.3972
# Epoch 6/10 loss -4.8211 index_layer_21_loss -0.4738 index_layer_24_loss -4.3473
# Epoch 7/10 loss -4.7857 index_layer_21_loss -0.4912 index_layer_24_loss -4.2945
# Epoch 8/10 loss -4.7469 index_layer_21_loss -0.4548 index_layer_24_loss -4.2921
# Epoch 9/10 loss -4.8666 index_layer_21_loss -0.5070 index_layer_24_loss -4.3596
# 46 / 50
# Epoch 0/10 loss -4.7898 index_layer_21_loss -0.5004 index_layer_24_loss -4.2894
# Epoch 1/10 loss -4.8365 index_layer_21_loss -0.5120 index_layer_24_loss -4.3244
# Epoch 2/10 loss -4.8475 index_layer_21_loss -0.5385 index_layer_24_loss -4.3090
# Epoch 3/10 loss -4.7770 index_layer_21_loss -0.4971 index_layer_24_loss -4.2799
# Epoch 4/10 loss -4.7840 index_layer_21_loss -0.4946 index_layer_24_loss -4.2894
# Epoch 5/10 loss -4.8464 index_layer_21_loss -0.5329 index_layer_24_loss -4.3134
# Epoch 6/10 loss -4.7494 index_layer_21_loss -0.4891 index_layer_24_loss -4.2603
# Epoch 7/10 loss -4.7462 index_layer_21_loss -0.4416 index_layer_24_loss -4.3045
# Epoch 8/10 loss -4.7919 index_layer_21_loss -0.4924 index_layer_24_loss -4.2995
# Epoch 9/10 loss -4.7904 index_layer_21_loss -0.4931 index_layer_24_loss -4.2973
# 47 / 50
# Epoch 0/10 loss -4.7863 index_layer_21_loss -0.4609 index_layer_24_loss -4.3254
# Epoch 1/10 loss -4.7576 index_layer_21_loss -0.5129 index_layer_24_loss -4.2447
# Epoch 2/10 loss -4.8068 index_layer_21_loss -0.4990 index_layer_24_loss -4.3077
# Epoch 3/10 loss -4.7769 index_layer_21_loss -0.4903 index_layer_24_loss -4.2866
# Epoch 4/10 loss -4.7897 index_layer_21_loss -0.5230 index_layer_24_loss -4.2667
# Epoch 5/10 loss -4.6947 index_layer_21_loss -0.4105 index_layer_24_loss -4.2843
# Epoch 6/10 loss -4.8415 index_layer_21_loss -0.4756 index_layer_24_loss -4.3660
# Epoch 7/10 loss -4.8452 index_layer_21_loss -0.4965 index_layer_24_loss -4.3487
# Epoch 8/10 loss -4.8103 index_layer_21_loss -0.4960 index_layer_24_loss -4.3143
# Epoch 9/10 loss -4.8108 index_layer_21_loss -0.4777 index_layer_24_loss -4.3331
# 48 / 50
# Epoch 0/10 loss -4.8487 index_layer_21_loss -0.4858 index_layer_24_loss -4.3629
# Epoch 1/10 loss -4.7876 index_layer_21_loss -0.4741 index_layer_24_loss -4.3136
# Epoch 2/10 loss -4.7860 index_layer_21_loss -0.5138 index_layer_24_loss -4.2723
# Epoch 3/10 loss -4.7724 index_layer_21_loss -0.4775 index_layer_24_loss -4.2949
# Epoch 4/10 loss -4.7728 index_layer_21_loss -0.4878 index_layer_24_loss -4.2850
# Epoch 5/10 loss -4.8709 index_layer_21_loss -0.5192 index_layer_24_loss -4.3517
# Epoch 6/10 loss -4.8055 index_layer_21_loss -0.5295 index_layer_24_loss -4.2761
# Epoch 7/10 loss -4.8934 index_layer_21_loss -0.5154 index_layer_24_loss -4.3780
# Epoch 8/10 loss -4.7985 index_layer_21_loss -0.4718 index_layer_24_loss -4.3267
# Epoch 9/10 loss -4.7548 index_layer_21_loss -0.5072 index_layer_24_loss -4.2475
# 49 / 50
# Epoch 0/10 loss -4.7977 index_layer_21_loss -0.4903 index_layer_24_loss -4.3073
# Epoch 1/10 loss -4.7301 index_layer_21_loss -0.4136 index_layer_24_loss -4.3165
# Epoch 2/10 loss -4.7744 index_layer_21_loss -0.4761 index_layer_24_loss -4.2983
# Epoch 3/10 loss -4.7760 index_layer_21_loss -0.5230 index_layer_24_loss -4.2530
# Epoch 4/10 loss -4.8308 index_layer_21_loss -0.5031 index_layer_24_loss -4.3277
# Epoch 5/10 loss -4.8109 index_layer_21_loss -0.4739 index_layer_24_loss -4.3370
# Epoch 6/10 loss -4.7783 index_layer_21_loss -0.5311 index_layer_24_loss -4.2472
# Epoch 7/10 loss -4.8249 index_layer_21_loss -0.4969 index_layer_24_loss -4.3280
# Epoch 8/10 loss -4.7435 index_layer_21_loss -0.4647 index_layer_24_loss -4.2788
# Epoch 9/10 loss -4.7448 index_layer_21_loss -0.4515 index_layer_24_loss -4.2934

# %%
F1_by_temp = np.hstack([F1_ML_by_temp, F1_KL_by_temp])
F2_by_temp = np.hstack([F2_ML_by_temp, F2_KL_by_temp])
dF_temp05 = (F2_by_temp-F1_by_temp)[7]
dF_temp10 = (F2_by_temp-F1_by_temp)[10]
dF_temp20 = (F2_by_temp-F1_by_temp)[14]

# %%
plt.figure(figsize=(5, 4))
dF_temp05_runningmean = dF_running_mean(dF_temp05, window=1000, step=10, dF_cut=10)
dF_temp10_runningmean = dF_running_mean(dF_temp10, window=1000, step=10, dF_cut=10)
dF_temp20_runningmean = dF_running_mean(dF_temp20, window=1000, step=10, dF_cut=10)
xrange = np.linspace(0, 700, len(dF_temp10_runningmean))

plt.plot([xrange[0], xrange[-1]], [dFs_ref[7], dFs_ref[7]], color='black', linewidth=3, label='Exact value')
plt.plot([xrange[0], xrange[-1]], [dFs_ref[10], dFs_ref[10]], color='black', linewidth=3)
plt.plot([xrange[0], xrange[-1]], [dFs_ref[14], dFs_ref[14]], color='black', linewidth=3)
plt.plot(xrange, dF_temp05_runningmean, linewidth=3, color='#007700', label='0.5 $T_0$')
plt.plot(xrange, dF_temp10_runningmean, linewidth=3, color='#00AA00', label='1.0 $T_0$')
plt.plot(xrange, dF_temp20_runningmean, linewidth=3, color='#00FF00', label='2.0 $T_0$')
plt.legend(loc='upper center', ncol=2, frameon=False)
plt.xlabel('Training iterations')
plt.ylabel('Free energy difference / $kT_0$')
plt.ylim(0, 10)
#plt.savefig(paper_dir + 'figs/double_well/free_energy_2BGs_conv.pdf', bbox_inches='tight', transparent=True)
# Out:
# (0, 10)

# %%
dFs_direct = []
for t, T in enumerate(temperatures_analysis):
    dF_direct = (F2_by_temp-F1_by_temp)[t][20000:]# (Ex_by_temp2[t]/T - Jzx_by_temp2[t]) - (Ex_by_temp1[t]/T - Jzx_by_temp1[t])
    #dF_direct = (Ex_by_temp2[t] - Jzx_by_temp2[t]) - (Ex_by_temp1[t] - Jzx_by_temp1[t])
    #dF_direct /= T
    dFs_direct.append(dF_direct)
dFs_direct = np.array(dFs_direct)

# %%
plt.plot(dFs_direct[10])

# %%
# bootstrap estimates
niter=100
N = dFs_direct.shape[1]
dFs_direct_bs = [dFs_direct[:, np.random.choice(N, size=N, replace=True)] for i in range(10)]
means = np.mean(dFs_direct, axis=1)
#uncertainties = np.std(np.mean(np.array(dFs_direct_bs), axis=2), axis=0)
uncertainties = np.std(dFs_direct, axis=1) / np.sqrt(niter)

# %%
plt.figure(figsize=(5, 4))
#plt.errorbar(temperatures_analysis, means, 2.0*uncertainties,
#             color='green', linewidth=1, label='BG estimate')
plt.plot(temperatures_analysis, means, linewidth=2, color='green', label='BG estimate')
plt.plot(temperatures_analysis, dFs_ref, linewidth=2, color='black', label='Exact value')
plt.fill_between(temperatures_analysis, means-2.0*uncertainties, means+2.0*uncertainties, color='green', alpha=0.5)
plt.xlabel('Temperature / $T_0$')
plt.ylabel('Free energy difference / $kT_0$')
plt.semilogx()
plt.xlim(0.1, 3)
plt.ylim(-7, 35)

#plt.semilogy()
#plt.ylim(0, 1.0)
plt.legend(loc=3, frameon=False)
#plt.savefig(paper_dir + 'figs/double_well/free_energy_2BGs.pdf', bbox_inches='tight', transparent=True)
